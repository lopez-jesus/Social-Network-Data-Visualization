# %% [markdown]
# # Social Network Data Visualization
#
# This projects builds upon the previous one we completed: "Classifying Nobel Prize Physicists by Physics Field."
#
# In that project, we assigned each Nobel Prize Physicist to one of 6 physics subfields. Now, we graphically represent all these physicists (along with various physics domains) as a social network.
#
# ## Social network - The basics
# A social network consists of nodes and links between those nodes. We produce a small social network as a json file, where the nodes are phsicists, and the links are "connections between them". The file produced is named "small_network.json". To visualize this network, you must open the "small_network.html" file (provided by Damien Benveniste) in your preferred browser. Both the JSON and HTML files are available in the repository.
#
# NOTE: In order to work, the json file MUST be in a folder titled "data", which is itself within the folder containing the html file.

# %%
small_network = {
    "nodes": [
        {"id": "Albert Einstein"},
        {"id": "Paul Dirac"},
        {"id": "Niels Bohr"}
    ],
    "links": [
        {"source": "Albert Einstein", "target": "Paul Dirac"},
        {"source": "Albert Einstein", "target": "Niels Bohr"},
        {"source": "Paul Dirac", "target": "Niels Bohr"}
    ]
}

## We dump this network into a .json file
import json
with open(".\data\small_network.json","w") as f:
    json.dump(small_network, f, indent=4)

# %% [markdown]
# The networks just created is simple. The rest of this project builds a more complex social network, connecting Nobel physicists and various physics topics.
#
# ## Getting physicists and physics domains data
#
# We are going to gather the words from the Wikipedia pages for physicists and physics domains. This will be the information we use to determine which physicists/domains are connect to which, and how strong each connection is.
#
# We first get the links for each Nobel physicist's and physics domains's Wikipedia page. We identify the Nobel physicists by a table present at "https://en.wikipedia.org/wiki/List_of_Nobel_laureates_in_Physics" (as of 12 Jul 2018) which lists them all. We get the physics topics from the Reasearch table at "https://en.wikipedia.org/wiki/Physics", which lists all these physics domains.
#
# - ### Gathering physicists links
# We gather the links for the physicists. This is largely done using the code from the previous project, "Classifying Nobel Prize Physicists by Physics Field." However, we drop the Year, Country, Rationale that we gather. We then use Beautiful Soup to parse for the links on Wikipedia. At the end of this we have a df with the physicist ("Laureate") as the index, and containing the links for each physicist's Wikipedia page.

# %%
## We get the nobel data set
import numpy as np
import pandas as pd
from httplib2 import Http
from bs4 import BeautifulSoup, SoupStrainer

class Parser:
    
    def __init__(self, url):  
        http = Http()
        status, response = http.request(url)
        tables = BeautifulSoup(response, "lxml", 
                              parse_only=SoupStrainer("table", {"class":"wikitable plainrowheaders sortable"}))
        self.table = tables.contents[1]
    
    def parse_table(self):      
        rows = self.table.find_all("tr")
        header = self.parse_header(rows[0])
        table_array = [self.parse_row(row) for row in rows[1:]]
        table_df = pd.DataFrame(table_array, columns=header).apply(self.clean_table, 1)
        table_df = table_df.replace({"Year":{'':np.nan}})
        table_df.drop(labels = ['Ref','Image'], axis =1, inplace=True)
        return table_df
        
    def parse_row(self, row):     
        columns = row.find_all(["td","th"])
        return [BeautifulSoup.get_text(col).strip() for col in columns if BeautifulSoup.get_text(col) != '']
    
    def parse_header(self, row):     
        columns = row.find_all("th")
        to_return = [BeautifulSoup.get_text(col).strip() for col in columns if BeautifulSoup.get_text(col) != ""]
        return to_return

    def clean_table(self, row):
        if not row.iloc[0].isdigit():
            return row.shift(periods = 1)
        else:
            return row
        
url = "https://en.wikipedia.org/wiki/List_of_Nobel_laureates_in_Physics"        
parser = Parser(url)   
nobel_df = parser.parse_table()

nobel_df.columns = ["Year", "Laureate", "Country", "Rationale"]
nobel_df.dropna(subset=["Country"], inplace=True)
nobel_df.fillna(method="ffill", inplace=True)
nobel_df.drop(["Year", "Country", "Rationale"], 1, inplace=True)

http = Http()
status, response = http.request(url)

table = BeautifulSoup(response, "lxml", parse_only=SoupStrainer('table'))
link_df = pd.DataFrame([[x.string, x["href"]] for x in table.contents[1].find_all("a")],
                       columns=["Laureate", "link"]).drop_duplicates()

nobel_df = nobel_df.merge(link_df, on="Laureate", how="left")
nobel_df.set_index("Laureate", inplace=True)
nobel_df.drop_duplicates(inplace=True)
nobel_df
# Out:
#                                                                           link
# Laureate
# Wilhelm Conrad Röntgen                              /wiki/Wilhelm_R%C3%B6ntgen
# Hendrik Lorentz                                          /wiki/Hendrik_Lorentz
# Pieter Zeeman                                              /wiki/Pieter_Zeeman
# Antoine Henri Becquerel                                  /wiki/Henri_Becquerel
# Pierre Curie                                                /wiki/Pierre_Curie
# Maria Skłodowska-Curie                       /wiki/Maria_Sk%C5%82odowska-Curie
# Lord Rayleigh                    /wiki/John_William_Strutt,_3rd_Baron_Rayleigh
# Philipp Eduard Anton von Lenard                           /wiki/Philipp_Lenard
# Joseph John Thomson                                        /wiki/J._J._Thomson
# Albert Abraham Michelson                             /wiki/Albert_A._Michelson
# Gabriel Lippmann                                        /wiki/Gabriel_Lippmann
# Guglielmo Marconi                                      /wiki/Guglielmo_Marconi
# Karl Ferdinand Braun                                /wiki/Karl_Ferdinand_Braun
# Johannes Diderik van der Waals            /wiki/Johannes_Diderik_van_der_Waals
# Wilhelm Wien                                                /wiki/Wilhelm_Wien
# Nils Gustaf Dalén                                      /wiki/Gustaf_Dal%C3%A9n
# Heike Kamerlingh-Onnes                            /wiki/Heike_Kamerlingh_Onnes
# Max von Laue                                                /wiki/Max_von_Laue
# William Henry Bragg                                  /wiki/William_Henry_Bragg
# William Lawrence Bragg                                    /wiki/Lawrence_Bragg
# Charles Glover Barkla                              /wiki/Charles_Glover_Barkla
# Max Planck                                                    /wiki/Max_Planck
# Johannes Stark                                            /wiki/Johannes_Stark
# Charles Édouard Guillaume                 /wiki/Charles_%C3%89douard_Guillaume
# Albert Einstein                                          /wiki/Albert_Einstein
# Niels Bohr                                                    /wiki/Niels_Bohr
# Robert Andrews Millikan                          /wiki/Robert_Andrews_Millikan
# Manne Siegbahn                                            /wiki/Manne_Siegbahn
# James Franck                                                /wiki/James_Franck
# Gustav Hertz                                         /wiki/Gustav_Ludwig_Hertz
# ...                                                                        ...
# John C. Mather                                            /wiki/John_C._Mather
# George F. Smoot                                             /wiki/George_Smoot
# Albert Fert                                                  /wiki/Albert_Fert
# Peter Grünberg                                       /wiki/Peter_Gr%C3%BCnberg
# Makoto Kobayashi                            /wiki/Makoto_Kobayashi_(physicist)
# Toshihide Maskawa                                      /wiki/Toshihide_Maskawa
# Yoichiro Nambu                                            /wiki/Yoichiro_Nambu
# Charles K. Kao                                            /wiki/Charles_K._Kao
# Willard S. Boyle                                           /wiki/Willard_Boyle
# George E. Smith                                          /wiki/George_E._Smith
# Andre Geim                                                    /wiki/Andre_Geim
# Konstantin Novoselov                                /wiki/Konstantin_Novoselov
# Saul Perlmutter                                          /wiki/Saul_Perlmutter
# Brian P. Schmidt                                           /wiki/Brian_Schmidt
# Adam G. Riess                                                 /wiki/Adam_Riess
# Serge Haroche                                              /wiki/Serge_Haroche
# David J. Wineland                                      /wiki/David_J._Wineland
# François Englert                                   /wiki/Fran%C3%A7ois_Englert
# Peter Higgs                                                  /wiki/Peter_Higgs
# Isamu Akasaki                                              /wiki/Isamu_Akasaki
# Hiroshi Amano                                              /wiki/Hiroshi_Amano
# Shuji Nakamura                                            /wiki/Shuji_Nakamura
# Takaaki Kajita                                            /wiki/Takaaki_Kajita
# Arthur B. McDonald                                    /wiki/Arthur_B._McDonald
# David J. Thouless                                      /wiki/David_J._Thouless
# F. Duncan M. Haldane                                      /wiki/Duncan_Haldane
# John M. Kosterlitz                                 /wiki/J._Michael_Kosterlitz
# Rainer Weiss                                                /wiki/Rainer_Weiss
# Kip Thorne                                                    /wiki/Kip_Thorne
# Barry Barish                                                /wiki/Barry_Barish
#
# [206 rows x 1 columns]

# %% [markdown]
# - ### Gather physics domain links
#
# Using similar code, and taking advantage of Beautiful Soup, we gather the links for the physics domains, and place them in a df named "physics_df".

# %%
## We get the physics links
url = "https://en.wikipedia.org/wiki/Physics"

http = Http()
status, response = http.request(url)

table = BeautifulSoup(response, "lxml", parse_only=SoupStrainer('table'))
physics_df = pd.DataFrame([[x.string.lower(), x["href"].lower()] for x in table.contents[3].find_all("a")],
                       columns=["Physics_domain", "link"]).drop_duplicates()

physics_df = physics_df.groupby("Physics_domain").first()

# %%
physics_df
# Out:
#                                                                                 link
# Physics_domain
# accelerator physics                                        /wiki/accelerator_physics
# acoustics                                                            /wiki/acoustics
# agrophysics                                                        /wiki/agrophysics
# antimatter                                                          /wiki/antimatter
# applied physics                                                /wiki/applied_physics
# astrometry                                                          /wiki/astrometry
# astronomy                                                            /wiki/astronomy
# astrophysics                                                      /wiki/astrophysics
# atom                                                                      /wiki/atom
# atomic and molecular astrophysics            /wiki/atomic_and_molecular_astrophysics
# atomic physics                                                  /wiki/atomic_physics
# atomic, molecular, and optical physics  /wiki/atomic,_molecular,_and_optical_physics
# bcs theory                                                          /wiki/bcs_theory
# big bang                                                              /wiki/big_bang
# biophysics                                                          /wiki/biophysics
# black hole                                                          /wiki/black_hole
# bloch wave                                                          /wiki/bloch_wave
# bose-einstein condensate                              /wiki/bose-einstein_condensate
# brane                                                      /wiki/membrane_(m-theory)
# casimir effect                                                  /wiki/casimir_effect
# chemical physics                                              /wiki/chemical_physics
# communication physics                                    /wiki/communication_physics
# condensed matter physics                              /wiki/condensed_matter_physics
# cosmic background radiation                        /wiki/cosmic_background_radiation
# cosmic inflation                                              /wiki/cosmic_inflation
# cosmic string                                                    /wiki/cosmic_string
# cosmology                                                   /wiki/physical_cosmology
# cosmos                                                                  /wiki/cosmos
# dark energy                                                        /wiki/dark_energy
# dark matter                                                        /wiki/dark_matter
# ...                                                                              ...
# quantum optics                                                  /wiki/quantum_optics
# seesaw mechanism                                              /wiki/seesaw_mechanism
# self-organization                                            /wiki/self-organization
# semiconductor                                                    /wiki/semiconductor
# solar physics                                                    /wiki/solar_physics
# solar system                                                      /wiki/solar_system
# solid                                                                    /wiki/solid
# solid state physics                                        /wiki/solid_state_physics
# solid-state devices                                        /wiki/solid-state_physics
# space physics                                                    /wiki/space_physics
# spectral line                                                    /wiki/spectral_line
# spin                                                            /wiki/spin_(physics)
# spontaneous symmetry breaking                    /wiki/spontaneous_symmetry_breaking
# standard model                                                  /wiki/standard_model
# star                                                                      /wiki/star
# statistical mechanics                                    /wiki/statistical_mechanics
# stellar astrophysics                               /wiki/astronomy#stellar_astronomy
# string                                                        /wiki/string_(physics)
# strong                                                      /wiki/strong_interaction
# superconductor                                               /wiki/superconductivity
# superfluid                                                          /wiki/superfluid
# supernova                                                            /wiki/supernova
# superstring theory                                          /wiki/superstring_theory
# supersymmetry                                                    /wiki/supersymmetry
# surface physics                                                /wiki/surface_science
# theory of everything                                      /wiki/theory_of_everything
# universe                                                              /wiki/universe
# vacuum energy                                                    /wiki/vacuum_energy
# vehicle dynamics                                              /wiki/vehicle_dynamics
# weak                                                          /wiki/weak_interaction
#
# [133 rows x 1 columns]

# %% [markdown]
# ## Gather important words from Wikipedia pages
#
# Now that we have the links, we need the words from each Wikipedia page corresponding to each link. We define a function to get a text, and multiple functions to keep only those words we consider "important". Largely, this code is borrowed from our previous project, "Classifying Nobel Prize Physicists by Physics Field." One difference here is that we aggregrate all these functions into a single function called "clean_everything" that will gather AND clean the words.
#
# - ### Gather all words from Wikipedia bios

# %%
from string import punctuation

## We get the bios
def get_text(link, root_website = "https://en.wikipedia.org"):    
    http = Http()
    status, response = http.request(root_website + link)
    body = BeautifulSoup(response, "lxml", parse_only=SoupStrainer("div", {"id":"mw-content-text"}))
    return BeautifulSoup.get_text(body.contents[1])

# %% [markdown]
# - ### Copy clean_string, remove, remove_one from previous project

# %%
## Copy clean_string function from Nobel Classification project
def clean_string(string):
    for p in punctuation + "1234567890":
        string = string.replace(p,'').lower()
    return string

## Copy remove function from the Nobel Classification project
def remove(list_to_clean, element_to_remove=[None, ""]):
    list_cleaned = [x for x in list_to_clean if x not in element_to_remove]
    return list_cleaned

## Copy remove_one function from Nobel Classification project
def remove_one(list_to_clean):
    list_cleaned = [x for x in list_to_clean if len(x) > 1]
    return list_cleaned

## Import stop words to remove
from nltk.corpus import stopwords
words_to_remove = set(stopwords.words('english'))

# %% [markdown]
# - ### Aggregate all the above functions into one to return a list of words from each link

# %%
def clean_everything(df):
    fin_list = df['link'].apply(get_text).apply(clean_string).str.split().apply(remove).apply(remove, element_to_remove = words_to_remove).apply(remove_one)
    return fin_list

physics_df["physics_list"] = clean_everything(physics_df)
nobel_df["physics_list"] = clean_everything(nobel_df)
nobel_df
# Out:
#                                                                           link  \
# Shuji Nakamura                                            /wiki/Shuji_Nakamura
# Takaaki Kajita                                            /wiki/Takaaki_Kajita
# Arthur B. McDonald                                    /wiki/Arthur_B._McDonald
# David J. Thouless                                      /wiki/David_J._Thouless
# F. Duncan M. Haldane                                      /wiki/Duncan_Haldane
# John M. Kosterlitz                                 /wiki/J._Michael_Kosterlitz
# Rainer Weiss                                                /wiki/Rainer_Weiss
# Kip Thorne                                                    /wiki/Kip_Thorne
# Barry Barish                                                /wiki/Barry_Barish
#
#                                                                       physics_list
# Laureate
# Wilhelm Conrad Röntgen           [wilhelm, röntgen, born, wilhelm, conrad, rönt...
# Hendrik Lorentz                  [confused, hendrikus, albertus, lorentz, ludvi...
# Pieter Zeeman                    [pieter, zeeman, born, may, zonnemaire, nether...
# Antoine Henri Becquerel          [uses, see, becquerel, disambiguation, antoine...
# Pierre Curie                     [pierre, curie, pierre, curie, born, may, pari...
# Maria Skłodowska-Curie           [article, polishfrench, physicist, uses, see, ...
# Lord Rayleigh                    [lord, rayleighom, prs, born, november, langfo...
# Philipp Eduard Anton von Lenard  [waterfall, effect, redirects, illusory, visua...
# Joseph John Thomson              [article, nobel, laureate, physicist, moral, p...
# Albert Abraham Michelson         [confused, athlete, albert, michelsen, albert,...
# Gabriel Lippmann                 [gabriel, lippmann, born, jonas, ferdinand, ga...
# Guglielmo Marconi                [marconi, redirects, uses, see, marconi, disam...
# Karl Ferdinand Braun             [german, politician, writer, see, karl, braun,...
# Johannes Diderik van der Waals   [uses, see, van, der, waals, disambiguation, j...
# Wilhelm Wien                     [wilhelm, wien, born, wilhelm, carl, werner, o...
# Nils Gustaf Dalén                [gustaf, dalén, born, nils, gustaf, dalén, nov...
# Heike Kamerlingh-Onnes           [heike, kamerlingh, onnes, born, heike, kamerl...
# Max von Laue                     [max, von, laue, laue, born, max, theodor, fel...
# William Henry Bragg              [confused, son, fellow, nobel, prize, winner, ...
# William Lawrence Bragg           [article, australian, born, physicist, father,...
# Charles Glover Barkla            [barkla, redirects, lunar, crater, see, barkla...
# Max Planck                       [planck, redirects, uses, see, planck, disambi...
# Johannes Stark                   [article, needs, additional, citations, verifi...
# Charles Édouard Guillaume        [charles, édouard, guillaume, born, february, ...
# Albert Einstein                  [einstein, redirects, musicologist, see, alfre...
# Niels Bohr                       [bohr, redirects, uses, see, bohr, disambiguat...
# Robert Andrews Millikan          [confused, robert, mulliken, robert, millikan,...
# Manne Siegbahn                   [manne, siegbahn, karl, manne, siegbahn, born,...
# James Franck                     [james, franck, born, august, hamburg, german,...
# Gustav Hertz                     [gustav, ludwig, hertz, hertz, born, july, fre...
# ...                                                                            ...
# John C. Mather                   [people, similar, names, see, john, mather, jo...
# George F. Smoot                  [george, smoot, george, smoot, povo, conferenc...
# Albert Fert                      [albert, fert, born, march, age, carcassonne, ...
# Peter Grünberg                   [peter, grünberg, grünberg, born, peter, andre...
# Makoto Kobayashi                 [小林, makoto, kobayashi, kobayashi, born, april...
# Toshihide Maskawa                [益川, 敏英, toshihide, maskawa, maskawa, born, fe...
# Yoichiro Nambu                   [yoichiro, nambu南部, 陽一郎, nambu, born, january,...
# Charles K. Kao                   [honourablesir, charles, kuen, kaogbm, kbe, fr...
# Willard S. Boyle                 [willard, boyle, boyle, born, august, amherst,...
# George E. Smith                  [article, american, physicist, american, polit...
# Andre Geim                       [sir, andre, geim, geim, born, andrei, konstan...
# Konstantin Novoselov             [name, uses, eastern, slavic, naming, customs,...
# Saul Perlmutter                  [saul, perlmutter, saul, perlmutter, nobel, we...
# Brian P. Schmidt                 [article, astrophysicist, music, composer, see...
# Adam G. Riess                    [adam, riess, riess, born, adam, guy, riess, d...
# Serge Haroche                    [serge, haroche, serge, haroche, stockholm, bo...
# David J. Wineland                [david, wineland, david, wineland, born, david...
# François Englert                 [françois, englert, françois, englert, born, n...
# Peter Higgs                      [british, physicist, peter, higgsch, frs, frse...
# Isamu Akasaki                    [biography, living, person, needs, additional,...
# Hiroshi Amano                    [uses, see, brave, fighter, sun, fighbird, cha...
# Shuji Nakamura                   [shuji, nakamura, shuji, nakamura, native, nam...
# Takaaki Kajita                   [takaaki, kajita, takaaki, kajita, nobel, laur...
# Arthur B. McDonald               [arthur, mcdonaldcc, oont, ons, frs, frsc, art...
# David J. Thouless                [david, thoulessfrs, david, thouless, born, da...
# F. Duncan M. Haldane             [duncan, haldane, duncan, haldane, nobel, pres...
# John M. Kosterlitz               [michael, kosterlitz, born, john, michael, kos...
# Rainer Weiss                     [rainer, weiss, weiss, june, born, september, ...
# Kip Thorne                       [kip, thorne, thorne, august, born, kip, steph...
# Barry Barish                     [article, needs, additional, citations, verifi...
#
# [206 rows x 2 columns]

# %% [markdown]
# ## How many words?
#
# We now have all the words from the Wikipedia pages for the physicists and physics domains. Let's find out how many unique words are in the nobel_df["physics_list"], how many are in physics_df["physics_list"], how many are in the interesction of the two, and how many of the words in each entry (bio) of each respective list are in the intersection.
#
# - ### Find all the words in nobel_df["physics_list"]

# %%
all_nobel_words =  set( nobel_df["physics_list"].sum() )
all_nobel_words
# Out:
# {'camilla',
#  'buckley',
#  'température',
#  'angelesdoctoral',
#  'thickness',
#  'breslow',
#  'northen',
#  'armistice',
#  'distorted',
#  'maldon',
#  'sampson',
#  'howard',
#  'maquoketa',
#  'schik',
#  'awarding',
#  'judd',
#  'mussolini',
#  'interpretational',
#  'driggs',
#  'longest',
#  'europhysics',
#  'uhuru',
#  'kaka',
#  'honesttogoodness',
#  'nicéphore',
#  'colman',
#  'delhi',
#  'cars',
#  'conducting',
#  'hbs',
#  'человека',
#  'deserlawrence',
#  'darin',
#  'bscknown',
#  'marshakgordon',
#  'bombed',
#  'cancellation',
#  'anna',
#  'roger',
#  'ovation',
#  'kattowitz',
#  'whhmxg',
#  'romanian',
#  'ccting',
#  'donor',
#  'expertise',
#  'distortion',
#  'australiancitizenship',
#  '秀樹born',
#  'distort',
#  'danby',
#  'lazarevich',
#  'orb',
#  'shiver',
#  'arxivhepex',
#  'indexes',
#  'watts',
#  'www',
#  'chap',
#  'jrfebruary',
#  'kölliker',
#  'rijkedoctoral',
#  'peres',
#  'poets',
#  'meti',
#  'nandalal',
#  'byrobert',
#  'rich',
#  'obsolescent',
#  'alton',
#  'arthurs',
#  'unassailability',
#  'pseudoreligious',
#  'chidambaram',
#  'bacterial',
#  'isotopesmass',
#  'boyle',
#  'orientation',
#  'daresbury',
#  'acs',
#  'prus',
#  'poltergeist',
#  'lose',
#  'samples',
#  'assimilate',
#  'whiffen',
#  'bischöfe',
#  'correctional',
#  'oconnor',
#  'hoop',
#  'lost',
#  'electronic',
#  'interactionsorg',
#  'gluon',
#  'jonathan',
#  'ruben',
#  'halperin',
#  'huffington',
#  'zhao',
#  'bilayers',
#  'rowena',
#  'displacement',
#  'receptions',
#  'usual',
#  'humid',
#  'refers',
#  'biospace',
#  'ihrer',
#  'editor',
#  'dhebar',
#  'witkin',
#  'rajaram',
#  'fohsankarl',
#  'itep',
#  'lcd',
#  'duly',
#  'powder',
#  'subheadings',
#  'holt',
#  'bibcodenatmac',
#  'llewellyn',
#  'kamerlingh',
#  'rubidium',
#  'truslow',
#  'szymborska',
#  'benjamins',
#  'cvv',
#  'motts',
#  'treatise',
#  'klerk',
#  'janeiro',
#  'kidney',
#  'bibcodephpb',
#  'benedicks',
#  'stancesedit',
#  'sallie',
#  'singing',
#  'elsa',
#  'lbco',
#  'cofounding',
#  'campaigning',
#  'increase',
#  'isles',
#  'junichirō',
#  'translator',
#  'illegal',
#  'courtyard',
#  'geburtsjahres',
#  'алекса́ндр',
#  'meadow',
#  'clayton',
#  'partialdruck',
#  'remsen',
#  'shipments',
#  'spiritualism',
#  'borestein',
#  'pinsky',
#  'pmc',
#  'university–',
#  'clarice',
#  'berridge',
#  'stateless',
#  'garden',
#  'francisco',
#  'singleparticle',
#  'kilby',
#  'lxii',
#  'doiradiol',
#  'romania',
#  'daynight',
#  'plate',
#  'ieeeieeeghn',
#  'media',
#  'passes',
#  'mit',
#  'ntype',
#  'youshang',
#  'sternberg',
#  'aalto',
#  'portraiture',
#  'dinant',
#  'davidovna',
#  'tobey',
#  'invisible',
#  'ам',
#  'hadrons—having',
#  'λmax',
#  'comparable',
#  'spurious',
#  'afraid',
#  'jost',
#  'scuola',
#  'collapsed',
#  'putons',
#  'statescanadaliteraturederek',
#  'transatlantic',
#  'nadai',
#  'hosei',
#  'oregonuniversity',
#  'overfly',
#  'lichtemission',
#  'backgrounds',
#  'renato',
#  'civilisation',
#  'circulated',
#  'zetterberg',
#  'ellinwood',
#  'halpern',
#  'ausserordentlicher',
#  'culturel',
#  'hundfritz',
#  'undermining',
#  'coronation',
#  'jesnsen',
#  'olympus',
#  'exileedit',
#  'lecturescitation',
#  'germanjewish',
#  'acceptor',
#  'answered',
#  'mètre',
#  'riezler',
#  'fairless',
#  'recollection',
#  'berlinbrandenberg',
#  'christmas',
#  'decided',
#  'resting',
#  'seventieth',
#  'deflectionedit',
#  'blames',
#  'emergence',
#  'equations',
#  'haldanemichael',
#  'freistaat',
#  'wie',
#  'hongwen',
#  'conversations',
#  'nyberg',
#  'shimbun',
#  'fourstar',
#  'price',
#  'filtered',
#  'dynamid',
#  'henryk',
#  'competitions',
#  '–—discovery',
#  'cariche',
#  'isaac',
#  'shapell',
#  'integrated',
#  'americandanishcitizenship',
#  'nobelprizewinning',
#  'famous',
#  'globally',
#  'buoys',
#  'structural',
#  'servicesiqcuwaterloocapeopleprofilealeggett',
#  'joe',
#  'deppner',
#  'wealth',
#  'synchrocyclotron',
#  'decaying',
#  'mr',
#  'erroneous',
#  'alder',
#  'actively',
#  'effectiveness',
#  'newsmagazine',
#  'artist',
#  'lin',
#  'finest',
#  'movers',
#  'psbt',
#  'ganalgan',
#  'pohl',
#  'ida',
#  'onedimensional',
#  'russianclimbcom',
#  'hesperium',
#  'catching',
#  'stands',
#  'supplanted',
#  'kosterlitz–thouless',
#  'etc',
#  'summed',
#  'austriahungarydied',
#  'kunming',
#  'staudinger',
#  'forney',
#  'spires',
#  'rudinger',
#  'jats',
#  'avec',
#  'disturb',
#  'endeavoured',
#  'schumacher',
#  'corpus',
#  'krise',
#  'arabic',
#  'fudan',
#  'upright',
#  'petites',
#  'istva',
#  'ketchum',
#  'environments',
#  'kohn',
#  'manual',
#  'grande',
#  'привлечь',
#  'historieknet',
#  'merzbacher',
#  'silvy',
#  'interviews',
#  'ferroelectricity',
#  'imdbcom',
#  'fused',
#  'uncovered',
#  'eötvös',
#  'spacetimes',
#  'ramanujam',
#  'predicted',
#  'prasanta',
#  'modifying',
#  'dodicken',
#  'pisaedit',
#  'frances',
#  'unsalaried',
#  'vterichard',
#  'vtebreakthrough',
#  'photographie',
#  'rodgers',
#  'marathon',
#  'reviewing',
#  'freezingcitation',
#  'submerge',
#  'doctrines',
#  'diplom',
#  'brink',
#  'ginnasio',
#  'scheduled',
#  'bpn',
#  'sullelettrostatica',
#  'brekhovskikhanatoly',
#  'organisations',
#  'medizinische',
#  'rolls',
#  'voices',
#  'founders',
#  'magnetometers',
#  'cresswelsing',
#  'pulsar',
#  'saint',
#  'trinity',
#  'things',
#  'vitalism',
#  'secrets',
#  'reuters',
#  'reportsedit',
#  'cuxhaven',
#  'liebesbriefe',
#  'contracts',
#  'mokshagundam',
#  'whs',
#  'shenglong',
#  'darby',
#  'disconcerting',
#  'transl',
#  'lectureship',
#  'overestimation',
#  'megan',
#  'chargetomass',
#  'qualified',
#  'noch',
#  'accelerator',
#  'protonneutron',
#  'uncredited',
#  'diplon',
#  'moved',
#  'xeroderma',
#  'order',
#  'parisβα',
#  'relations',
#  'helix',
#  'ges',
#  'speaks',
#  'october',
#  'lyons',
#  'proselytizers',
#  'religionwissenschaftweltbild',
#  'residing',
#  'fastgrowing',
#  'michał',
#  'copied',
#  'invested',
#  'bai',
#  'word',
#  'consider',
#  'cartlidge',
#  'sophomore',
#  'ads',
#  'polishjewishfrenchcitizenship',
#  'recast',
#  'fostering',
#  'twentythree',
#  'jia',
#  'respecting',
#  'knaw',
#  'armstrong',
#  'recognized',
#  'doibf',
#  'па́вел',
#  'campina',
#  'transitioned',
#  'discern',
#  'centred',
#  'grating',
#  'impressions',
#  'teng',
#  'zygmund',
#  'satebt',
#  'felix',
#  'ennery',
#  'lélectricité',
#  'phillip',
#  'principals',
#  'consultant',
#  'shouse',
#  'sushantha',
#  'onewoman',
#  'marey',
#  'books',
#  'testability',
#  'flower',
#  'erda',
#  'novette',
#  'topologyand',
#  'bizarre',
#  'adcock',
#  'bc',
#  'fluids',
#  'ignacio',
#  'along',
#  'rumoured',
#  'walton',
#  'prerequisites',
#  'sb',
#  'hertha',
#  'raided',
#  'gamebut',
#  'didier',
#  'mechanics',
#  'lindemann',
#  'preparations',
#  'connections',
#  'doc',
#  'ottawa',
#  'gwilyn',
#  'fullerian',
#  'independently—a',
#  'outcome',
#  'delved',
#  'mile',
#  'uepler',
#  'kharkov',
#  'polands',
#  'renowned',
#  'dogmatism',
#  'division',
#  'gamesmanship',
#  'paulsson',
#  'landsat',
#  'repetitively',
#  'eruptions',
#  'asahicom',
#  'jpl',
#  'secure',
#  'deprivation',
#  'portalbiography',
#  'inert',
#  'nonleptonic',
#  'skipp',
#  'pride',
#  'erinnerungen',
#  'ethyne',
#  'kernphysik',
#  'mourners',
#  'déformations',
#  'movies',
#  'httpwwwiasicsdorgresourcesicsdiasfoundingmemberspdf',
#  'farmelo',
#  'hopkinson',
#  'della',
#  'urs',
#  'reserve',
#  'transistor',
#  'cajal',
#  'volunteer',
#  'pagel',
#  'ver',
#  'semicircle',
#  'hayes',
#  'warships',
#  'figger',
#  'appreciable',
#  'utokyo',
#  'farms',
#  'facilitate',
#  'recentlyspecify',
#  'jca',
#  'tadatoshi',
#  'igem',
#  'bibcodervmpsw',
#  'wikiproject',
#  'немец',
#  'distracted',
#  'gavriel',
#  'careerservicebranch',
#  'labradorite',
#  'mandela',
#  'recollected',
#  'excitation',
#  'observatory',
#  'internationallyrecognised',
#  'bombarding',
#  'shivkumar',
#  'hoodbhoy',
#  'earl',
#  'ukiyoe',
#  'estes',
#  'blauert',
#  'nf',
#  'universität',
#  'pseudotelepathy',
#  'priorities',
#  'collecting',
#  'proclaiming',
#  'fruit',
#  'strike',
#  'rajagopala',
#  'luomo',
#  'carbonoxygennitrogen',
#  'transportation',
#  'gamows',
#  'touching',
#  'perioden',
#  'bibliographyedit',
#  'medzhitov',
#  'tsui崔琦',
#  'oxfordtrained',
#  'hacon',
#  'bounded',
#  'attilio',
#  'tecumseh',
#  'beckerdoctoral',
#  'nap',
#  'transferred',
#  'neal',
#  'morozov',
#  'freefalling',
#  'texasnationality',
#  'alsatian',
#  'climatology',
#  'llc',
#  'opium',
#  'belatedly',
#  'agreement',
#  'railways',
#  'vtediscovery',
#  'bfzhh',
#  'mormon',
#  'karuizawa',
#  'daoxing',
#  'focussing',
#  'cisoc',
#  'ardenne',
#  'verdun',
#  'insulators',
#  'appearing',
#  'carolina',
#  'remote',
#  'poggio',
#  'mizrachi',
#  'grimmeiss',
#  'little',
#  'rosse',
#  'cause',
#  'leaked',
#  'solidstate',
#  'ehnu',
#  'valenzkräfte',
#  'wdfstk',
#  'simpson',
#  'williamson',
#  'pfa',
#  'flavors',
#  'gladys',
#  'quickly',
#  'acae',
#  'wuhua',
#  'roe',
#  'l’invention',
#  'groupphase',
#  'filed',
#  'talked',
#  'magdalen',
#  'srivastava',
#  'interplay',
#  'oup',
#  'albrecht',
#  'baumeister',
#  'primacy',
#  'hallowell',
#  'wkdtr',
#  'calm',
#  'located',
#  'prevented',
#  'carlton',
#  'sapienza',
#  'elegant',
#  'atherosclerosis',
#  'proposer',
#  'fr',
#  'derek',
#  'layer”',
#  'получил',
#  'tete',
#  'encyclopædia',
#  'sanqiang',
#  'anschluss',
#  'luciano',
#  'athenäumverl',
#  'misguided',
#  'novels',
#  'maybritt',
#  'tons',
#  'chinafrancepeacekim',
#  'younger',
#  'coster',
#  'grad',
#  'lankester',
#  'freedom',
#  'afcea',
#  'short',
#  'corpuscle',
#  'kroebel',
#  'biography',
#  'pierce',
#  'aesthetics',
#  'shoichi',
#  'chemischen',
#  'lal',
#  'signing',
#  'univerziteta',
#  'interplanetary',
#  'computergenerated',
#  'paul',
#  'dikshit',
#  'selfreliance',
#  'use',
#  'watchung',
#  'hinducom',
#  'masonic',
#  'bonner',
#  'ictp',
#  'braunschen',
#  'chern',
#  'representatives',
#  'ellis',
#  'coblentz',
#  'maarten',
#  'britishamerican',
#  'effectlandau–yang',
#  'sv',
#  'né',
#  'piper',
#  'kennikat',
#  'httpschroniclecomarticlenobelistcarlwiemanmovesto',
#  'sota',
#  'moments',
#  'httpswwwnytimescomsciencealexeiabrikosovnobellaureateinphysicsdieshtml',
#  'routhsir',
#  'serin',
#  'brans–dicke',
#  'supervised',
#  'ap',
#  'slonimsky',
#  'televisions',
#  'sidgwick',
#  'honouring',
#  'obituaries',
#  'pending',
#  'campbell',
#  'elihu',
#  'retain',
#  'celebrations',
#  'klaas',
#  'yorknationality',
#  'barry',
#  'kemmerother',
#  'deeply',
#  'laboratoryparis',
#  'overpowered',
#  'doodle',
#  'debris',
#  'ozone',
#  'lion',
#  'emuseum',
#  'everitt',
#  'theological',
#  'trapprecise',
#  'installed',
#  'cohnsherbok',
#  'direktor',
#  'stoneman',
#  'majumder',
#  'censorship',
#  'shortlist',
#  'jinping',
#  'certitude',
#  'carlos',
#  'springerlink',
#  'unprepared',
#  'incredible',
#  'sensitivity',
#  'europeans',
#  'trial',
#  'parent',
#  'homemade',
#  'm͎͎',
#  'nim',
#  'ras',
#  'programmes',
#  'fission',
#  'examiner',
#  'government—peoples',
#  'diminish',
#  'refundable',
#  'tavaré',
#  'curl',
#  'bursary',
#  'stabilization',
#  'homeopathy',
#  'ynet',
#  'socialismedit',
#  'territory',
#  'aneesur',
#  'ˈmʌri',
#  'blas',
#  'tricart',
#  'teylers',
#  'ramoji',
#  'considerations',
#  'pronouncing',
#  'bunsengustav',
#  'safekeeping',
#  '\u200bh⁄mec',
#  'usalma',
#  'madhavan',
#  'detention',
#  'alienated',
#  'guloy',
#  'middleclass',
#  'sm',
#  'dexter',
#  'miniaturise',
#  'lays',
#  'wolfram',
#  'springer',
#  'dietz',
#  'smith',
#  'atomes',
#  'ingredient',
#  'теряют',
#  'stockholmsdelen',
#  'fernandez',
#  'propagator',
#  'ruckenstein',
#  'wax',
#  'khans',
#  'philly',
#  'hypotheses',
#  'bibcodenaturn',
#  'hallewittenberg',
#  'hate',
#  'hyderabad',
#  'starvation',
#  'sneddon',
#  'practical',
#  'distinction',
#  'presidents',
#  'westmoreland',
#  'shoes',
#  'goldberg',
#  'gita',
#  'jessica',
#  'radiochemistry',
#  'soraa',
#  'abul',
#  'questionable',
#  'slavnov–taylor',
#  'todays',
#  'simulation',
#  'characteristics',
#  'jenő',
#  'karlmarxstadt',
#  'drops',
#  'associated',
#  'cowley',
#  'children',
#  'decusatis',
#  'tunzelmann',
#  'rebuilding',
#  'transuranium',
#  'conductingpower',
#  'hw',
#  'mößbauer',
#  'oddz',
#  'youtubeb',
#  'aviation',
#  'jalil',
#  'haitingerpreis',
#  'bibcodesciamcd',
#  'convent',
#  'triton',
#  'perkins',
#  'synthesis',
#  'stanislao',
#  'correspond',
#  'spook',
#  'photoborn',
#  'thy',
#  'südhof',
#  'rocks',
#  'phonétique',
#  'chafed',
#  'buenos',
#  'jiangsu',
#  'clapeyron',
#  'moleculaire',
#  'validity',
#  'lasiastateedu',
#  'friedel',
#  'takeover',
#  'toll',
#  'behavior',
#  'brazilian',
#  'homi',
#  'ohki',
#  'reconnaissance',
#  'favorite',
#  'transition',
#  'lifeinterpretations',
#  'phases',
#  'crisis',
#  'centuryold',
#  'indiana',
#  'foreigner',
#  'climate',
#  'λ’',
#  'margarethe',
#  'mcpherson',
#  'scienceworld',
#  'discontinuity',
#  'fallout',
#  'problems',
#  'chelyabinsk',
#  'idealen',
#  'nanotechnology',
#  'cms',
#  'endless',
#  'assay',
#  'doctor',
#  'jennet',
#  'loran',
#  'rigor',
#  'civilized',
#  'shun',
#  'promoter',
#  'matters',
#  'hannah',
#  'illuminated',
#  'anfangs',
#  'moos',
#  'nationalsozialistischer',
#  'series',
#  'nagendra',
#  'dordrecht',
#  '—high',
#  'balakrishnan',
#  'physics—an',
#  'apparent',
#  'encyclopediacom',
#  'jha',
#  'immunologist',
#  'funeral',
#  'cristoforo',
#  'joliotcurieève',
#  'denisyuk',
#  'aa',
#  'style',
#  'decision',
#  'pietro',
#  'dune',
#  'hardy',
#  'unveiled',
#  'scalar',
#  'holds',
#  'serve',
#  'importantly',
#  'lea',
#  'nogues',
#  'dimension',
#  'biochemistry',
#  'keve',
#  'grant',
#  'fascismo',
#  'rsfsr',
#  'happer',
#  'harnessing',
#  'sverdlovsk',
#  'eighties',
#  'microstructures',
#  'portraits',
#  '“fabrication',
#  'transtech',
#  'havoc',
#  'pond',
#  'seizure',
#  'schilpp',
#  'ripe',
#  'pty',
#  'wake',
#  'kumasi',
#  'highlighted',
#  'overviewed',
#  'wqxkx',
#  'austriahungary',
#  'sweetheart',
#  'girl',
#  'duo',
#  'sciencesdivision',
#  'wrvv',
#  'brothermorgan',
#  'jozef',
#  'went',
#  'belgian',
#  'clicks',
#  'yuriy',
#  'firework',
#  'kerri',
#  'aitchison',
#  'nucleisodium',
#  'annihilated',
#  'millimetre',
#  'adjoint',
#  'reichshälfte',
#  'kraków',
#  'odds',
#  'lommel',
#  'télécharger',
#  'academy’s',
#  'eradication',
#  'chicagoacademic',
#  'strasbourguniversity',
#  'wnzk',
#  'fortunate',
#  'moving',
#  'bibcodeamjphc',
#  'wikibooks',
#  'haque',
#  'extrasensory',
#  'grandducal',
#  'barteljorisstraat',
#  'sortedam',
#  'transported',
#  'glashow',
#  'ordinates',
#  'booming',
#  'parliament',
#  'commodore',
#  'knuth',
#  'englandresidence',
#  'helveticat',
#  'prentis',
#  'fortyfive',
#  'goodbye',
#  'christ',
#  'magic',
#  'earth—creatures',
#  'chaturvedi',
#  'stress',
#  'archives',
#  'arguments',
#  'berühmte',
#  'bernard',
#  'jungnickel',
#  'ha',
#  'salwi',
#  'hat',
#  ...}

# %% [markdown]
# - ### Find all the words in physics_df["physics_list"]

# %%
all_physics_words =  set( physics_df["physics_list"].sum() )
all_physics_words
# Out:
# {'paints',
#  'deimosmoon',
#  'galyam',
#  'debyes',
#  'thickness',
#  'logicians',
#  'distorted',
#  'sculptures',
#  'howard',
#  'green–kubo',
#  'chevallier',
#  'cαγo',
#  'cgh',
#  'longest',
#  'patil',
#  'europhysics',
#  'florian',
#  'motioncitation',
#  'conceptedit',
#  'subbrown',
#  'cars',
#  'conducting',
#  'bina',
#  'sushruta',
#  'cancellation',
#  'meanfield',
#  'eccentricity',
#  'maire',
#  'anna',
#  'roger',
#  'ldx',
#  'lamarckism',
#  'romanian',
#  'offshore',
#  'neoncopper',
#  'brandon',
#  'setend',
#  'slicing',
#  'expertise',
#  'donor',
#  'distortion',
#  'distort',
#  'danby',
#  'rotatingnonspherical',
#  'sipylum',
#  'orb',
#  'alhazens',
#  'superdense',
#  'qm',
#  'arxivhepex',
#  'watts',
#  'grummans',
#  'indexes',
#  'riser',
#  'www',
#  'chap',
#  'integrator',
#  'decker',
#  'peres',
#  'trick',
#  'tunnelingcurrent',
#  'straightforwardly',
#  'rich',
#  'snr',
#  'cladding',
#  'leftcidagger',
#  'biomaterials',
#  'bk†',
#  'deviates',
#  'bacterial',
#  'bangedit',
#  'orientation',
#  'even–even',
#  'boyle',
#  'acs',
#  'lose',
#  'samples',
#  'floatovoltaics',
#  'timetravelers',
#  'electrorheological',
#  'firsts',
#  'oconnor',
#  'hoop',
#  'heuristically',
#  'terrella',
#  'pram',
#  'lost',
#  'electronic',
#  'interactionsorg',
#  'gluon',
#  'jonathan',
#  'finetuned',
#  'huffington',
#  'ruben',
#  'structure–activity',
#  'zhao',
#  'bilayers',
#  'solarization',
#  'dilution',
#  'displacement',
#  'usual',
#  'humid',
#  'refers',
#  'reimhult',
#  'editor',
#  'chirped',
#  'tellure',
#  'rtd',
#  'ipser',
#  'oeckl',
#  'dpsk',
#  'lcd',
#  'powder',
#  'aetius',
#  'holt',
#  'llewellyn',
#  'deile',
#  'kamerlingh',
#  'gmu',
#  'bibcodephrvdbs',
#  'rubidium',
#  'bibcodecsxsbookm',
#  'rpsi',
#  'presocratic',
#  'inevitability',
#  'treatise',
#  'giallongo',
#  'biosynthesis',
#  'janeiro',
#  'kidney',
#  'terrile',
#  'nast',
#  'sciencedaily',
#  'isolator',
#  'gherghetta',
#  'heatfree',
#  'bibcodearaat',
#  'reichert',
#  'compression',
#  'aliunde',
#  'toluene',
#  'motherlode',
#  'lowscale',
#  'mtheory',
#  'elsa',
#  'routinely',
#  'rightfrac',
#  'dittmann',
#  'increase',
#  'hartlehawking',
#  'ism',
#  'kdemo',
#  'translator',
#  'kutta',
#  'nhs',
#  'solarservercom',
#  'bibcodeaap',
#  'clayton',
#  'platzer',
#  'watlet',
#  'cryptography',
#  'pmc',
#  'garden',
#  'francisco',
#  'perezramirez',
#  'singleparticle',
#  'photometric',
#  'rj',
#  'romania',
#  'daynight',
#  'plate',
#  'agemetallicity',
#  'lindenmayer',
#  'media',
#  'passes',
#  'eialpha',
#  'mit',
#  'ntype',
#  'hamber',
#  'havarneanu',
#  'sternberg',
#  'aalto',
#  'helv',
#  'invisible',
#  'sylvie',
#  'horatio',
#  'nashelsky',
#  'comparable',
#  'spurious',
#  'thermoacoustics',
#  'battlestar',
#  'collapsed',
#  'atomsm',
#  'backgrounds',
#  'civilisation',
#  'modernday',
#  'mang',
#  'circulated',
#  'manyelectron',
#  'deformities',
#  'var',
#  'halpern',
#  'gravitationnewtons',
#  'photogeneration',
#  'singlecrystal',
#  'sliced',
#  'olympus',
#  'tertiary',
#  'acceptor',
#  'hera',
#  'answered',
#  'nickelironchromium',
#  'crete',
#  'nnlo',
#  'gif',
#  'duck',
#  'httpsarxivorgabshepth',
#  'decided',
#  'resting',
#  'cryopreservation',
#  'conceivable',
#  'flakes',
#  'nola',
#  'outshine',
#  'sages',
#  'stressedit',
#  'arbitrarydimensional',
#  'emergence',
#  'adolph',
#  'solidifying',
#  'selfassembly',
#  'equations',
#  'fuelsedit',
#  'wie',
#  'nonsusy',
#  'ihe',
#  'hocus',
#  'nmomega',
#  'conversations',
#  'beginbmatrixeioverline',
#  'pycbc',
#  'neglects',
#  'price',
#  'cwp',
#  'zoldan',
#  'tetrad',
#  'filtered',
#  'nilakantha',
#  'diminue',
#  'henryk',
#  'reducible',
#  'sahls',
#  'dampe',
#  'isaac',
#  'scienceii',
#  'rrightleftvec',
#  'integrated',
#  'largevolume',
#  'rectangular',
#  'famous',
#  'globally',
#  'bibcodecqgrajd',
#  'pavement',
#  'structural',
#  'heliosphere',
#  'wealth',
#  'tedxcolumbus',
#  'walliser',
#  'decaying',
#  'albiruni',
#  'collisioncoalescence',
#  'mr',
#  'erroneous',
#  'scalardriven',
#  'reestimates',
#  'egestate',
#  'actively',
#  'effectiveness',
#  'hannink',
#  'transfersome',
#  'artist',
#  'lin',
#  'squashed',
#  'pohl',
#  'ida',
#  'onedimensional',
#  'bibcodephrvlv',
#  'catching',
#  'chomsky',
#  'metalpoor',
#  'stands',
#  'etc',
#  'radiale',
#  'summed',
#  'firstmentioned',
#  'pulleyn',
#  'shpak',
#  'nostrums',
#  'pigment',
#  'textminlambda',
#  'pvwatts',
#  'disturb',
#  'avec',
#  'solargenerated',
#  'schumacher',
#  'titane',
#  'arabic',
#  'upright',
#  'carbon—to',
#  'gmathrm',
#  'environments',
#  'manual',
#  'kohn',
#  'abgerufen',
#  'blueshift',
#  'peiris',
#  'currentlyknown',
#  'fluxions',
#  'merzbacher',
#  'interviews',
#  'ammisaduqa',
#  'amid',
#  'geometrycurved',
#  'fused',
#  'uncovered',
#  'pp¯',
#  'eötvös',
#  'ravin',
#  'letarte',
#  'spacetimes',
#  'bartenstein',
#  'predicted',
#  'laserdevice',
#  'doiepjhey',
#  'modifying',
#  'prasanta',
#  'frances',
#  'explosion←earliest',
#  'wellunderstood',
#  'mostmassive',
#  'waelbroeck',
#  'eigengravitation',
#  'vtebreakthrough',
#  'tpartial',
#  'rodgers',
#  'marsplanet',
#  'minutely',
#  'bibcodejgras',
#  'reviewing',
#  'doesn´t',
#  'd’angelo',
#  'wegner',
#  'geodynamo',
#  'offresonant',
#  'doctrines',
#  'segregate',
#  'brink',
#  'scheduled',
#  'mollerach',
#  'infrac',
#  'definitely',
#  'depolarization',
#  'cgs',
#  'organisations',
#  'pulsar',
#  'rolls',
#  'founders',
#  'voices',
#  'magnetometers',
#  'chandrasekhar‐mass',
#  'behmechanism',
#  'previouslyunknown',
#  'hazeltine',
#  'moshé',
#  'things',
#  'secrets',
#  'reuters',
#  'oggtheora',
#  'nanohub',
#  'bibcodephthw',
#  'hasnip',
#  'contracts',
#  'gj',
#  'manifoldequivalence',
#  'cryosphere',
#  'transl',
#  'constructively',
#  'stau',
#  'quaestiones',
#  'africans',
#  'megan',
#  'draconis',
#  'krolik',
#  'thestandard',
#  'bikmaev',
#  'qualified',
#  'accelerator',
#  'redondo',
#  'gpc',
#  'zeushlons',
#  'braibant',
#  'moved',
#  'rochdi',
#  'order',
#  'there’s',
#  'relations',
#  'helix',
#  'systemnote',
#  'speaks',
#  'october',
#  'timescale',
#  'barbary',
#  'thunderstorm',
#  'lyons',
#  'chord',
#  'schnurr',
#  'colonization',
#  'scatteringedit',
#  'pollio',
#  'word',
#  'consider',
#  'invested',
#  'cartlidge',
#  'ads',
#  'rheaf',
#  'recast',
#  'cyrene',
#  'baixeras',
#  'jia',
#  'gigapascals',
#  'armstrong',
#  'saladi',
#  'recognized',
#  'doibf',
#  'airmass',
#  'peroxide',
#  'jeanluc',
#  'discern',
#  'slenderbody',
#  'changcai',
#  'grating',
#  'impressions',
#  'arrayed',
#  'felix',
#  'leptogenesis',
#  'staple',
#  'phillip',
#  'trough',
#  'ihhutchinson',
#  'monolithically',
#  'books',
#  'featurecitation',
#  'bibcodejpcmd',
#  'semiclass',
#  'muñoz',
#  'marinacci',
#  'erda',
#  'novette',
#  'siege',
#  'groundpenetrating',
#  'bizarre',
#  'bc',
#  'fluids',
#  'palz',
#  'oxygenneonmagnesium',
#  'breitbach',
#  'ignacio',
#  'along',
#  'psymmetry',
#  'shultis',
#  'pauleau',
#  'eqn',
#  'walton',
#  'bibcodenuphb',
#  'backlit',
#  'sb',
#  'banned',
#  'kusenko',
#  'becke',
#  'skillman',
#  'nkepsilon',
#  'didier',
#  'binaries',
#  'mechanics',
#  'icedit',
#  'preparations',
#  'connections',
#  'doc',
#  'ottawa',
#  'mercuryvenusearthmarsjupitersaturnuranusneptuneknown',
#  'xc',
#  'mole',
#  'bre',
#  'coleman–mandula',
#  'corpse',
#  'straighter',
#  'outcome',
#  'voltas',
#  'lineshape',
#  'renowned',
#  'division',
#  'counterweighs',
#  'steplike',
#  'eruptions',
#  'changeable',
#  'jpl',
#  'vhf',
#  'astro',
#  'bibcodemnrase',
#  'inert',
#  'podsiadlowski',
#  'fowles',
#  'grab',
#  'laboratorymade',
#  'movies',
#  'atomprobe',
#  'msbar',
#  'integers',
#  'timeevolution',
#  'della',
#  'urs',
#  'epsi',
#  'gritsch',
#  'reserve',
#  'unbiased',
#  'antired',
#  'transistor',
#  'ew',
#  'governance',
#  'leaved',
#  'azzam',
#  'hypotheticalobjects',
#  'hayes',
#  'californiariverside',
#  'wafer',
#  'mayall',
#  'handedness',
#  'iptf',
#  'farms',
#  'facilitate',
#  'setia',
#  'fujibayashi',
#  'resistanceedit',
#  'marchetti',
#  'olby',
#  'schneegans',
#  'ndyvo',
#  'wikiproject',
#  'cortina',
#  'bibcodervmpsw',
#  'hg',
#  'mineraloids',
#  'excitation',
#  'migma',
#  'observatory',
#  'fragmentation',
#  'curvelike',
#  'qurán',
#  'kronecker',
#  'afflicts',
#  'discredits',
#  'bibcodephtib',
#  'blauert',
#  'nf',
#  'unverifiable',
#  'universität',
#  'priorities',
#  'byrne',
#  'varun',
#  'fruit',
#  'strike',
#  'transportation',
#  'gamows',
#  'tractable',
#  'bibliographyedit',
#  'grinding',
#  'gadzuk',
#  'precipitators',
#  'narrower',
#  'bounded',
#  'nparticle',
#  'ὅλος',
#  'τὸ',
#  'transferred',
#  'neal',
#  'diversa',
#  'morozov',
#  'sbdelta',
#  'freefalling',
#  'microgeneration',
#  'timechange',
#  'buildingmounted',
#  'dunkle',
#  'bibcodejhepa',
#  'llc',
#  'nasu',
#  'pifrac',
#  'agreement',
#  'kurtiss',
#  'railways',
#  'bibcodephrvbl',
#  'reiss',
#  'zoned',
#  'negated',
#  'selin',
#  'bravais',
#  'stefanov',
#  'insulators',
#  'qlefttfrac',
#  'subgiant',
#  'portalgravitation',
#  'appearing',
#  'spatiales',
#  'fichtel',
#  'carolina',
#  'remote',
#  'alandalus',
#  'little',
#  'httpswwwnistgovpublicaffairsreleasesbecbackgroundcfm',
#  'diazenylium',
#  'schenker',
#  'multiset',
#  'rosse',
#  'inflating',
#  'solidstate',
#  'cause',
#  'eocm',
#  'lazzarin',
#  'ltextn',
#  'ehnu',
#  'rescaling',
#  'simpson',
#  'williamson',
#  'jorryt',
#  'dalal',
#  'flavors',
#  'quickly',
#  'bournaud',
#  'formalismedit',
#  'filed',
#  'bibcodersptad',
#  'donc',
#  'bogoliubov',
#  'rica',
#  'interplay',
#  'oup',
#  'albrecht',
#  'acknowledging',
#  'cyclopropenone',
#  'fthenakis',
#  'geobiology',
#  'located',
#  'calm',
#  'acp',
#  'sotoeguibar',
#  'carlton',
#  'prevented',
#  'elegant',
#  'distancedefinition',
#  'reessciama',
#  'fr',
#  'arsenijevic',
#  'blochs',
#  'derek',
#  'biogeography',
#  'encyclopædia',
#  'mariner',
#  'space–what',
#  'fueledit',
#  'aqual',
#  'luciano',
#  'maybritt',
#  'younger',
#  'counterpart',
#  'movable',
#  'schism',
#  'freedom',
#  'short',
#  'lafon',
#  'corpuscle',
#  'biography',
#  'pierce',
#  'shoichi',
#  'paracrystalline',
#  'lal',
#  'straub',
#  'yanling',
#  'interplanetary',
#  'gopakumar',
#  'megabars',
#  'bibcodeapssd',
#  'aboutclassical',
#  'computergenerated',
#  'antimatter–matter',
#  'fluctuation–dissipation',
#  'paul',
#  'use',
#  'extensible',
#  'upmanship',
#  'ketenyl',
#  'superparamagnet',
#  'szapudi',
#  'chern',
#  'ccp',
#  'ictp',
#  'ellis',
#  'kovalevskayas',
#  'photocoagulation',
#  'aigo',
#  'bibcodenascpb',
#  'sv',
#  'memristor',
#  'moments',
#  'liver',
#  'reservations',
#  'haoyi',
#  'serin',
#  'brans–dicke',
#  'ap',
#  'televisions',
#  'fabricate',
#  'honouring',
#  'volatiles',
#  'pending',
#  'campbell',
#  'silvera',
#  'retain',
#  'quia',
#  'doublewalled',
#  'nonbiological',
#  'barry',
#  'crystallinesilicon',
#  'molecularscale',
#  'deeply',
#  'intromission',
#  'surfacetensiondriven',
#  'lion',
#  'possesses',
#  'ozone',
#  'wavelets',
#  'debris',
#  'theological',
#  'everitt',
#  'imbalances',
#  'ik',
#  'nanocomposites',
#  'roderic',
#  'installed',
#  'bunce',
#  'censorship',
#  'jinping',
#  'shortlist',
#  'parallelplate',
#  'terella',
#  'equipartition',
#  'carlos',
#  'dishes',
#  'muchnik',
#  'protostars',
#  'sensitivity',
#  'pmaxecdot',
#  'hpartial',
#  'galileophysvirginiaedu',
#  'hawkingorguk',
#  'europeans',
#  'goroff',
#  'lase',
#  'pathway',
#  'trial',
#  'parent',
#  'icebergs',
#  'reconstructs',
#  'homemade',
#  'closepacked',
#  'coalfired',
#  'downwind',
#  'crises',
#  'ras',
#  'hybrids',
#  'programmes',
#  'fission',
#  'dimensionsk',
#  'diminish',
#  'io',
#  'lcds',
#  'stabilization',
#  'curl',
#  'randall–sundrum',
#  'territory',
#  'aneesur',
#  'subjecting',
#  'ackley',
#  'bailes',
#  'reshmy',
#  'considerations',
#  'metaanalysis',
#  'approachesstring',
#  'nearsurface',
#  'coalesce',
#  'microfluidics',
#  'rad⋅m−',
#  'rothe',
#  'fullest',
#  'wrist',
#  'sm',
#  'transneptunian',
#  'lays',
#  'wolfram',
#  'compresses',
#  'springer',
#  'polchinskij',
#  'ratz',
#  'stobaeus',
#  'geochemical',
#  'smith',
#  'longawaited',
#  'ingredient',
#  'vteradiation',
#  'propagator',
#  'gangopadhyaya',
#  'wax',
#  'nonstandard',
#  'hypotheses',
#  'bibcodenaturn',
#  'combisystem',
#  'heavyquarkonium',
#  'homotopy',
#  'hannambu',
#  'astronomic',
#  'mirny',
#  'pascos',
#  'pointtopoint',
#  'us—they',
#  'geometriesedit',
#  'practical',
#  'distinction',
#  'uy',
#  'poznanski',
#  'bazo',
#  'jessica',
#  'radiochemistry',
#  'questionable',
#  'nebula',
#  'sadegh',
#  'simulation',
#  'todays',
#  'characteristics',
#  'comfort',
#  'высшего',
#  'suppositions',
#  'gas—so',
#  'drops',
#  'associated',
#  'cowley',
#  'decusatis',
#  'transuranium',
#  'hw',
#  'randomly',
#  'aviation',
#  'dina',
#  'wentworth',
#  'triton',
#  'perkins',
#  'neutrinoantineutrino',
#  'synthesis',
#  'stanislao',
#  'notional',
#  'correspond',
#  'leftarrow',
#  'oneway',
#  'nuncius',
#  'ndcentury',
#  'nbohr',
#  'downflows',
#  'ħωk',
#  'rinton',
#  'rocks',
#  'pits',
#  'continuity—infinitely',
#  'наук',
#  'validity',
#  'μl',
#  'mostprecisely',
#  'buyer',
#  'tj',
#  'friedel',
#  'moʊs',
#  'serranoluján',
#  'behavior',
#  'dolgov',
#  'cmtimes',
#  'laquila',
#  'thermostat',
#  'brazilian',
#  'posthelium',
#  'processingstructureproperties',
#  'transition',
#  'favorite',
#  'phases',
#  'crisis',
#  'china’s',
#  'bibcodervmpe',
#  'climate',
#  'archaeological',
#  'mcpherson',
#  'discontinuity',
#  'relegated',
#  'problems',
#  'dissipated',
#  'bibcodefophd',
#  'stars—even',
#  'idealen',
#  'nanotechnology',
#  'cms',
#  'counterterm',
#  'nearest',
#  'sunscreen',
#  'endless',
#  'cigarshaped',
#  'doctor',
#  'rigor',
#  'shun',
#  'axiomatic',
#  'biocoenosis',
#  'quarterwave',
#  'qfts',
#  'matters',
#  'glows',
#  'illuminated',
#  'hefib',
#  'analysi',
#  'series',
#  'augustinlouis',
#  'dordrecht',
#  'mssmsrangle',
#  'budha',
#  'panish',
#  'semiotic',
#  'ptfrac',
#  'kawana',
#  'singleletter',
#  'ghostfield',
#  'apparent',
#  'thinfilms',
#  'littlestudied',
#  'methane',
#  'encyclopediacom',
#  'jha',
#  'kleftfrac',
#  'funeral',
#  'yhat',
#  'formcitation',
#  'aa',
#  'style',
#  'decision',
#  'dune',
#  'pretorius',
#  'hardy',
#  'scalar',
#  'unveiled',
#  'unveils',
#  'holds',
#  'serve',
#  'importantly',
#  'dimension',
#  'stellmer',
#  'dissension',
#  'opv',
#  'biochemistry',
#  'grant',
#  'harnessing',
#  'bicycles',
#  'lingle',
#  'methodsby',
#  'recoups',
#  'leptonic',
#  'jovians',
#  'otimes',
#  'portraits',
#  'peppercorn',
#  'zumino',
#  'pond',
#  'correspondingly',
#  'trg',
#  'sun—but',
#  'ripe',
#  'wake',
#  'lubick',
#  'highlighted',
#  'typesterrestrial',
#  'dgp',
#  'girl',
#  'duo',
#  'madumarov',
#  'bibcodeajg',
#  'bibcodepthphn',
#  'lisanti',
#  'jozef',
#  'praseodymium',
#  'went',
#  ...}

# %% [markdown]
# - ### Find the intersection of all_nobel_words and all_physics_words

# %%
physics_corpus =  all_nobel_words.intersection(all_physics_words)

physics_corpus
# Out:
# {'paved',
#  'proposal',
#  'released',
#  'wwwencyclopediacom',
#  'pbar',
#  'exact',
#  'mystic',
#  'thickness',
#  'element',
#  'aas',
#  'poisonous',
#  'ralph',
#  'oleary',
#  'distorted',
#  'aqueous',
#  'howard',
#  'society',
#  'reject',
#  'le',
#  'ramsey',
#  'students',
#  'liberated',
#  'jaguar',
#  'mother',
#  'wrinkles',
#  'kids',
#  'longest',
#  'europhysics',
#  'electrochemical',
#  'abelian',
#  'religious',
#  'natura',
#  'detroit',
#  'bibcodephrvk',
#  'unanticipated',
#  'enumerating',
#  'dem',
#  'nearer',
#  'thermostatic',
#  'cars',
#  'conducting',
#  'keeps',
#  'genes',
#  'intrigued',
#  'allied',
#  'stripped',
#  'dj',
#  'automaton',
#  'eta',
#  'harwood',
#  'manifest',
#  'cancellation',
#  'contain',
#  'stabilized',
#  'trend',
#  'installations',
#  'lists',
#  'anna',
#  'roger',
#  'superconductive',
#  'glasses',
#  'romanian',
#  'pearce',
#  'highquality',
#  'schopenhauer',
#  'donor',
#  'expertise',
#  'distortion',
#  'chu',
#  'congress',
#  'manmade',
#  'drawn',
#  'routes',
#  'distort',
#  'danby',
#  'alkali',
#  'orb',
#  'preferring',
#  'ring',
#  'microscope',
#  'bibcodenuphba',
#  'row',
#  'riess',
#  'arxivhepex',
#  'indexes',
#  'watts',
#  'www',
#  'chap',
#  'dirk',
#  'bibcodepar',
#  'doiphysrev',
#  'doses',
#  'peres',
#  'silicon',
#  'experimental',
#  'mauro',
#  'colourful',
#  'preserves',
#  'winery',
#  'neighbourhood',
#  'rocketry',
#  'copy',
#  'erik',
#  'rich',
#  'julia',
#  'mixtures',
#  'viability',
#  'hawkes',
#  'basil',
#  'thoughts',
#  'exterior',
#  'bacterial',
#  'tsukuba',
#  'orientation',
#  'boyle',
#  'indistinguishable',
#  'consumer',
#  'extrapolate',
#  'acs',
#  'packard',
#  'zeta',
#  'lifelong',
#  'lose',
#  'samples',
#  'masks',
#  'telephone',
#  'nikolay',
#  'security',
#  'facilitated',
#  'addison–wesley',
#  'healthy',
#  'classified',
#  'eigenvalues',
#  'maldacena',
#  'oconnor',
#  'hoop',
#  'naeye',
#  'dragon',
#  'lost',
#  'electronic',
#  'barely',
#  'interactionsorg',
#  'breakup',
#  'dubbed',
#  'gluon',
#  'jonathan',
#  'ruben',
#  'huffington',
#  'metal',
#  'zhao',
#  'postwar',
#  'another',
#  'bilayers',
#  'displacement',
#  'computation',
#  'donoghue',
#  'usual',
#  'humid',
#  'refers',
#  'thermodynamics',
#  'geographic',
#  'editor',
#  'einsteinium',
#  'mirror',
#  'dh',
#  'abbe',
#  'jewett',
#  'circuit',
#  'neighborhood',
#  'bibcodeapjss',
#  'lcd',
#  'metallurgy',
#  'powder',
#  'aware',
#  'holt',
#  'llewellyn',
#  'kamerlingh',
#  'modus',
#  'prolific',
#  'rubidium',
#  'abe',
#  'pillar',
#  'topdown',
#  'honoring',
#  'treatise',
#  'jarosik',
#  'recorder',
#  'settle',
#  'executive',
#  'electrolytic',
#  'janeiro',
#  'kidney',
#  'reluctant',
#  'clarendon',
#  'ionizing',
#  'observing',
#  'posing',
#  'significance',
#  'data',
#  'physicscitation',
#  'muhammad',
#  'bachelors',
#  'houston',
#  'halides',
#  'elsa',
#  'amateur',
#  'diracs',
#  'characterization',
#  'spacedivision',
#  'increase',
#  'respects',
#  'change',
#  'odd',
#  'observatoire',
#  'menlo',
#  'third',
#  'collaborating',
#  'validation',
#  'sina',
#  'translator',
#  'merged',
#  'clayton',
#  'driver',
#  'corrosion',
#  'schweber',
#  'stan',
#  'meticulously',
#  'differentiate',
#  'missiles',
#  'bibcodephrvh',
#  'cat',
#  'les',
#  'sironi',
#  'singular',
#  'rb',
#  'nix',
#  'till',
#  'probabilistic',
#  'consist',
#  'stateoftheart',
#  'dalibard',
#  'pmc',
#  'microphysical',
#  'garden',
#  'francisco',
#  'expeditions',
#  'singleparticle',
#  'pioneering',
#  'decreased',
#  'romania',
#  'daynight',
#  'fh',
#  'predicting',
#  'plate',
#  'media',
#  'passes',
#  'commerce',
#  'exactly',
#  'edward',
#  'mit',
#  'ntype',
#  'realized',
#  'methods',
#  'sternberg',
#  'aalto',
#  'joel',
#  'quasistellar',
#  'invisible',
#  'carbon',
#  'eht',
#  'discs',
#  'convection',
#  'comparable',
#  'spurious',
#  'review',
#  'abovementioned',
#  'constantly',
#  'canada',
#  'isbn',
#  'curie',
#  'immortality',
#  'necessitated',
#  'collapsed',
#  'highintensity',
#  'rice',
#  'hong',
#  'clinton',
#  'backgrounds',
#  'basic',
#  'civilisation',
#  'eleven',
#  'quarters',
#  'circulated',
#  'geophysical',
#  'alchemy',
#  'bibcodescia',
#  'max',
#  'synonymous',
#  'superheated',
#  'halpern',
#  'figures',
#  'ancient',
#  'liner',
#  'radiant',
#  'tv',
#  'says',
#  'abc',
#  'rotary',
#  'citationsedit',
#  'whipple',
#  'ignoring',
#  'olympus',
#  'acceptor',
#  'spectrograph',
#  'inferior',
#  'answered',
#  'prasad',
#  'psr',
#  'dangers',
#  'comptons',
#  'pour',
#  'ligo',
#  'largely',
#  'ironically',
#  'spectrometry',
#  'decided',
#  'janus',
#  'spencer',
#  'resting',
#  'ec',
#  'travels',
#  'column',
#  'disease',
#  'databases',
#  'acids',
#  'additional',
#  'asad',
#  'included',
#  'emergence',
#  'cyril',
#  'existing',
#  'weighing',
#  'equations',
#  'wie',
#  'affiliated',
#  'renaissance',
#  'rudolf',
#  'conversations',
#  'bibcodephrvm',
#  'norton',
#  'modelling',
#  'mans',
#  'urbana–champaign',
#  'prime',
#  'shadow',
#  'price',
#  'factors',
#  'pole',
#  'filtered',
#  'prolonged',
#  'jiang',
#  'versus',
#  'naturally',
#  'henryk',
#  'incompatible',
#  'versuch',
#  'steadily',
#  'sir',
#  'griffiths',
#  'arrive',
#  'twenty',
#  'jersey',
#  'revolutions',
#  'lm',
#  'isaac',
#  'lyon',
#  'integrated',
#  'richter',
#  'schilling',
#  'endeavors',
#  'famous',
#  'globally',
#  'addition',
#  'tullio',
#  'written',
#  'structural',
#  'orbit',
#  'xraysedit',
#  'wealth',
#  'owed',
#  'bombarded',
#  'decaying',
#  'institution',
#  'perhaps',
#  'effects',
#  'zinn',
#  'asaro',
#  'mr',
#  'thouless',
#  'erroneous',
#  'highlights',
#  'gary',
#  'localisation',
#  'boss',
#  'actively',
#  'pk',
#  'punishment',
#  'effectiveness',
#  'ny',
#  'brady',
#  'xie',
#  'easily',
#  'artist',
#  'lin',
#  'democracy',
#  'reported',
#  'nowadays',
#  'permitting',
#  'economical',
#  'ice',
#  'michelle',
#  'pohl',
#  'ida',
#  'oscillating',
#  'onedimensional',
#  'entertainment',
#  'schechter',
#  'catching',
#  'wavelike',
#  'illustris',
#  'seminar',
#  'stands',
#  'indium',
#  'reproduce',
#  'etc',
#  'underwater',
#  'summed',
#  'macmillan',
#  'ucl',
#  'notesedit',
#  'rogers',
#  'wife',
#  'prix',
#  'alike',
#  'rabi',
#  'elucidating',
#  'bar',
#  'adding',
#  'avec',
#  'disturb',
#  'schumacher',
#  'ellipsoidal',
#  'emits',
#  'sun',
#  'jhd',
#  'nuovo',
#  'arabic',
#  'influenced',
#  'italiana',
#  'indians',
#  'ultrasound',
#  'upright',
#  'abbott',
#  'environments',
#  'kohn',
#  'manual',
#  'processed',
#  'higgslike',
#  'cantor',
#  'winners',
#  'leadership',
#  'merzbacher',
#  'interviews',
#  'smooth',
#  'demanded',
#  'amount',
#  'nevertheless',
#  'fused',
#  'clay',
#  'uncovered',
#  'practically',
#  'currently',
#  'drove',
#  'eötvös',
#  'concluded',
#  'rebecca',
#  'spacetimes',
#  'billion',
#  'archaeology',
#  'predicted',
#  'prasanta',
#  'modifying',
#  'sinha',
#  'tripos',
#  'frances',
#  'citeseerx',
#  'antineutrinos',
#  'stacking',
#  'alloy',
#  'charles',
#  'wheel',
#  'société',
#  'runaway',
#  'inversely',
#  'realworld',
#  'vtebreakthrough',
#  'total',
#  'dear',
#  'thomsons',
#  'arranging',
#  'rodgers',
#  'lh',
#  'reviewing',
#  'hanford',
#  'covering',
#  'doctrines',
#  'slowed',
#  'steigman',
#  'mm',
#  'brink',
#  'cooperation',
#  'lesson',
#  'penetrating',
#  'dissociation',
#  'printed',
#  'scheduled',
#  'franz',
#  'brigham',
#  'newer',
#  'goudsmit',
#  'manfred',
#  'automobile',
#  'submerged',
#  'organisations',
#  'rolls',
#  'voices',
#  'founders',
#  'magnetometers',
#  'pulsar',
#  'things',
#  'secrets',
#  'colors',
#  'reuters',
#  'sword',
#  'existed',
#  'volta',
#  'petermann',
#  'liberty',
#  'antinuclear',
#  'temporal',
#  'radar',
#  'bibcoderspsac',
#  'contracts',
#  'rectifiers',
#  'vte',
#  'domes',
#  'facility',
#  'clarity',
#  'terence',
#  'ulysses',
#  'nicola',
#  'derivation',
#  'cole',
#  'transl',
#  'weapon',
#  'modell',
#  'frederick',
#  'altogether',
#  'megan',
#  'insurmountable',
#  'strip',
#  'josephson',
#  'qualified',
#  'gérard',
#  'back',
#  'accelerator',
#  'may',
#  'colorado',
#  'faded',
#  'hollow',
#  'lars',
#  'kl',
#  'hardware',
#  'larson',
#  'carnap',
#  'henning',
#  'excimer',
#  'moved',
#  'collingridge',
#  'order',
#  'sergeevich',
#  'relations',
#  'helix',
#  'speaks',
#  'injustice',
#  'rajiv',
#  'october',
#  'lyons',
#  'worlds',
#  'opens',
#  'scully',
#  'unsuccessful',
#  'laurent',
#  'robson',
#  'referencesedit',
#  'interiors',
#  'invested',
#  'word',
#  'consider',
#  'cartlidge',
#  'karl',
#  'portalphysics',
#  'disappearance',
#  'ads',
#  'award',
#  'recast',
#  'discrimination',
#  'mars',
#  'jia',
#  'mie',
#  'materie',
#  'armstrong',
#  'recognized',
#  'polarized',
#  'refute',
#  'doibf',
#  'defect',
#  'atlanta',
#  'discern',
#  'taken',
#  'signal',
#  'grating',
#  'protein',
#  'prussian',
#  'impressions',
#  'move',
#  'oxford',
#  'plutonium',
#  'néel',
#  'annihilation',
#  'meyers',
#  'felix',
#  'interview',
#  'émises',
#  'timeofflight',
#  'lightedit',
#  'phillip',
#  'faced',
#  'rd',
#  'cleared',
#  'paulis',
#  'electronically',
#  'golf',
#  'books',
#  'hundred',
#  'orchiston',
#  'curved',
#  'trivedi',
#  'fiveyear',
#  'erda',
#  'novette',
#  'acr',
#  'swiss',
#  'bizarre',
#  'manganese',
#  'alaska',
#  'bc',
#  'fluids',
#  'confused',
#  'year',
#  'independent',
#  'virtual',
#  'ignacio',
#  'along',
#  'arecibo',
#  'area',
#  'gasoline',
#  'walton',
#  'fin',
#  'good',
#  'sb',
#  'entire',
#  'lab',
#  'oskar',
#  'siliconbased',
#  'perl',
#  'wen',
#  'didier',
#  'suitable',
#  'mechanics',
#  'increasingly',
#  'unleash',
#  'preparations',
#  'connections',
#  'doc',
#  'assurance',
#  'unrelated',
#  'ottawa',
#  'maxwell–boltzmann',
#  'snolab',
#  'exploration',
#  'bromberg',
#  'martins',
#  'esslinger',
#  'gsfc',
#  'bremsstrahlung',
#  'ulaby',
#  'views',
#  'outcome',
#  'exhibited',
#  'stellar',
#  'projected',
#  'receding',
#  'francesco',
#  'sullivan',
#  'irradiation',
#  'renowned',
#  'roots',
#  'physical',
#  'division',
#  'scholarpedia',
#  'telescopic',
#  'undiscovered',
#  'topological',
#  'fj',
#  'powerful',
#  'transactions',
#  'eruptions',
#  'contrary',
#  'plotting',
#  'jpl',
#  'chapman',
#  'feltrinelli',
#  'northern',
#  'ammonia',
#  'bull',
#  'laureates',
#  'inert',
#  'attributable',
#  'parallax',
#  'sul',
#  'luna',
#  'flying',
#  'stark',
#  'watchmaker',
#  'movies',
#  'articles',
#  'persisting',
#  'cylinder',
#  'antigravity',
#  'uniformity',
#  'inb',
#  'della',
#  'urs',
#  'groves',
#  'keys',
#  'seen',
#  'singh',
#  'reserve',
#  'nasas',
#  'transistor',
#  'einer',
#  'lorentzian',
#  'libraries',
#  'quantum',
#  'hayes',
#  'companies',
#  'tang',
#  'injury',
#  'ionosphere',
#  'junctions',
#  'jp',
#  'purely',
#  'followed',
#  'positions',
#  'deep',
#  'farms',
#  'facilitate',
#  'distance',
#  'waltham',
#  'importance',
#  'woodrow',
#  'bibcodervmpsw',
#  'strict',
#  'wikiproject',
#  'prolong',
#  'handled',
#  'healthcare',
#  'associate',
#  'speck',
#  'criticality',
#  'excitation',
#  'passing',
#  'observatory',
#  'tidal',
#  'wineland',
#  'outstanding',
#  'powell',
#  'trade',
#  'lineofsight',
#  'founded',
#  'equivalent',
#  'colours',
#  'conrad',
#  'hartree',
#  'blauert',
#  'journalist',
#  'hale',
#  'limiting',
#  'nf',
#  'universität',
#  'instrumental',
#  'speeding',
#  'priorities',
#  'sparking',
#  'bohr–van',
#  'fruit',
#  'pencil',
#  'strike',
#  'woldemar',
#  'transportation',
#  'escaped',
#  'gamows',
#  'contacts',
#  'dispute',
#  'start',
#  'photodiodes',
#  'dated',
#  'utrecht',
#  'sc',
#  'bibliographyedit',
#  'wherein',
#  'ceramic',
#  'technicolor',
#  'unwanted',
#  'obviously',
#  'mattuck',
#  'render',
#  'paget',
#  'polar',
#  'bounded',
#  'almost',
#  'rouse',
#  'highly',
#  'form',
#  'transferred',
#  'neal',
#  'morozov',
#  'subway',
#  'ge',
#  'freefalling',
#  'obtaining',
#  'residency',
#  'economic',
#  'organized',
#  'photons',
#  'anonymous',
#  'highredshift',
#  'predominantly',
#  'llc',
#  'puts',
#  'agreement',
#  'gerhard',
#  'railways',
#  'hänsch',
#  'determinations',
#  'spanned',
#  'diane',
#  'mounting',
#  'postage',
#  'confirmations',
#  'insulators',
#  'circuits',
#  'ferro',
#  'accorded',
#  'regularly',
#  'appearing',
#  'gold',
#  'binding',
#  'cofounded',
#  'carolina',
#  'utilizing',
#  'everett',
#  'occurrences',
#  'remote',
#  'bibcodephlbp',
#  'assisted',
#  'polynomials',
#  'teilchen',
#  'presents',
#  'little',
#  'harris',
#  'disappearing',
#  'broadway',
#  'blurred',
#  'jet',
#  'trillion',
#  'rosse',
#  'condensates',
#  'cause',
#  'solidstate',
#  'yu',
#  'au',
#  'every',
#  'residues',
#  'conveyed',
#  'inharmonicity',
#  'ehnu',
#  'eddy',
#  'marder',
#  'users',
#  'full',
#  'empirical',
#  'simpson',
#  'williamson',
#  'dummies',
#  'flavors',
#  'collect',
#  'holliday',
#  'candidate',
#  'quickly',
#  'angeles',
#  'radiography',
#  'possibility',
#  'cart',
#  'bombardment',
#  'pieces',
#  'compressibility',
#  'wärme',
#  'reasons',
#  'filed',
#  'loose',
#  'li',
#  'lemaître',
#  'interplay',
#  'oup',
#  'desy',
#  'albrecht',
#  'tales',
#  'electrification',
#  'optimistic',
#  'particulates',
#  'martian',
#  'viatcheslav',
#  'high',
#  'multimode',
#  'bibcodeanphyc',
#  'energy',
#  'wisdom',
#  'euclidean',
#  'calm',
#  'located',
#  'ambiguous',
#  'islands',
#  'prevented',
#  'carlton',
#  'legislative',
#  'manner',
#  'wavefunction',
#  'johan',
#  'elegant',
#  'pneumatic',
#  'gu',
#  'alwyn',
#  'helmholtzs',
#  'fr',
#  'penney',
#  'derek',
#  'fly',
#  'indirectly',
#  'ultra',
#  'metrology',
#  'temple',
#  'charless',
#  'encyclopædia',
#  'apparatus',
#  'nauk',
#  'jhu',
#  'douglas',
#  'luciano',
#  'reliably',
#  'maybritt',
#  'religions',
#  'diagnostics',
#  'khalatnikov',
#  'inverse',
#  'duality',
#  'lends',
#  'younger',
#  'whereby',
#  'proportion',
#  'rundle',
#  'freedom',
#  'origine',
#  'constitutes',
#  'exclusion',
#  'short',
#  'smart',
#  'sound',
#  'connects',
#  ...}

# %%
print(len(physics_corpus), len(all_nobel_words), len(all_physics_words))
# Out:
# 12935 33378 34722

# %% [markdown]
# So the unique words from the physicist pages total 33,378.
# The unique words from the physics domain pages totals 34,722.
# The unique words they share in common is 12,935. A little more than a third of the total words in either.
#
# For every entry in the "physics_list" for both nobel_df and physics_df, we are going to keep only those words in the intersection (physics_corpus, as defined above). We will store these in a new column in our dataframes, "physics_list_clean".
#
# - ### Keep only words in physics corpus.

# %%
def keep_only(list_to_clean, corpus=physics_corpus):
    return [word for word in list_to_clean if word in corpus]
    
nobel_df["physics_list_clean"] = nobel_df["physics_list"].apply(keep_only)
physics_df["physics_list_clean"] = physics_df["physics_list"].apply(keep_only)
nobel_df
# Out:
#                                                                           link  \
# Laureate
# Wilhelm Conrad Röntgen                              /wiki/Wilhelm_R%C3%B6ntgen
# Hendrik Lorentz                                          /wiki/Hendrik_Lorentz
# Pieter Zeeman                                              /wiki/Pieter_Zeeman
# Antoine Henri Becquerel                                  /wiki/Henri_Becquerel
# Pierre Curie                                                /wiki/Pierre_Curie
# Maria Skłodowska-Curie                       /wiki/Maria_Sk%C5%82odowska-Curie
# Lord Rayleigh                    /wiki/John_William_Strutt,_3rd_Baron_Rayleigh
# Philipp Eduard Anton von Lenard                           /wiki/Philipp_Lenard
# Joseph John Thomson                                        /wiki/J._J._Thomson
# Albert Abraham Michelson                             /wiki/Albert_A._Michelson
# Gabriel Lippmann                                        /wiki/Gabriel_Lippmann
# Guglielmo Marconi                                      /wiki/Guglielmo_Marconi
# Karl Ferdinand Braun                                /wiki/Karl_Ferdinand_Braun
# Johannes Diderik van der Waals            /wiki/Johannes_Diderik_van_der_Waals
# Wilhelm Wien                                                /wiki/Wilhelm_Wien
# Nils Gustaf Dalén                                      /wiki/Gustaf_Dal%C3%A9n
# Heike Kamerlingh-Onnes                            /wiki/Heike_Kamerlingh_Onnes
# Max von Laue                                                /wiki/Max_von_Laue
# William Henry Bragg                                  /wiki/William_Henry_Bragg
# William Lawrence Bragg                                    /wiki/Lawrence_Bragg
# Charles Glover Barkla                              /wiki/Charles_Glover_Barkla
# Guglielmo Marconi                [marconi, redirects, uses, see, marconi, disam...
# Karl Ferdinand Braun             [german, politician, writer, see, karl, braun,...
# Johannes Diderik van der Waals   [uses, see, van, der, waals, disambiguation, j...
# Wilhelm Wien                     [wilhelm, wien, born, wilhelm, carl, werner, o...
# Nils Gustaf Dalén                [gustaf, dalén, born, nils, gustaf, dalén, nov...
# Heike Kamerlingh-Onnes           [heike, kamerlingh, onnes, born, heike, kamerl...
# Max von Laue                     [max, von, laue, laue, born, max, theodor, fel...
# William Henry Bragg              [confused, son, fellow, nobel, prize, winner, ...
# William Lawrence Bragg           [article, australian, born, physicist, father,...
# Charles Glover Barkla            [barkla, redirects, lunar, crater, see, barkla...
# Max Planck                       [planck, redirects, uses, see, planck, disambi...
# Johannes Stark                   [article, needs, additional, citations, verifi...
# Charles Édouard Guillaume        [charles, édouard, guillaume, born, february, ...
# Albert Einstein                  [einstein, redirects, musicologist, see, alfre...
# Niels Bohr                       [bohr, redirects, uses, see, bohr, disambiguat...
# Robert Andrews Millikan          [confused, robert, mulliken, robert, millikan,...
# Manne Siegbahn                   [manne, siegbahn, karl, manne, siegbahn, born,...
# James Franck                     [james, franck, born, august, hamburg, german,...
# Gustav Hertz                     [gustav, ludwig, hertz, hertz, born, july, fre...
# ...                                                                            ...
# John C. Mather                   [people, similar, names, see, john, mather, jo...
# George F. Smoot                  [george, smoot, george, smoot, povo, conferenc...
# Albert Fert                      [albert, fert, born, march, age, carcassonne, ...
# Peter Grünberg                   [peter, grünberg, grünberg, born, peter, andre...
# Makoto Kobayashi                 [小林, makoto, kobayashi, kobayashi, born, april...
# Toshihide Maskawa                [益川, 敏英, toshihide, maskawa, maskawa, born, fe...
# Yoichiro Nambu                   [yoichiro, nambu南部, 陽一郎, nambu, born, january,...
# Charles K. Kao                   [honourablesir, charles, kuen, kaogbm, kbe, fr...
# Willard S. Boyle                 [willard, boyle, boyle, born, august, amherst,...
# George E. Smith                  [article, american, physicist, american, polit...
# Andre Geim                       [sir, andre, geim, geim, born, andrei, konstan...
# Konstantin Novoselov             [name, uses, eastern, slavic, naming, customs,...
# Saul Perlmutter                  [saul, perlmutter, saul, perlmutter, nobel, we...
# Brian P. Schmidt                 [article, astrophysicist, music, composer, see...
# Adam G. Riess                    [adam, riess, riess, born, adam, guy, riess, d...
# Serge Haroche                    [serge, haroche, serge, haroche, stockholm, bo...
# David J. Wineland                [david, wineland, david, wineland, born, david...
# François Englert                 [françois, englert, françois, englert, born, n...
# Peter Higgs                      [british, physicist, peter, higgsch, frs, frse...
# Isamu Akasaki                    [biography, living, person, needs, additional,...
# Hiroshi Amano                    [uses, see, brave, fighter, sun, fighbird, cha...
# Shuji Nakamura                   [shuji, nakamura, shuji, nakamura, native, nam...
# Takaaki Kajita                   [takaaki, kajita, takaaki, kajita, nobel, laur...
# Arthur B. McDonald               [arthur, mcdonaldcc, oont, ons, frs, frsc, art...
# David J. Thouless                [david, thoulessfrs, david, thouless, born, da...
# F. Duncan M. Haldane             [duncan, haldane, duncan, haldane, nobel, pres...
# John M. Kosterlitz               [michael, kosterlitz, born, john, michael, kos...
# Rainer Weiss                     [rainer, weiss, weiss, june, born, september, ...
# Kip Thorne                       [kip, thorne, thorne, august, born, kip, steph...
# Barry Barish                     [article, needs, additional, citations, verifi...
#
#                                                                 physics_list_clean
# Laureate
# Wilhelm Conrad Röntgen           [wilhelm, röntgen, born, wilhelm, conrad, rönt...
# Hendrik Lorentz                  [confused, lorentz, lorenz, see, also, lorentz...
# Pieter Zeeman                    [pieter, zeeman, born, may, october, amsterdam...
# Antoine Henri Becquerel          [uses, see, becquerel, disambiguation, henri, ...
# Pierre Curie                     [pierre, curie, pierre, curie, born, may, pari...
# Maria Skłodowska-Curie           [article, physicist, uses, see, marie, curie, ...
# Lord Rayleigh                    [lord, born, november, langford, june, place, ...
# Philipp Eduard Anton von Lenard  [effect, redirects, visual, motion, effect, se...
# Joseph John Thomson              [article, nobel, laureate, physicist, moral, p...
# Albert Abraham Michelson         [confused, albert, albert, michelson, born, de...
# Gabriel Lippmann                 [gabriel, born, ferdinand, gabriel, august, si...
# Guglielmo Marconi                [redirects, uses, see, disambiguation, born, g...
# Karl Ferdinand Braun             [german, see, karl, braun, karl, ferdinand, br...
# Johannes Diderik van der Waals   [uses, see, van, der, waals, disambiguation, j...
# Wilhelm Wien                     [wilhelm, wien, born, wilhelm, carl, werner, o...
# Nils Gustaf Dalén                [born, november, december, stockholm, mater, c...
# Heike Kamerlingh-Onnes           [heike, kamerlingh, onnes, born, heike, kamerl...
# Max von Laue                     [max, von, laue, laue, born, max, theodor, fel...
# William Henry Bragg              [confused, son, fellow, nobel, prize, winner, ...
# William Lawrence Bragg           [article, australian, born, physicist, father,...
# Charles Glover Barkla            [redirects, lunar, crater, see, crater, charle...
# Max Planck                       [planck, redirects, uses, see, planck, disambi...
# Johannes Stark                   [article, needs, additional, citations, verifi...
# Charles Édouard Guillaume        [charles, édouard, guillaume, born, february, ...
# Albert Einstein                  [einstein, redirects, see, alfred, einstein, p...
# Niels Bohr                       [bohr, redirects, uses, see, bohr, disambiguat...
# Robert Andrews Millikan          [confused, robert, mulliken, robert, millikan,...
# Manne Siegbahn                   [karl, born, karl, georg, december, september,...
# James Franck                     [james, franck, born, august, hamburg, german,...
# Gustav Hertz                     [gustav, ludwig, hertz, hertz, born, july, fre...
# ...                                                                            ...
# John C. Mather                   [people, similar, names, see, john, mather, jo...
# George F. Smoot                  [george, smoot, george, smoot, conference, geo...
# Albert Fert                      [albert, fert, born, march, age, paris, mater,...
# Peter Grünberg                   [peter, grünberg, grünberg, born, peter, andre...
# Makoto Kobayashi                 [makoto, kobayashi, kobayashi, born, april, ag...
# Toshihide Maskawa                [toshihide, maskawa, maskawa, born, february, ...
# Yoichiro Nambu                   [yoichiro, nambu, born, january, tokyo, july, ...
# Charles K. Kao                   [charles, frs, charles, receiving, degree, pri...
# Willard S. Boyle                 [willard, boyle, boyle, born, august, amherst,...
# George E. Smith                  [article, american, physicist, american, see, ...
# Andre Geim                       [sir, andre, born, andrei, russian, october, a...
# Konstantin Novoselov             [name, uses, eastern, naming, sergeevich, fami...
# Saul Perlmutter                  [saul, perlmutter, saul, perlmutter, nobel, we...
# Brian P. Schmidt                 [article, astrophysicist, music, see, brian, s...
# Adam G. Riess                    [adam, riess, riess, born, adam, guy, riess, d...
# Serge Haroche                    [serge, haroche, serge, haroche, stockholm, bo...
# David J. Wineland                [david, wineland, david, wineland, born, david...
# François Englert                 [françois, englert, françois, englert, born, n...
# Peter Higgs                      [british, physicist, peter, frs, nobel, laurea...
# Isamu Akasaki                    [biography, living, person, needs, additional,...
# Hiroshi Amano                    [uses, see, sun, characters, september, age, m...
# Shuji Nakamura                   [nakamura, nakamura, native, name, may, age, u...
# Takaaki Kajita                   [takaaki, kajita, takaaki, kajita, nobel, laur...
# Arthur B. McDonald               [arthur, frs, arthur, mcdonald, stockholm, dec...
# David J. Thouless                [david, david, thouless, born, david, james, t...
# F. Duncan M. Haldane             [duncan, haldane, duncan, haldane, nobel, pres...
# John M. Kosterlitz               [michael, kosterlitz, born, john, michael, kos...
# Rainer Weiss                     [rainer, weiss, weiss, june, born, september, ...
# Kip Thorne                       [kip, thorne, thorne, august, born, kip, steph...
# Barry Barish                     [article, needs, additional, citations, verifi...
#
# [206 rows x 3 columns]

# %% [markdown]
# Next, we gather the information that we really want: The number of words in each Wikipedia entry that are in the physics corpus, and store them in a new column in both dataframes (the column is named "length").
#
# - ### Compute the length of each list

# %%
nobel_df["length"] =  nobel_df["physics_list_clean"].apply(len)
physics_df["length"] = physics_df["physics_list_clean"].apply(len)

# %% [markdown]
# Lastly, we are eventually going to keep all this information in a single dataframe. However, we still want to identify which entries are physicists, and which are physics domains. So we create a new column, named "group", in both dataframes. Entries in nobel_df receive a value of 1 for "group", while those in physics_df are set to 0.
#
# - ### Create "group" column: 1 for nobel_df, 0 for physics_df

# %%
nobel_df["group"] =  1

# %%
physics_df["group"] =  0

# %% [markdown]
# Now that we have essentialy all the information we need, we simply need to put it into the right format. Recall that a social network consists of nodes and links connecting those nodes. Specifically, we are going to create a list containing the nodes (nodes_list), and a df containing the links (links_list). For now, we will focus on creating the nodes_list.
#
# ## Create nodes_list
#
# nodes_list: A list of dictionaries, each containing a physics domain/physicist, the length of their Wikipedia entry (specifically, how many words in their entry were also in physics_corpus), and their group (0 if it is a physics domain, 1 if it is a physicist).
#
# First, let's get the relevant info for all the physicists and physics domains into one dataframe.
#
# - ### Concatenate phsycics_df and nobel_df to form nodes_df

# %%
nodes_df =  pd.concat([physics_df, nobel_df])[['length','group']]

nodes_df.index.name = "id"
nodes_df
# Out:
#                                         length  group
# id
# accelerator physics                        866      0
# acoustics                                 2072      0
# agrophysics                                398      0
# antimatter                                3532      0
# applied physics                            289      0
# astrometry                                1151      0
# astronomy                                 5207      0
# astrophysics                              1859      0
# atom                                      6633      0
# atomic and molecular astrophysics          471      0
# atomic physics                             964      0
# atomic, molecular, and optical physics    1870      0
# bcs theory                                1362      0
# big bang                                  6932      0
# biophysics                                1074      0
# black hole                                8355      0
# bloch wave                                 839      0
# bose-einstein condensate                  3494      0
# brane                                      105      0
# casimir effect                            3105      0
# chemical physics                           496      0
# communication physics                      259      0
# condensed matter physics                  3486      0
# cosmic background radiation                517      0
# cosmic inflation                          6381      0
# cosmic string                             1610      0
# cosmology                                 4294      0
# cosmos                                     769      0
# dark energy                               4323      0
# dark matter                               6844      0
# ...                                        ...    ...
# John C. Mather                            1180      1
# George F. Smoot                           1679      1
# Albert Fert                                709      1
# Peter Grünberg                             879      1
# Makoto Kobayashi                           675      1
# Toshihide Maskawa                          609      1
# Yoichiro Nambu                            1636      1
# Charles K. Kao                            4088      1
# Willard S. Boyle                           709      1
# George E. Smith                            544      1
# Andre Geim                                2205      1
# Konstantin Novoselov                      1446      1
# Saul Perlmutter                           1388      1
# Brian P. Schmidt                          2385      1
# Adam G. Riess                             1221      1
# Serge Haroche                              865      1
# David J. Wineland                         1481      1
# François Englert                          1130      1
# Peter Higgs                               2496      1
# Isamu Akasaki                             1277      1
# Hiroshi Amano                              594      1
# Shuji Nakamura                             947      1
# Takaaki Kajita                            1006      1
# Arthur B. McDonald                        1166      1
# David J. Thouless                          934      1
# F. Duncan M. Haldane                       813      1
# John M. Kosterlitz                         621      1
# Rainer Weiss                              1859      1
# Kip Thorne                                2851      1
# Barry Barish                              1466      1
#
# [339 rows x 2 columns]

# %% [markdown]
# Since we are using the D3.js library, we must properly format as a list of dictionaries. Each dictionary will contain the group, length, and name of the physicist/physics domain (as 'id').
#
# - ### Convert nodes_df to list of dictionaries

# %%
nodes_list = list(nodes_df.reset_index().transpose().to_dict().values())
nodes_list
# Out:
# [{'group': 0, 'id': 'accelerator physics', 'length': 866},
#  {'group': 0, 'id': 'acoustics', 'length': 2072},
#  {'group': 0, 'id': 'agrophysics', 'length': 398},
#  {'group': 0, 'id': 'antimatter', 'length': 3532},
#  {'group': 0, 'id': 'applied physics', 'length': 289},
#  {'group': 0, 'id': 'astrometry', 'length': 1151},
#  {'group': 0, 'id': 'astronomy', 'length': 5207},
#  {'group': 0, 'id': 'astrophysics', 'length': 1859},
#  {'group': 0, 'id': 'atom', 'length': 6633},
#  {'group': 0, 'id': 'atomic and molecular astrophysics', 'length': 471},
#  {'group': 0, 'id': 'atomic physics', 'length': 964},
#  {'group': 0, 'id': 'atomic, molecular, and optical physics', 'length': 1870},
#  {'group': 0, 'id': 'bcs theory', 'length': 1362},
#  {'group': 0, 'id': 'big bang', 'length': 6932},
#  {'group': 0, 'id': 'biophysics', 'length': 1074},
#  {'group': 0, 'id': 'black hole', 'length': 8355},
#  {'group': 0, 'id': 'bloch wave', 'length': 839},
#  {'group': 0, 'id': 'bose-einstein condensate', 'length': 3494},
#  {'group': 0, 'id': 'brane', 'length': 105},
#  {'group': 0, 'id': 'casimir effect', 'length': 3105},
#  {'group': 0, 'id': 'chemical physics', 'length': 496},
#  {'group': 0, 'id': 'communication physics', 'length': 259},
#  {'group': 0, 'id': 'condensed matter physics', 'length': 3486},
#  {'group': 0, 'id': 'cosmic background radiation', 'length': 517},
#  {'group': 0, 'id': 'cosmic inflation', 'length': 6381},
#  {'group': 0, 'id': 'cosmic string', 'length': 1610},
#  {'group': 0, 'id': 'cosmology', 'length': 4294},
#  {'group': 0, 'id': 'cosmos', 'length': 769},
#  {'group': 0, 'id': 'dark energy', 'length': 4323},
#  {'group': 0, 'id': 'dark matter', 'length': 6844},
#  {'group': 0, 'id': 'density functional theory', 'length': 2626},
#  {'group': 0, 'id': 'diffraction', 'length': 2684},
#  {'group': 0, 'id': 'econophysics', 'length': 1767},
#  {'group': 0, 'id': 'effective field theory', 'length': 868},
#  {'group': 0, 'id': 'electrical conduction', 'length': 3105},
#  {'group': 0, 'id': 'electromagnetic', 'length': 3151},
#  {'group': 0, 'id': 'electromagnetic radiation', 'length': 5746},
#  {'group': 0, 'id': 'electroweak theory', 'length': 1004},
#  {'group': 0, 'id': 'elementary particle', 'length': 2231},
#  {'group': 0, 'id': 'engineering physics', 'length': 845},
#  {'group': 0, 'id': 'fermi gas', 'length': 1536},
#  {'group': 0, 'id': 'fermi liquid', 'length': 1344},
#  {'group': 0, 'id': 'fluid dynamics', 'length': 2824},
#  {'group': 0, 'id': 'fundamental force', 'length': 2592},
#  {'group': 0, 'id': 'galaxy', 'length': 5593},
#  {'group': 0, 'id': 'gas', 'length': 3206},
#  {'group': 0, 'id': 'gauge theory', 'length': 3375},
#  {'group': 0, 'id': 'general relativity', 'length': 11305},
#  {'group': 0, 'id': 'geophysics', 'length': 2540},
#  {'group': 0, 'id': 'grand unification theory', 'length': 2167},
#  {'group': 0, 'id': 'gravitation physics', 'length': 3381},
#  {'group': 0, 'id': 'gravitational', 'length': 3381},
#  {'group': 0, 'id': 'gravitational radiation', 'length': 6136},
#  {'group': 0, 'id': 'gravitational singularity', 'length': 1569},
#  {'group': 0, 'id': 'gravity', 'length': 3381},
#  {'group': 0, 'id': 'high pressure physics', 'length': 262},
#  {'group': 0, 'id': 'high-energy astrophysics', 'length': 183},
#  {'group': 0, 'id': 'lambda-cdm model', 'length': 109},
#  {'group': 0, 'id': 'laser', 'length': 6506},
#  {'group': 0, 'id': 'laser physics', 'length': 533},
#  {'group': 0, 'id': 'lattice field theory', 'length': 160},
#  {'group': 0, 'id': 'lattice gauge theory', 'length': 792},
#  {'group': 0, 'id': 'liquid', 'length': 2041},
#  {'group': 0, 'id': 'low-temperature physics', 'length': 1050},
#  {'group': 0, 'id': 'm-theory', 'length': 4073},
#  {'group': 0, 'id': 'magnetism', 'length': 2952},
#  {'group': 0, 'id': 'magnetohydrodynamics', 'length': 2885},
#  {'group': 0, 'id': 'many-body theory', 'length': 91},
#  {'group': 0, 'id': 'materials physics', 'length': 3642},
#  {'group': 0, 'id': 'medical physics', 'length': 1392},
#  {'group': 0, 'id': 'molecular physics', 'length': 234},
#  {'group': 0, 'id': 'molecule', 'length': 1818},
#  {'group': 0, 'id': 'nanoscale and mesoscopic physics', 'length': 4417},
#  {'group': 0, 'id': 'nanotechnology', 'length': 4417},
#  {'group': 0, 'id': 'neutrino oscillation', 'length': 3049},
#  {'group': 0, 'id': "newton's law of universal gravitation", 'length': 3166},
#  {'group': 0, 'id': 'nuclear', 'length': 2413},
#  {'group': 0, 'id': 'nuclear astrophysics', 'length': 955},
#  {'group': 0, 'id': 'nuclear physics', 'length': 2413},
#  {'group': 0, 'id': 'optics', 'length': 6742},
#  {'group': 0, 'id': 'optoelectronics', 'length': 206},
#  {'group': 0, 'id': 'particle astrophysics', 'length': 920},
#  {'group': 0, 'id': 'particle physics', 'length': 2572},
#  {'group': 0, 'id': 'particle physics phenomenology', 'length': 314},
#  {'group': 0, 'id': 'phases', 'length': 1026},
#  {'group': 0, 'id': 'phonon', 'length': 2363},
#  {'group': 0, 'id': 'photon', 'length': 6027},
#  {'group': 0, 'id': 'photonics', 'length': 1479},
#  {'group': 0, 'id': 'photovoltaics', 'length': 6211},
#  {'group': 0, 'id': 'physical chemistry', 'length': 1091},
#  {'group': 0, 'id': 'physics of computation', 'length': 71},
#  {'group': 0, 'id': 'planet', 'length': 6506},
#  {'group': 0, 'id': 'planetary astrophysics', 'length': 1913},
#  {'group': 0, 'id': 'plasma physics', 'length': 4519},
#  {'group': 0, 'id': 'polarization (waves)', 'length': 4860},
#  {'group': 0, 'id': 'polymer physics', 'length': 1472},
#  {'group': 0, 'id': 'quantum chemistry', 'length': 1628},
#  {'group': 0, 'id': 'quantum chromodynamics', 'length': 3133},
#  {'group': 0, 'id': 'quantum electrodynamics', 'length': 3217},
#  {'group': 0, 'id': 'quantum electronics', 'length': 1345},
#  {'group': 0, 'id': 'quantum field theory', 'length': 6957},
#  {'group': 0, 'id': 'quantum gravity', 'length': 3702},
#  {'group': 0, 'id': 'quantum information science', 'length': 981},
#  {'group': 0, 'id': 'quantum optics', 'length': 1345},
#  {'group': 0, 'id': 'seesaw mechanism', 'length': 480},
#  {'group': 0, 'id': 'self-organization', 'length': 2756},
#  {'group': 0, 'id': 'semiconductor', 'length': 2582},
#  {'group': 0, 'id': 'solar physics', 'length': 934},
#  {'group': 0, 'id': 'solar system', 'length': 6433},
#  {'group': 0, 'id': 'solid', 'length': 2917},
#  {'group': 0, 'id': 'solid state physics', 'length': 768},
#  {'group': 0, 'id': 'solid-state devices', 'length': 768},
#  {'group': 0, 'id': 'space physics', 'length': 448},
#  {'group': 0, 'id': 'spectral line', 'length': 1305},
#  {'group': 0, 'id': 'spin', 'length': 3305},
#  {'group': 0, 'id': 'spontaneous symmetry breaking', 'length': 2119},
#  {'group': 0, 'id': 'standard model', 'length': 3379},
#  {'group': 0, 'id': 'star', 'length': 7689},
#  {'group': 0, 'id': 'statistical mechanics', 'length': 2530},
#  {'group': 0, 'id': 'stellar astrophysics', 'length': 5207},
#  {'group': 0, 'id': 'string', 'length': 446},
#  {'group': 0, 'id': 'strong', 'length': 1471},
#  {'group': 0, 'id': 'superconductor', 'length': 3350},
#  {'group': 0, 'id': 'superfluid', 'length': 1033},
#  {'group': 0, 'id': 'supernova', 'length': 7738},
#  {'group': 0, 'id': 'superstring theory', 'length': 1874},
#  {'group': 0, 'id': 'supersymmetry', 'length': 3322},
#  {'group': 0, 'id': 'surface physics', 'length': 1133},
#  {'group': 0, 'id': 'theory of everything', 'length': 4038},
#  {'group': 0, 'id': 'universe', 'length': 7538},
#  {'group': 0, 'id': 'vacuum energy', 'length': 1163},
#  {'group': 0, 'id': 'vehicle dynamics', 'length': 564},
#  {'group': 0, 'id': 'weak', 'length': 1992},
#  {'group': 1, 'id': 'Wilhelm Conrad Röntgen', 'length': 1360},
#  {'group': 1, 'id': 'Hendrik Lorentz', 'length': 2890},
#  {'group': 1, 'id': 'Pieter Zeeman', 'length': 999},
#  {'group': 1, 'id': 'Antoine Henri Becquerel', 'length': 1390},
#  {'group': 1, 'id': 'Pierre Curie', 'length': 1502},
#  {'group': 1, 'id': 'Maria Skłodowska-Curie', 'length': 5040},
#  {'group': 1, 'id': 'Lord Rayleigh', 'length': 1508},
#  {'group': 1, 'id': 'Philipp Eduard Anton von Lenard', 'length': 1236},
#  {'group': 1, 'id': 'Joseph John Thomson', 'length': 2882},
#  {'group': 1, 'id': 'Albert Abraham Michelson', 'length': 2455},
#  {'group': 1, 'id': 'Gabriel Lippmann', 'length': 1455},
#  {'group': 1, 'id': 'Guglielmo Marconi', 'length': 4093},
#  {'group': 1, 'id': 'Karl Ferdinand Braun', 'length': 820},
#  {'group': 1, 'id': 'Johannes Diderik van der Waals', 'length': 2144},
#  {'group': 1, 'id': 'Wilhelm Wien', 'length': 772},
#  {'group': 1, 'id': 'Nils Gustaf Dalén', 'length': 753},
#  {'group': 1, 'id': 'Heike Kamerlingh-Onnes', 'length': 1121},
#  {'group': 1, 'id': 'Max von Laue', 'length': 2367},
#  {'group': 1, 'id': 'William Henry Bragg', 'length': 1977},
#  {'group': 1, 'id': 'William Lawrence Bragg', 'length': 2087},
#  {'group': 1, 'id': 'Charles Glover Barkla', 'length': 518},
#  {'group': 1, 'id': 'Max Planck', 'length': 3195},
#  {'group': 1, 'id': 'Johannes Stark', 'length': 914},
#  {'group': 1, 'id': 'Charles Édouard Guillaume', 'length': 544},
#  {'group': 1, 'id': 'Albert Einstein', 'length': 9540},
#  {'group': 1, 'id': 'Niels Bohr', 'length': 5026},
#  {'group': 1, 'id': 'Robert Andrews Millikan', 'length': 2353},
#  {'group': 1, 'id': 'Manne Siegbahn', 'length': 505},
#  {'group': 1, 'id': 'James Franck', 'length': 2268},
#  {'group': 1, 'id': 'Gustav Hertz', 'length': 1051},
#  {'group': 1, 'id': 'Jean Baptiste Perrin', 'length': 873},
#  {'group': 1, 'id': 'Arthur Holly Compton', 'length': 2642},
#  {'group': 1, 'id': 'Charles Thomson Rees Wilson', 'length': 998},
#  {'group': 1, 'id': 'Owen Willans Richardson', 'length': 529},
#  {'group': 1,
#   'id': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'length': 1762},
#  {'group': 1, 'id': 'Chandrasekhara Venkata Raman', 'length': 1920},
#  {'group': 1, 'id': 'Werner Heisenberg', 'length': 6452},
#  {'group': 1, 'id': 'Erwin Schrödinger', 'length': 2356},
#  {'group': 1, 'id': 'Paul Dirac', 'length': 3846},
#  {'group': 1, 'id': 'James Chadwick', 'length': 3947},
#  {'group': 1, 'id': 'Victor Francis Hess', 'length': 625},
#  {'group': 1, 'id': 'Carl David Anderson', 'length': 631},
#  {'group': 1, 'id': 'Clinton Joseph Davisson', 'length': 594},
#  {'group': 1, 'id': 'George Paget Thomson', 'length': 582},
#  {'group': 1, 'id': 'Enrico Fermi', 'length': 5784},
#  {'group': 1, 'id': 'Ernest Lawrence', 'length': 3706},
#  {'group': 1, 'id': 'Otto Stern', 'length': 522},
#  {'group': 1, 'id': 'Isidor Isaac Rabi', 'length': 3567},
#  {'group': 1, 'id': 'Wolfgang Pauli', 'length': 1883},
#  {'group': 1, 'id': 'Percy Williams Bridgman', 'length': 1204},
#  {'group': 1, 'id': 'Edward Victor Appleton', 'length': 1512},
#  {'group': 1, 'id': 'Patrick Maynard Stuart Blackett', 'length': 1709},
#  {'group': 1, 'id': 'Hideki Yukawa', 'length': 716},
#  {'group': 1, 'id': 'Cecil Frank Powell', 'length': 860},
#  {'group': 1, 'id': 'John Douglas Cockcroft', 'length': 2919},
#  {'group': 1, 'id': 'Ernest Thomas Sinton Walton', 'length': 1001},
#  {'group': 1, 'id': 'Felix Bloch', 'length': 1034},
#  {'group': 1, 'id': 'Edward Mills Purcell', 'length': 981},
#  {'group': 1, 'id': 'Frits Zernike', 'length': 659},
#  {'group': 1, 'id': 'Max Born', 'length': 3493},
#  {'group': 1, 'id': 'Walther Bothe', 'length': 1993},
#  {'group': 1, 'id': 'Willis Eugene Lamb', 'length': 581},
#  {'group': 1, 'id': 'Polykarp Kusch', 'length': 461},
#  {'group': 1, 'id': 'John Bardeen', 'length': 2374},
#  {'group': 1, 'id': 'Walter Houser Brattain', 'length': 1698},
#  {'group': 1, 'id': 'William Bradford Shockley', 'length': 2755},
#  {'group': 1, 'id': 'Tsung-Dao Lee', 'length': 1582},
#  {'group': 1, 'id': 'Chen-Ning Yang', 'length': 2145},
#  {'group': 1, 'id': 'Pavel Alekseyevich Cherenkov', 'length': 466},
#  {'group': 1, 'id': 'Ilya Frank', 'length': 535},
#  {'group': 1, 'id': 'Igor Yevgenyevich Tamm', 'length': 693},
#  {'group': 1, 'id': 'Emilio Gino Segrè', 'length': 2505},
#  {'group': 1, 'id': 'Owen Chamberlain', 'length': 635},
#  {'group': 1, 'id': 'Donald Arthur Glaser', 'length': 1165},
#  {'group': 1, 'id': 'Robert Hofstadter', 'length': 870},
#  {'group': 1, 'id': 'Rudolf Ludwig Mössbauer', 'length': 588},
#  {'group': 1, 'id': 'Lev Davidovich Landau', 'length': 1747},
#  {'group': 1, 'id': 'Eugene Paul Wigner', 'length': 3488},
#  {'group': 1, 'id': 'Maria Goeppert-Mayer', 'length': 2145},
#  {'group': 1, 'id': 'J. Hans D. Jensen', 'length': 930},
#  {'group': 1, 'id': 'Nicolay Gennadiyevich Basov', 'length': 559},
#  {'group': 1, 'id': 'Alexander Prokhorov', 'length': 927},
#  {'group': 1, 'id': 'Charles Hard Townes', 'length': 2238},
#  {'group': 1, 'id': 'Richard Phillips Feynman', 'length': 6499},
#  {'group': 1, 'id': 'Julian Schwinger', 'length': 1469},
#  {'group': 1, 'id': "Shin'ichirō Tomonaga", 'length': 705},
#  {'group': 1, 'id': 'Alfred Kastler', 'length': 481},
#  {'group': 1, 'id': 'Hans Albrecht Bethe', 'length': 4063},
#  {'group': 1, 'id': 'Luis Walter Alvarez', 'length': 4299},
#  {'group': 1, 'id': 'Murray Gell-Mann', 'length': 1575},
#  {'group': 1, 'id': 'Hannes Olof Gösta Alfvén', 'length': 1624},
#  {'group': 1, 'id': 'Louis Néel', 'length': 778},
#  {'group': 1, 'id': 'Dennis Gabor', 'length': 1140},
#  {'group': 1, 'id': 'Leon Neil Cooper', 'length': 644},
#  {'group': 1, 'id': 'John Robert Schrieffer', 'length': 850},
#  {'group': 1, 'id': 'Leo Esaki', 'length': 915},
#  {'group': 1, 'id': 'Ivar Giaever', 'length': 1154},
#  {'group': 1, 'id': 'Brian David Josephson', 'length': 3480},
#  {'group': 1, 'id': 'Martin Ryle', 'length': 1252},
#  {'group': 1, 'id': 'Antony Hewish', 'length': 717},
#  {'group': 1, 'id': 'Aage Bohr', 'length': 1611},
#  {'group': 1, 'id': 'Ben Roy Mottelson', 'length': 525},
#  {'group': 1, 'id': 'Leo James Rainwater', 'length': 1196},
#  {'group': 1, 'id': 'Burton Richter', 'length': 970},
#  {'group': 1, 'id': 'Samuel Chao Chung Ting', 'length': 1066},
#  {'group': 1, 'id': 'Philip Warren Anderson', 'length': 1088},
#  {'group': 1, 'id': 'Nevill Francis Mott', 'length': 1430},
#  {'group': 1, 'id': 'John Hasbrouck Van Vleck', 'length': 1217},
#  {'group': 1, 'id': 'Pyotr Leonidovich Kapitsa', 'length': 805},
#  {'group': 1, 'id': 'Arno Allan Penzias', 'length': 949},
#  {'group': 1, 'id': 'Robert Woodrow Wilson', 'length': 668},
#  {'group': 1, 'id': 'Sheldon Lee Glashow', 'length': 811},
#  {'group': 1, 'id': 'Abdus Salam', 'length': 5504},
#  {'group': 1, 'id': 'Steven Weinberg', 'length': 1784},
#  {'group': 1, 'id': 'James Watson Cronin', 'length': 1007},
#  {'group': 1, 'id': 'Val Logsdon Fitch', 'length': 2370},
#  {'group': 1, 'id': 'Nicolaas Bloembergen', 'length': 1306},
#  {'group': 1, 'id': 'Arthur Leonard Schawlow', 'length': 904},
#  {'group': 1, 'id': 'Kai Manne Börje Siegbahn', 'length': 361},
#  {'group': 1, 'id': 'Kenneth G. Wilson', 'length': 1090},
#  {'group': 1, 'id': 'Subrahmanyan Chandrasekhar', 'length': 2895},
#  {'group': 1, 'id': 'William Alfred Fowler', 'length': 853},
#  {'group': 1, 'id': 'Carlo Rubbia', 'length': 1156},
#  {'group': 1, 'id': 'Simon van der Meer', 'length': 868},
#  {'group': 1, 'id': 'Klaus von Klitzing', 'length': 673},
#  {'group': 1, 'id': 'Ernst Ruska', 'length': 445},
#  {'group': 1, 'id': 'Gerd Binnig', 'length': 655},
#  {'group': 1, 'id': 'Heinrich Rohrer', 'length': 463},
#  {'group': 1, 'id': 'Johannes Georg Bednorz', 'length': 553},
#  {'group': 1, 'id': 'Karl Alexander Müller', 'length': 666},
#  {'group': 1, 'id': 'Leon Max Lederman', 'length': 2092},
#  {'group': 1, 'id': 'Melvin Schwartz', 'length': 552},
#  {'group': 1, 'id': 'Jack Steinberger', 'length': 1248},
#  {'group': 1, 'id': 'Norman Foster Ramsey', 'length': 2725},
#  {'group': 1, 'id': 'Hans Georg Dehmelt', 'length': 543},
#  {'group': 1, 'id': 'Wolfgang Paul', 'length': 497},
#  {'group': 1, 'id': 'Jerome I. Friedman', 'length': 793},
#  {'group': 1, 'id': 'Henry Way Kendall', 'length': 759},
#  {'group': 1, 'id': 'Richard E. Taylor', 'length': 714},
#  {'group': 1, 'id': 'Pierre-Gilles de Gennes', 'length': 681},
#  {'group': 1, 'id': 'Georges Charpak', 'length': 773},
#  {'group': 1, 'id': 'Russell Alan Hulse', 'length': 713},
#  {'group': 1, 'id': 'Joseph Hooton Taylor Jr.', 'length': 1128},
#  {'group': 1, 'id': 'Bertram Brockhouse', 'length': 525},
#  {'group': 1, 'id': 'Clifford Glenwood Shull', 'length': 852},
#  {'group': 1, 'id': 'Martin Lewis Perl', 'length': 935},
#  {'group': 1, 'id': 'Frederick Reines', 'length': 2424},
#  {'group': 1, 'id': 'David Morris Lee', 'length': 604},
#  {'group': 1, 'id': 'Douglas D. Osheroff', 'length': 647},
#  {'group': 1, 'id': 'Robert Coleman Richardson', 'length': 509},
#  {'group': 1, 'id': 'Steven Chu', 'length': 2369},
#  {'group': 1, 'id': 'Claude Cohen-Tannoudji', 'length': 689},
#  {'group': 1, 'id': 'William Daniel Phillips', 'length': 557},
#  {'group': 1, 'id': 'Robert B. Laughlin', 'length': 587},
#  {'group': 1, 'id': 'Horst Ludwig Störmer', 'length': 509},
#  {'group': 1, 'id': 'Daniel Chee Tsui', 'length': 558},
#  {'group': 1, 'id': "Gerard 't Hooft", 'length': 1882},
#  {'group': 1, 'id': 'Martinus J. G. Veltman', 'length': 712},
#  {'group': 1, 'id': 'Zhores Ivanovich Alferov', 'length': 974},
#  {'group': 1, 'id': 'Herbert Kroemer', 'length': 563},
#  {'group': 1, 'id': 'Jack St. Clair Kilby', 'length': 1842},
#  {'group': 1, 'id': 'Eric Allin Cornell', 'length': 599},
#  {'group': 1, 'id': 'Carl Edwin Wieman', 'length': 691},
#  {'group': 1, 'id': 'Wolfgang Ketterle', 'length': 727},
#  {'group': 1, 'id': 'Raymond Davis Jr.', 'length': 971},
#  {'group': 1, 'id': 'Masatoshi Koshiba', 'length': 840},
#  {'group': 1, 'id': 'Riccardo Giacconi', 'length': 604},
#  {'group': 1, 'id': 'Alexei Alexeyevich Abrikosov', 'length': 807},
#  {'group': 1, 'id': 'Vitaly Lazarevich Ginzburg', 'length': 1012},
#  {'group': 1, 'id': 'Anthony James Leggett', 'length': 1197},
#  {'group': 1, 'id': 'David J. Gross', 'length': 1006},
#  {'group': 1, 'id': 'Hugh David Politzer', 'length': 546},
#  {'group': 1, 'id': 'Frank Wilczek', 'length': 1187},
#  {'group': 1, 'id': 'Roy J. Glauber', 'length': 782},
#  {'group': 1, 'id': 'John L. Hall', 'length': 693},
#  {'group': 1, 'id': 'Theodor W. Hänsch', 'length': 881},
#  {'group': 1, 'id': 'John C. Mather', 'length': 1180},
#  {'group': 1, 'id': 'George F. Smoot', 'length': 1679},
#  {'group': 1, 'id': 'Albert Fert', 'length': 709},
#  {'group': 1, 'id': 'Peter Grünberg', 'length': 879},
#  {'group': 1, 'id': 'Makoto Kobayashi', 'length': 675},
#  {'group': 1, 'id': 'Toshihide Maskawa', 'length': 609},
#  {'group': 1, 'id': 'Yoichiro Nambu', 'length': 1636},
#  {'group': 1, 'id': 'Charles K. Kao', 'length': 4088},
#  {'group': 1, 'id': 'Willard S. Boyle', 'length': 709},
#  {'group': 1, 'id': 'George E. Smith', 'length': 544},
#  {'group': 1, 'id': 'Andre Geim', 'length': 2205},
#  {'group': 1, 'id': 'Konstantin Novoselov', 'length': 1446},
#  {'group': 1, 'id': 'Saul Perlmutter', 'length': 1388},
#  {'group': 1, 'id': 'Brian P. Schmidt', 'length': 2385},
#  {'group': 1, 'id': 'Adam G. Riess', 'length': 1221},
#  {'group': 1, 'id': 'Serge Haroche', 'length': 865},
#  {'group': 1, 'id': 'David J. Wineland', 'length': 1481},
#  {'group': 1, 'id': 'François Englert', 'length': 1130},
#  {'group': 1, 'id': 'Peter Higgs', 'length': 2496},
#  {'group': 1, 'id': 'Isamu Akasaki', 'length': 1277},
#  {'group': 1, 'id': 'Hiroshi Amano', 'length': 594},
#  {'group': 1, 'id': 'Shuji Nakamura', 'length': 947},
#  {'group': 1, 'id': 'Takaaki Kajita', 'length': 1006},
#  {'group': 1, 'id': 'Arthur B. McDonald', 'length': 1166},
#  {'group': 1, 'id': 'David J. Thouless', 'length': 934},
#  {'group': 1, 'id': 'F. Duncan M. Haldane', 'length': 813},
#  {'group': 1, 'id': 'John M. Kosterlitz', 'length': 621},
#  {'group': 1, 'id': 'Rainer Weiss', 'length': 1859},
#  {'group': 1, 'id': 'Kip Thorne', 'length': 2851},
#  {'group': 1, 'id': 'Barry Barish', 'length': 1466}]

# %% [markdown]
# Creating nodes_list was easy. Creating links_list will be more involved.
#
# ## Create links_list
#
# Ultimately we want to create a list of libraries, each containing two physicists/physics domains (one listed as "target", the other as "source"), and their "value", which measures the strength of their connection (we will discuss later how the strength of their connection is computed).
#
# Here is the basic outline of what we are going to do:
#
# - Create a df (words_vector) containing the how many times each word in physics_corpus occurs in each physicist/physics domain entry.
# - Create another df (similarity_df) containing the cosine-similarity index between each of two entries. This is the value we will use to measure how "connected" two physicists/physics domains are. (The cosine-similarity index will be explained later)
# - Melt similarity_df into a df containing three columns ("source", "target", "value". The resulting df is named melted_df.
# - Convert similarity_df into a list of dictionaries. This list will be named links_list.
#
# Once we have that, we can use nodes_list and links_list to visualize our social network.
#
# Let's start with creating words_vector. We will create an empty dataframe, populate it with the count of each word per Wikipedia entry, and then fill in any missing values with a 0.
#
# - ### Create a(n empty) data frame with the nodes_df index as columns and physics_corpus as index

# %%
words_vector =  pd.DataFrame( columns = nodes_df.index.values, index = physics_corpus)
words_vector
# Out:
#                      accelerator physics acoustics agrophysics antimatter  \
# paved                                NaN       NaN         NaN        NaN
# proposal                             NaN       NaN         NaN        NaN
# released                             NaN       NaN         NaN        NaN
# wwwencyclopediacom                   NaN       NaN         NaN        NaN
# pbar                                 NaN       NaN         NaN        NaN
# exact                                NaN       NaN         NaN        NaN
# mystic                               NaN       NaN         NaN        NaN
# thickness                            NaN       NaN         NaN        NaN
# element                              NaN       NaN         NaN        NaN
# aas                                  NaN       NaN         NaN        NaN
# poisonous                            NaN       NaN         NaN        NaN
# ralph                                NaN       NaN         NaN        NaN
# oleary                               NaN       NaN         NaN        NaN
# distorted                            NaN       NaN         NaN        NaN
# aqueous                              NaN       NaN         NaN        NaN
# howard                               NaN       NaN         NaN        NaN
# society                              NaN       NaN         NaN        NaN
# reject                               NaN       NaN         NaN        NaN
# le                                   NaN       NaN         NaN        NaN
# ramsey                               NaN       NaN         NaN        NaN
# students                             NaN       NaN         NaN        NaN
# liberated                            NaN       NaN         NaN        NaN
# jaguar                               NaN       NaN         NaN        NaN
# mother                               NaN       NaN         NaN        NaN
# wrinkles                             NaN       NaN         NaN        NaN
# kids                                 NaN       NaN         NaN        NaN
# longest                              NaN       NaN         NaN        NaN
# europhysics                          NaN       NaN         NaN        NaN
# electrochemical                      NaN       NaN         NaN        NaN
# abelian                              NaN       NaN         NaN        NaN
# ...                                  ...       ...         ...        ...
# lamb                                 NaN       NaN         NaN        NaN
# disagree                             NaN       NaN         NaN        NaN
# xn                                   NaN       NaN         NaN        NaN
# homestake                            NaN       NaN         NaN        NaN
# traverses                            NaN       NaN         NaN        NaN
# bergman                              NaN       NaN         NaN        NaN
# powerpoint                           NaN       NaN         NaN        NaN
# broglie                              NaN       NaN         NaN        NaN
# gammarays                            NaN       NaN         NaN        NaN
# arxivquantph                         NaN       NaN         NaN        NaN
# flowing                              NaN       NaN         NaN        NaN
# sensible                             NaN       NaN         NaN        NaN
# scholars                             NaN       NaN         NaN        NaN
# compendium                           NaN       NaN         NaN        NaN
# quantentheoretischen                 NaN       NaN         NaN        NaN
# efforts                              NaN       NaN         NaN        NaN
# pulsating                            NaN       NaN         NaN        NaN
# kluwer                               NaN       NaN         NaN        NaN
# gl                                   NaN       NaN         NaN        NaN
# thermionic                           NaN       NaN         NaN        NaN
# unifying                             NaN       NaN         NaN        NaN
# delineated                           NaN       NaN         NaN        NaN
# electromechanical                    NaN       NaN         NaN        NaN
# eckert                               NaN       NaN         NaN        NaN
# dilute                               NaN       NaN         NaN        NaN
# nordström                            NaN       NaN         NaN        NaN
# hydride                              NaN       NaN         NaN        NaN
# lap                                  NaN       NaN         NaN        NaN
# piezoelectricity                     NaN       NaN         NaN        NaN
# stamp                                NaN       NaN         NaN        NaN
#
# lap                              NaN        NaN       NaN          NaN  NaN
# piezoelectricity                 NaN        NaN       NaN          NaN  NaN
# stamp                            NaN        NaN       NaN          NaN  NaN
#
#                      atomic and molecular astrophysics     ...       \
# paved                                              NaN     ...
# proposal                                           NaN     ...
# released                                           NaN     ...
# wwwencyclopediacom                                 NaN     ...
# pbar                                               NaN     ...
# exact                                              NaN     ...
# mystic                                             NaN     ...
# thickness                                          NaN     ...
# element                                            NaN     ...
# aas                                                NaN     ...
# poisonous                                          NaN     ...
# ralph                                              NaN     ...
# oleary                                             NaN     ...
# distorted                                          NaN     ...
# aqueous                                            NaN     ...
# howard                                             NaN     ...
# society                                            NaN     ...
# reject                                             NaN     ...
# le                                                 NaN     ...
# ramsey                                             NaN     ...
# students                                           NaN     ...
# liberated                                          NaN     ...
# jaguar                                             NaN     ...
# mother                                             NaN     ...
# wrinkles                                           NaN     ...
# kids                                               NaN     ...
# longest                                            NaN     ...
# europhysics                                        NaN     ...
# electrochemical                                    NaN     ...
# abelian                                            NaN     ...
# ...                                                ...     ...
# lamb                                               NaN     ...
# disagree                                           NaN     ...
# xn                                                 NaN     ...
# homestake                                          NaN     ...
# traverses                                          NaN     ...
# bergman                                            NaN     ...
# powerpoint                                         NaN     ...
# broglie                                            NaN     ...
# gammarays                                          NaN     ...
# arxivquantph                                       NaN     ...
# flowing                                            NaN     ...
# sensible                                           NaN     ...
# scholars                                           NaN     ...
# compendium                                         NaN     ...
# quantentheoretischen                               NaN     ...
# efforts                                            NaN     ...
# pulsating                                          NaN     ...
# kluwer                                             NaN     ...
# gl                                                 NaN     ...
# thermionic                                         NaN     ...
# unifying                                           NaN     ...
# delineated                                         NaN     ...
# electromechanical                                  NaN     ...
# eckert                                             NaN     ...
# dilute                                             NaN     ...
# nordström                                          NaN     ...
# hydride                                            NaN     ...
# lap                                                NaN     ...
# piezoelectricity                                   NaN     ...
# stamp                                              NaN     ...
#
#                      Hiroshi Amano Shuji Nakamura Takaaki Kajita  \
# paved                          NaN            NaN            NaN
# proposal                       NaN            NaN            NaN
# released                       NaN            NaN            NaN
# wwwencyclopediacom             NaN            NaN            NaN
# pbar                           NaN            NaN            NaN
# exact                          NaN            NaN            NaN
# mystic                         NaN            NaN            NaN
# thickness                      NaN            NaN            NaN
# element                        NaN            NaN            NaN
# aas                            NaN            NaN            NaN
# poisonous                      NaN            NaN            NaN
# ralph                          NaN            NaN            NaN
# oleary                         NaN            NaN            NaN
# distorted                      NaN            NaN            NaN
# aqueous                        NaN            NaN            NaN
# howard                         NaN            NaN            NaN
# society                        NaN            NaN            NaN
# reject                         NaN            NaN            NaN
# le                             NaN            NaN            NaN
# ramsey                         NaN            NaN            NaN
# students                       NaN            NaN            NaN
# liberated                      NaN            NaN            NaN
# jaguar                         NaN            NaN            NaN
# mother                         NaN            NaN            NaN
# wrinkles                       NaN            NaN            NaN
# kids                           NaN            NaN            NaN
# longest                        NaN            NaN            NaN
# europhysics                    NaN            NaN            NaN
# electrochemical                NaN            NaN            NaN
# abelian                        NaN            NaN            NaN
# ...                            ...            ...            ...
# lamb                           NaN            NaN            NaN
# disagree                       NaN            NaN            NaN
# xn                             NaN            NaN            NaN
# homestake                      NaN            NaN            NaN
# traverses                      NaN            NaN            NaN
# bergman                        NaN            NaN            NaN
# powerpoint                     NaN            NaN            NaN
# broglie                        NaN            NaN            NaN
# gammarays                      NaN            NaN            NaN
# arxivquantph                   NaN            NaN            NaN
# flowing                        NaN            NaN            NaN
# sensible                       NaN            NaN            NaN
# scholars                       NaN            NaN            NaN
# compendium                     NaN            NaN            NaN
# quantentheoretischen           NaN            NaN            NaN
# efforts                        NaN            NaN            NaN
# pulsating                      NaN            NaN            NaN
# kluwer                         NaN            NaN            NaN
# gl                             NaN            NaN            NaN
# thermionic                     NaN            NaN            NaN
# unifying                       NaN            NaN            NaN
# delineated                     NaN            NaN            NaN
# electromechanical              NaN            NaN            NaN
# eckert                         NaN            NaN            NaN
# dilute                         NaN            NaN            NaN
# nordström                      NaN            NaN            NaN
# hydride                        NaN            NaN            NaN
# lap                            NaN            NaN            NaN
# piezoelectricity               NaN            NaN            NaN
# stamp                          NaN            NaN            NaN
#
#                      Arthur B. McDonald David J. Thouless  \
# paved                               NaN               NaN
# proposal                            NaN               NaN
# released                            NaN               NaN
# wwwencyclopediacom                  NaN               NaN
# pbar                                NaN               NaN
# exact                               NaN               NaN
# mystic                              NaN               NaN
# thickness                           NaN               NaN
# element                             NaN               NaN
# aas                                 NaN               NaN
# poisonous                           NaN               NaN
# ralph                               NaN               NaN
# oleary                              NaN               NaN
# distorted                           NaN               NaN
# aqueous                             NaN               NaN
# howard                              NaN               NaN
# society                             NaN               NaN
# reject                              NaN               NaN
# le                                  NaN               NaN
# ramsey                              NaN               NaN
# students                            NaN               NaN
# liberated                           NaN               NaN
# jaguar                              NaN               NaN
# mother                              NaN               NaN
# wrinkles                            NaN               NaN
# kids                                NaN               NaN
# longest                             NaN               NaN
# europhysics                         NaN               NaN
# electrochemical                     NaN               NaN
# abelian                             NaN               NaN
# ...                                 ...               ...
# lamb                                NaN               NaN
# disagree                            NaN               NaN
# xn                                  NaN               NaN
# homestake                           NaN               NaN
# traverses                           NaN               NaN
# bergman                             NaN               NaN
# powerpoint                          NaN               NaN
# broglie                             NaN               NaN
# gammarays                           NaN               NaN
# arxivquantph                        NaN               NaN
# flowing                             NaN               NaN
# sensible                            NaN               NaN
# scholars                            NaN               NaN
# compendium                          NaN               NaN
# quantentheoretischen                NaN               NaN
# efforts                             NaN               NaN
# pulsating                           NaN               NaN
# kluwer                              NaN               NaN
# gl                                  NaN               NaN
# thermionic                          NaN               NaN
# unifying                            NaN               NaN
# delineated                          NaN               NaN
# electromechanical                   NaN               NaN
# eckert                              NaN               NaN
# dilute                              NaN               NaN
# nordström                           NaN               NaN
# hydride                             NaN               NaN
# lap                                 NaN               NaN
# piezoelectricity                    NaN               NaN
# stamp                               NaN               NaN
#
#                      F. Duncan M. Haldane John M. Kosterlitz Rainer Weiss  \
# paved                                 NaN                NaN          NaN
# ...                         ...          ...
# lamb                        NaN          NaN
# disagree                    NaN          NaN
# xn                          NaN          NaN
# homestake                   NaN          NaN
# traverses                   NaN          NaN
# bergman                     NaN          NaN
# powerpoint                  NaN          NaN
# broglie                     NaN          NaN
# gammarays                   NaN          NaN
# arxivquantph                NaN          NaN
# flowing                     NaN          NaN
# sensible                    NaN          NaN
# scholars                    NaN          NaN
# compendium                  NaN          NaN
# quantentheoretischen        NaN          NaN
# efforts                     NaN          NaN
# pulsating                   NaN          NaN
# kluwer                      NaN          NaN
# gl                          NaN          NaN
# thermionic                  NaN          NaN
# unifying                    NaN          NaN
# delineated                  NaN          NaN
# electromechanical           NaN          NaN
# eckert                      NaN          NaN
# dilute                      NaN          NaN
# nordström                   NaN          NaN
# hydride                     NaN          NaN
# lap                         NaN          NaN
# piezoelectricity            NaN          NaN
# stamp                       NaN          NaN
#
# [12935 rows x 339 columns]

# %% [markdown]
# Now we need to make a function which takes a list, and returns the count for each element in the list. The format will be a Series with the elements of the list as index, and contains the count of each one.
#
# We will apply this function to each element in "physics_list_clean" in both nobel_df  and physics_df. Recall that physics_list_clean columns contains all words from each physicist's/physics domain's Wikipedia entry that are also physics_corpus. Thus, applying this function to an element of "physics_list_clean" will return a Series, with index physics_corpus and counts for each. Thus, it will work perfectly to fill each column of words_vector.
#
# - ### Write/apply function that returns word count of given list

# %%
def count_words(list_to_count):
    return (pd.Series(list_to_count)).value_counts()

words_vector.loc[:,nobel_df.index] = nobel_df["physics_list_clean"].apply(count_words).transpose()
words_vector.loc[:,physics_df.index] = physics_df["physics_list_clean"].apply(count_words).transpose()

# %% [markdown]
# Now we replace any NaN values with 0.
#
# - ### Fill the missing values

# %%
words_vector = words_vector.fillna(value=0)
words_vector
#nobel_df["physics_list_clean"].apply(count_words)
# Out:
#                       accelerator physics  acoustics  agrophysics  antimatter  \
# paved                                 0.0        0.0          0.0         0.0
# proposal                              0.0        0.0          0.0         1.0
# released                              0.0        0.0          0.0         3.0
# wwwencyclopediacom                    0.0        0.0          0.0         0.0
# pbar                                  0.0        0.0          0.0         0.0
# exact                                 1.0        0.0          1.0         1.0
# mystic                                0.0        0.0          0.0         0.0
# thickness                             0.0        0.0          0.0         0.0
# element                               0.0        1.0          0.0         0.0
# aas                                   0.0        0.0          0.0         0.0
# poisonous                             0.0        0.0          0.0         0.0
# ralph                                 0.0        0.0          0.0         0.0
# oleary                                0.0        0.0          0.0         0.0
# distorted                             0.0        0.0          0.0         0.0
# aqueous                               0.0        0.0          0.0         0.0
# howard                                0.0        0.0          0.0         0.0
# society                               0.0       16.0          2.0         5.0
# reject                                0.0        0.0          0.0         0.0
# le                                    0.0        0.0          0.0         0.0
# ramsey                                0.0        0.0          0.0         0.0
# students                              0.0        0.0          0.0         0.0
# liberated                             0.0        0.0          0.0         1.0
# jaguar                                0.0        0.0          0.0         0.0
# mother                                0.0        0.0          0.0         0.0
# wrinkles                              0.0        0.0          0.0         0.0
# kids                                  0.0        0.0          0.0         0.0
# longest                               0.0        0.0          0.0         0.0
#
# Thus for any two Wikipedia entries, we can compute the cosine similarity index as
#
# $$similarity = cos\left(\theta\right) = \frac{A\cdot B}{\left\|A\right\| \left\|B\right\|},$$ where $A, B$ are their vector representations. A similarity value of 1 means that the two entries are completely identical. A value of -1 means that they are completely opposite.
#
#
#
# - ### Create similarity_df

# %%
def euc_norm(list):
    return np.sqrt( sum([x**2 for x in list]))
    
# Use "norm"s for denominator
norm = pd.DataFrame(words_vector.apply(euc_norm))
    
numer = words_vector.transpose().dot(words_vector)
denom = norm.dot( norm.transpose() )
similarity_df = numer/denom

# %%
similarity_df
# Out:
#                                         accelerator physics  acoustics  \
# accelerator physics                                1.000000   0.181027
# acoustics                                          0.181027   1.000000
# agrophysics                                        0.324358   0.232904
# antimatter                                         0.243108   0.145087
# applied physics                                    0.476278   0.204141
# astrometry                                         0.133262   0.137180
# astronomy                                          0.169541   0.179164
# astrophysics                                       0.296805   0.224255
# atom                                               0.250150   0.163213
# atomic and molecular astrophysics                  0.106064   0.064637
# atomic physics                                     0.370747   0.167784
# atomic, molecular, and optical physics             0.380099   0.206760
# bcs theory                                         0.130958   0.098204
# big bang                                           0.148255   0.112224
# biophysics                                         0.209139   0.159056
# black hole                                         0.119595   0.088073
# bloch wave                                         0.105065   0.138314
# bose-einstein condensate                           0.207098   0.103820
# brane                                              0.042053   0.051464
# casimir effect                                     0.231781   0.133763
# chemical physics                                   0.290227   0.124739
# communication physics                              0.202803   0.139637
# condensed matter physics                           0.388740   0.206765
# cosmic background radiation                        0.081196   0.054156
# cosmic inflation                                   0.167451   0.111732
# cosmic string                                      0.072375   0.100303
# cosmology                                          0.211602   0.150225
# cosmos                                             0.099352   0.110556
# dark energy                                        0.114450   0.094833
# dark matter                                        0.140769   0.085197
# ...                                                     ...        ...
# John C. Mather                                     0.111033   0.086052
# George F. Smoot                                    0.147118   0.105797
# Albert Fert                                        0.141381   0.079228
# Peter Grünberg                                     0.118677   0.070847
# Makoto Kobayashi                                   0.239615   0.110185
# Toshihide Maskawa                                  0.191127   0.095180
# Yoichiro Nambu                                     0.152042   0.114350
# Charles K. Kao                                     0.136672   0.156477
# Willard S. Boyle                                   0.113726   0.079910
# George E. Smith                                    0.097994   0.075364
# Andre Geim                                         0.177628   0.132179
# Konstantin Novoselov                               0.196271   0.151797
# Saul Perlmutter                                    0.112366   0.068587
# Brian P. Schmidt                                   0.113383   0.104419
# Adam G. Riess                                      0.106271   0.082070
# Serge Haroche                                      0.144678   0.095556
# David J. Wineland                                  0.127581   0.109672
# François Englert                                   0.238962   0.114421
# Peter Higgs                                        0.198304   0.109187
# Isamu Akasaki                                      0.154898   0.140021
# Hiroshi Amano                                      0.172038   0.115521
# Shuji Nakamura                                     0.120158   0.092485
# Takaaki Kajita                                     0.170583   0.095625
# Arthur B. McDonald                                 0.180732   0.112706
# David J. Thouless                                  0.172286   0.108834
# F. Duncan M. Haldane                               0.169737   0.109798
# John M. Kosterlitz                                 0.145952   0.086004
# Shuji Nakamura                                    0.392842      0.352786
# Takaaki Kajita                                    0.526115      0.512958
# Arthur B. McDonald                                0.504031      0.417610
# David J. Thouless                                 0.685839      0.440842
# F. Duncan M. Haldane                              0.639772      0.372008
# John M. Kosterlitz                                1.000000      0.380107
# Rainer Weiss                                      0.380107      1.000000
# Kip Thorne                                        0.346648      0.622091
# Barry Barish                                      0.430225      0.557152
#
#                                         Kip Thorne  Barry Barish
# accelerator physics                       0.179970      0.200716
# acoustics                                 0.150543      0.138593
# agrophysics                               0.232340      0.241451
# antimatter                                0.211923      0.197134
# applied physics                           0.265340      0.295526
# astrometry                                0.172844      0.117039
# astronomy                                 0.254451      0.215852
# astrophysics                              0.307599      0.263597
# atom                                      0.213961      0.209013
# atomic and molecular astrophysics         0.094658      0.062200
# atomic physics                            0.249683      0.228720
# atomic, molecular, and optical physics    0.248516      0.218869
# bcs theory                                0.140172      0.113051
# big bang                                  0.215088      0.147227
# biophysics                                0.144778      0.126263
# black hole                                0.368648      0.186534
# bloch wave                                0.089408      0.074597
# bose-einstein condensate                  0.186395      0.162715
# brane                                     0.038446      0.023851
# casimir effect                            0.200168      0.135824
# chemical physics                          0.155391      0.168827
# communication physics                     0.110728      0.105540
# condensed matter physics                  0.294211      0.280583
# cosmic background radiation               0.093950      0.086325
# cosmic inflation                          0.198132      0.138364
# cosmic string                             0.134026      0.098787
# cosmology                                 0.266672      0.224833
# cosmos                                    0.158150      0.089958
# dark energy                               0.151500      0.117833
# dark matter                               0.145686      0.107724
# ...                                            ...           ...
# John C. Mather                            0.313393      0.372650
# George F. Smoot                           0.302232      0.352798
# Albert Fert                               0.329380      0.393766
# Peter Grünberg                            0.267776      0.301966
# Makoto Kobayashi                          0.317669      0.400255
# Toshihide Maskawa                         0.329062      0.411192
# Yoichiro Nambu                            0.355357      0.436922
# Charles K. Kao                            0.323366      0.382160
# Willard S. Boyle                          0.305400      0.380756
# George E. Smith                           0.305088      0.411351
# Andre Geim                                0.420811      0.538539
# Konstantin Novoselov                      0.386731      0.468755
# Saul Perlmutter                           0.368459      0.379704
# Brian P. Schmidt                          0.368636      0.376633
# Adam G. Riess                             0.403789      0.394487
# Serge Haroche                             0.330871      0.381999
# David J. Wineland                         0.366826      0.446275
# François Englert                          0.379683      0.438085
# Peter Higgs                               0.297676      0.327415
# Isamu Akasaki                             0.367187      0.425930
# Hiroshi Amano                             0.353244      0.456745
# Shuji Nakamura                            0.327254      0.385316
# Takaaki Kajita                            0.427320      0.512504
# Arthur B. McDonald                        0.391899      0.454892
# David J. Thouless                         0.395757      0.472888
# F. Duncan M. Haldane                      0.361680      0.430148
# John M. Kosterlitz                        0.346648      0.430225
# Rainer Weiss                              0.622091      0.557152
# Kip Thorne                                1.000000      0.532536
# Barry Barish                              0.532536      1.000000
#
# [339 rows x 339 columns]

# %% [markdown]
# We have all the information we need! We have the cosine similarity for every pair of physicists/physics domains, but we're going to clean it up some more. Here's what we need to do.
#
# - Melt the df so that the data is easier to work with.
# - Get rid of duplicates (for example, there is a row with acoustics for "source" and accelerator physics for "target". There is also a row with accelerator physics for "source" and aocustics for "target". Because our social network is not directed, we treat these as the same. Thus we are going to only keep one of these entries. Similarly, we will remove all other "duplicates"
# - We want to highlight only the most important connections. So for every physicist/physics domain, we only keep the 8 physicists/domains with the highest cosine similarity index to it.
#
#
# - ### Reset the index and melt the dataframe

# %%
melted_df = pd.melt(similarity_df.reset_index(), id_vars = ['index'])
melted_df.columns = ["source", "target", "value"]
melted_df
# Out:
#                                         source               target     value
# 0                          accelerator physics  accelerator physics  1.000000
# 1                                    acoustics  accelerator physics  0.181027
# 2                                  agrophysics  accelerator physics  0.324358
# 3                                   antimatter  accelerator physics  0.243108
# 4                              applied physics  accelerator physics  0.476278
# 5                                   astrometry  accelerator physics  0.133262
# 6                                    astronomy  accelerator physics  0.169541
# 7                                 astrophysics  accelerator physics  0.296805
# 8                                         atom  accelerator physics  0.250150
# 9            atomic and molecular astrophysics  accelerator physics  0.106064
# 10                              atomic physics  accelerator physics  0.370747
# 11      atomic, molecular, and optical physics  accelerator physics  0.380099
# 12                                  bcs theory  accelerator physics  0.130958
# 13                                    big bang  accelerator physics  0.148255
# 14                                  biophysics  accelerator physics  0.209139
# 15                                  black hole  accelerator physics  0.119595
# 16                                  bloch wave  accelerator physics  0.105065
# 17                    bose-einstein condensate  accelerator physics  0.207098
# 18                                       brane  accelerator physics  0.042053
# 19                              casimir effect  accelerator physics  0.231781
# 20                            chemical physics  accelerator physics  0.290227
# 21                       communication physics  accelerator physics  0.202803
# 22                    condensed matter physics  accelerator physics  0.388740
# 23                 cosmic background radiation  accelerator physics  0.081196
# 24                            cosmic inflation  accelerator physics  0.167451
# 25                               cosmic string  accelerator physics  0.072375
# 26                                   cosmology  accelerator physics  0.211602
# 27                                      cosmos  accelerator physics  0.099352
# 28                                 dark energy  accelerator physics  0.114450
# 29                                 dark matter  accelerator physics  0.140769
# ...                                        ...                  ...       ...
# 114891                          John C. Mather         Barry Barish  0.372650
# 114892                         George F. Smoot         Barry Barish  0.352798
# 114893                             Albert Fert         Barry Barish  0.393766
# 114894                          Peter Grünberg         Barry Barish  0.301966
# 114895                        Makoto Kobayashi         Barry Barish  0.400255
# 114896                       Toshihide Maskawa         Barry Barish  0.411192
# 114897                          Yoichiro Nambu         Barry Barish  0.436922
# 114898                          Charles K. Kao         Barry Barish  0.382160
# 114899                        Willard S. Boyle         Barry Barish  0.380756
# 114900                         George E. Smith         Barry Barish  0.411351
# 114901                              Andre Geim         Barry Barish  0.538539
# 114902                    Konstantin Novoselov         Barry Barish  0.468755
# 114903                         Saul Perlmutter         Barry Barish  0.379704
# 114904                        Brian P. Schmidt         Barry Barish  0.376633
# 114905                           Adam G. Riess         Barry Barish  0.394487
# 114906                           Serge Haroche         Barry Barish  0.381999
# 114907                       David J. Wineland         Barry Barish  0.446275
# 114908                        François Englert         Barry Barish  0.438085
# 114909                             Peter Higgs         Barry Barish  0.327415
# 114910                           Isamu Akasaki         Barry Barish  0.425930
# 114911                           Hiroshi Amano         Barry Barish  0.456745
# 114912                          Shuji Nakamura         Barry Barish  0.385316
# 114913                          Takaaki Kajita         Barry Barish  0.512504
# 114914                      Arthur B. McDonald         Barry Barish  0.454892
# 114915                       David J. Thouless         Barry Barish  0.472888
# 114916                    F. Duncan M. Haldane         Barry Barish  0.430148
# 114917                      John M. Kosterlitz         Barry Barish  0.430225
# 114918                            Rainer Weiss         Barry Barish  0.557152
# 114919                              Kip Thorne         Barry Barish  0.532536
# 114920                            Barry Barish         Barry Barish  1.000000
#
# [114921 rows x 3 columns]

# %% [markdown]
# - ### Shuffle data set rowwise.

# %%
melted_df = melted_df.sample(frac=1.).reset_index(drop=True)
melted_df
# Out:
#                                    source                          target  \
# 0                              antimatter         Rudolf Ludwig Mössbauer
# 1                     Joseph John Thomson         William Daniel Phillips
# 2        nanoscale and mesoscopic physics          physics of computation
# 3                              Kip Thorne             gravitation physics
# 4                             Peter Higgs        Albert Abraham Michelson
# 5                              biophysics             Luis Walter Alvarez
# 6                              Steven Chu                      Steven Chu
# 7                         nuclear physics                   Tsung-Dao Lee
# 8                         applied physics            Horst Ludwig Störmer
# 9                         Georges Charpak              Arthur B. McDonald
# 10                     Willis Eugene Lamb           high pressure physics
# 11                   neutrino oscillation            nuclear astrophysics
# 12                   theory of everything                      Max Planck
# 13                         Alfred Kastler                          string
# 14                          cosmic string               Robert Hofstadter
# 15               Joseph Hooton Taylor Jr.              Simon van der Meer
# 16        Patrick Maynard Stuart Blackett                      superfluid
# 17                                 galaxy           Lev Davidovich Landau
# 18                          Wolfgang Paul         quantum electrodynamics
# 19                          Frits Zernike         William Daniel Phillips
# 20                          Serge Haroche                    Enrico Fermi
# 21                    Charles Hard Townes            quantum field theory
# 22                     John M. Kosterlitz         low-temperature physics
# 23                            Abdus Salam                          optics
# 24                  Robert Woodrow Wilson         William Daniel Phillips
# 25                  William Alfred Fowler                         nuclear
# 26                        Herbert Kroemer       William Bradford Shockley
# 27                 Philip Warren Anderson                  Polykarp Kusch
# 28                         Charles K. Kao          Edward Victor Appleton
# 29                              Leo Esaki             Alexander Prokhorov
# ...                                   ...                             ...
# 114891                      Hiroshi Amano                       magnetism
# 114892                      photovoltaics             William Henry Bragg
# 114893                      semiconductor                   Serge Haroche
# 114894             Maria Skłodowska-Curie             Victor Francis Hess
# 114895                     Roy J. Glauber                 Albert Einstein
# 114896                  Wolfgang Ketterle             accelerator physics
# 114897                James Watson Cronin                             gas
# 114898                          photonics                  James Chadwick
# 114899             Claude Cohen-Tannoudji                            spin
# 114900                      Isamu Akasaki              Bertram Brockhouse
# 114901                 John M. Kosterlitz                  Peter Grünberg
# 114902                             liquid            Norman Foster Ramsey
# 114903    Patrick Maynard Stuart Blackett                  John C. Mather
# 114904                          astronomy     Charles Thomson Rees Wilson
# 114905             Philip Warren Anderson           electrical conduction
# 114906                 Robert B. Laughlin                      Louis Néel
# 114907                  molecular physics                   photovoltaics
# 114908                  Guglielmo Marconi                Owen Chamberlain
# 114909                engineering physics             Luis Walter Alvarez
# 114910                  self-organization                  James Chadwick
# 114911                Carl David Anderson            Shin'ichirō Tomonaga
# 114912                      spectral line  Johannes Diderik van der Waals
# 114913                Victor Francis Hess      Subrahmanyan Chandrasekhar
# 114914       Pavel Alekseyevich Cherenkov                     dark energy
# 114915                     standard model                     Gerd Binnig
# 114916              electrical conduction                    econophysics
# 114917                        Gerd Binnig                        universe
# 114918  atomic and molecular astrophysics                Daniel Chee Tsui
# 114919                      laser physics                  Wolfgang Pauli
# 114920                  Toshihide Maskawa         gravitational radiation
#
#            value
# 0       0.134750
# 1       0.233942
# 2       0.079613
# 3       0.344277
# 4       0.206263
# 5       0.085663
# 6       1.000000
# 7       0.206987
# 8       0.220484
# 9       0.373899
# 10      0.069202
# 11      0.294435
# 12      0.214999
# 13      0.055601
# 14      0.045146
# 15      0.303808
# 16      0.089802
# 17      0.079503
# 18      0.107877
# 19      0.442416
# 20      0.207518
# 21      0.097739
# 22      0.035858
# 23      0.124684
# 24      0.326109
# 25      0.229523
# 26      0.305241
# 27      0.264253
# 28      0.201653
# 29      0.357860
# ...          ...
# 114891  0.061758
# 114892  0.075768
# 114893  0.101425
# 114894  0.315640
# 114895  0.244529
# 114896  0.119661
# 114897  0.073858
# 114898  0.073592
# 114899  0.078168
# 114900  0.487691
# 114901  0.371209
# 114902  0.050535
# 114903  0.212951
# 114904  0.128639
# 114905  0.099335
# 114906  0.377040
# 114907  0.117071
# 114908  0.180698
# 114909  0.111895
# 114910  0.191151
# 114911  0.326214
# 114912  0.144867
# 114913  0.228745
# 114914  0.056948
# 114915  0.109680
# 114916  0.148298
# 114917  0.087374
# 114918  0.043532
# 114919  0.040158
# 114920  0.089641
#
# [114921 rows x 3 columns]

# %% [markdown]
# Getting rid of duplicates is a bit tricky. What we do is merge melted_df with itself, merging on ['source', 'target'] with ['target', 'source']. We keep the indices of both "copies" of melted_df. For each pair of duplicates (i.e. source_x, target_x =target_x, source_y),  we store in the list "index_to_drop" the value of either index_x or index_y, whichever is greater (using .unique() so that we don't have duplicates in this list). Finally, we drop all indices in "index_to_drop" from melted_df to get melted_df_sub, which has no duplicates.
#
# - ### Merge melted_df with itself

# %%
merged_df = pd.merge(melted_df.reset_index(), melted_df.reset_index(), left_on =['source','target'], right_on=['target','source'])

merged_df
# Out:
#         index_x                           source_x  \
# 0             0                         antimatter
# 1             1                Joseph John Thomson
# 2             2   nanoscale and mesoscopic physics
# 3             3                         Kip Thorne
# 4             4                        Peter Higgs
# 5             5                         biophysics
# 6             6                         Steven Chu
# 7             7                    nuclear physics
# 8             8                    applied physics
# 9             9                    Georges Charpak
# 10           10                 Willis Eugene Lamb
# 11           11               neutrino oscillation
# 12           12               theory of everything
# 13           13                     Alfred Kastler
# 14           14                      cosmic string
# 15           15           Joseph Hooton Taylor Jr.
# 16           16    Patrick Maynard Stuart Blackett
# 17           17                             galaxy
# 18           18                      Wolfgang Paul
# 19           19                      Frits Zernike
# 20           20                      Serge Haroche
# 21           21                Charles Hard Townes
# 22           22                 John M. Kosterlitz
# 114905           electrical conduction             Philip Warren Anderson
# 114906                      Louis Néel                 Robert B. Laughlin
# 114907                   photovoltaics                  molecular physics
# 114908                Owen Chamberlain                  Guglielmo Marconi
# 114909             Luis Walter Alvarez                engineering physics
# 114910                  James Chadwick                  self-organization
# 114911            Shin'ichirō Tomonaga                Carl David Anderson
# 114912  Johannes Diderik van der Waals                      spectral line
# 114913      Subrahmanyan Chandrasekhar                Victor Francis Hess
# 114914                     dark energy       Pavel Alekseyevich Cherenkov
# 114915                     Gerd Binnig                     standard model
# 114916                    econophysics              electrical conduction
# 114917                        universe                        Gerd Binnig
# 114918                Daniel Chee Tsui  atomic and molecular astrophysics
# 114919                  Wolfgang Pauli                      laser physics
# 114920         gravitational radiation                  Toshihide Maskawa
#
#          value_y
# 0       0.134750
# 1       0.233942
# 2       0.079613
# 3       0.344277
# 4       0.206263
# 5       0.085663
# 6       1.000000
# 7       0.206987
# 8       0.220484
# 9       0.373899
# 10      0.069202
# 11      0.294435
# 12      0.214999
# 13      0.055601
# 14      0.045146
# 15      0.303808
# 16      0.089802
# 17      0.079503
# 18      0.107877
# 19      0.442416
# 20      0.207518
# 21      0.097739
# 22      0.035858
# 23      0.124684
# 24      0.326109
# 25      0.229523
# 26      0.305241
# 27      0.264253
# 28      0.201653
# 29      0.357860
# ...          ...
# 114891  0.061758
# 114892  0.075768
# 114893  0.101425
# 114894  0.315640
# 114895  0.244529
# 114896  0.119661
# 114897  0.073858
# 114898  0.073592
# 114899  0.078168
# 114900  0.487691
# 114901  0.371209
# 114902  0.050535
# 114903  0.212951
# 114904  0.128639
# 114905  0.099335
# 114906  0.377040
# 114907  0.117071
# 114908  0.180698
# 114909  0.111895
# 114910  0.191151
# 114911  0.326214
# 114912  0.144867
# 114913  0.228745
# 114914  0.056948
# 114915  0.109680
# 114916  0.148298
# 114917  0.087374
# 114918  0.043532
# 114919  0.040158
# 114920  0.089641
#
# [114921 rows x 8 columns]

# %% [markdown]
# - ### Find the indices to drop

# %%
index_to_drop = merged_df[["index_x", "index_y"]].apply(max, axis=1).unique()

# %% [markdown]
# - ### Use the index_to_drop to subset the melted_df dataframe

# %%
melted_df_sub =  melted_df.drop(index_to_drop)
melted_df_sub
# Out:
#                                   source                     target     value
# 0                             antimatter    Rudolf Ludwig Mössbauer  0.134750
# 1                    Joseph John Thomson    William Daniel Phillips  0.233942
# 2       nanoscale and mesoscopic physics     physics of computation  0.079613
# 3                             Kip Thorne        gravitation physics  0.344277
# 4                            Peter Higgs   Albert Abraham Michelson  0.206263
# 5                             biophysics        Luis Walter Alvarez  0.085663
# 7                        nuclear physics              Tsung-Dao Lee  0.206987
# 8                        applied physics       Horst Ludwig Störmer  0.220484
# 9                        Georges Charpak         Arthur B. McDonald  0.373899
# 10                    Willis Eugene Lamb      high pressure physics  0.069202
# 11                  neutrino oscillation       nuclear astrophysics  0.294435
# 12                  theory of everything                 Max Planck  0.214999
# 13                        Alfred Kastler                     string  0.055601
# 14                         cosmic string          Robert Hofstadter  0.045146
# 15              Joseph Hooton Taylor Jr.         Simon van der Meer  0.303808
# 16       Patrick Maynard Stuart Blackett                 superfluid  0.089802
# 17                                galaxy      Lev Davidovich Landau  0.079503
# 18                         Wolfgang Paul    quantum electrodynamics  0.107877
# 19                         Frits Zernike    William Daniel Phillips  0.442416
# 20                         Serge Haroche               Enrico Fermi  0.207518
# 21                   Charles Hard Townes       quantum field theory  0.097739
# 22                    John M. Kosterlitz    low-temperature physics  0.035858
# 23                           Abdus Salam                     optics  0.124684
# 24                 Robert Woodrow Wilson    William Daniel Phillips  0.326109
# 25                 William Alfred Fowler                    nuclear  0.229523
# 26                       Herbert Kroemer  William Bradford Shockley  0.305241
# 27                Philip Warren Anderson             Polykarp Kusch  0.264253
# 28                        Charles K. Kao     Edward Victor Appleton  0.201653
# 29                             Leo Esaki        Alexander Prokhorov  0.357860
# 30                    Klaus von Klitzing       stellar astrophysics  0.096349
# ...                                  ...                        ...       ...
# 112482                      econophysics    William Daniel Phillips  0.119236
# 112530                            phonon               Carlo Rubbia  0.143899
# 112540         Pyotr Leonidovich Kapitsa            Steven Weinberg  0.255911
# 112541                              atom             Roy J. Glauber  0.222312
# 112563                    Chen-Ning Yang                 Andre Geim  0.395182
# 112569                        astrometry          materials physics  0.158080
# 112588               engineering physics              semiconductor  0.147767
# 112642                         Aage Bohr    quantum electrodynamics  0.118144
# 112678                        Otto Stern     John Douglas Cockcroft  0.244912
# 112765                        Max Planck                 black hole  0.121911
# 112786                  Owen Chamberlain                     planet  0.053535
# 112922          Hannes Olof Gösta Alfvén             Chen-Ning Yang  0.237159
# 112930                    Roy J. Glauber     quantum chromodynamics  0.210943
# 112963                      solar system           Daniel Chee Tsui  0.043379
# 112974              neutrino oscillation          Martin Lewis Perl  0.169766
# 113093                        Paul Dirac                 bcs theory  0.197078
# 113110                            liquid           Murray Gell-Mann  0.045978
# 113158                         supernova                   molecule  0.126103
# 113268                physical chemistry            Ernest Lawrence  0.093681
# 113316       cosmic background radiation        accelerator physics  0.081196
# 113376              lattice field theory             Polykarp Kusch  0.053599
# 113481                        biophysics            Ernest Lawrence  0.089990
# 113512      Pavel Alekseyevich Cherenkov                      laser  0.077333
# 113685                 self-organization          Guglielmo Marconi  0.194802
# 113818              stellar astrophysics  William Bradford Shockley  0.154772
# 113883                    Polykarp Kusch                 Paul Dirac  0.219942
# 114117             William Alfred Fowler          J. Hans D. Jensen  0.221884
# 114124                 self-organization               Rainer Weiss  0.170083
# 114516                         cosmology     Walter Houser Brattain  0.141388
# 114518           quantum electrodynamics       Karl Ferdinand Braun  0.068746
#
# [57291 rows x 3 columns]

# %% [markdown]
# And now, for every physicist/domain, we keep only the 8 strongest connections. We store this in largest_df, which will be a 2-level multiindex. We capture the values of index 1 and store them in index_to_keep. These store the indices we want to keep in our links_df.
#
# - ### Group melted_df_sub by "source" using the groupby method and select the 8 targets with highest "value."

# %%
largest_df = melted_df_sub.groupby('source')['value'].nlargest(8)

# %% [markdown]
# - ### Get the level 1 of the multiindex

# %%
index_to_keep =  largest_df.index.get_level_values(1)

links_df = melted_df_sub.loc[index_to_keep]
links_df
# Out:
#                           source                                 target  \
# 1514                   Aage Bohr                             Niels Bohr
# 9442                   Aage Bohr                      Ben Roy Mottelson
# 22853                  Aage Bohr                    Leo James Rainwater
# 87695                  Aage Bohr                   Nicolaas Bloembergen
# 32066                  Aage Bohr                           James Franck
# 4246                   Aage Bohr                     Jerome I. Friedman
# 2537                   Aage Bohr                             Andre Geim
# 79156                  Aage Bohr                      David J. Thouless
# 58248                Abdus Salam                             Andre Geim
# 82062                Abdus Salam                   Nicolaas Bloembergen
# 31096                Abdus Salam                  Anthony James Leggett
# 16476                Abdus Salam                       Makoto Kobayashi
# 54470                Abdus Salam                     Arthur B. McDonald
# 32080                Abdus Salam                     Bertram Brockhouse
# 50668                Abdus Salam                        applied physics
# 18331                Abdus Salam                         David J. Gross
# 68030              Adam G. Riess                       Brian P. Schmidt
# 20712              Adam G. Riess                         Takaaki Kajita
# 46781              Adam G. Riess                           Rainer Weiss
# 1967               Adam G. Riess                             Andre Geim
# 18689              Adam G. Riess                      David J. Thouless
# 80502              Adam G. Riess                      Masatoshi Koshiba
# 83223              Adam G. Riess                   Horst Ludwig Störmer
# 14104              Adam G. Riess                     Bertram Brockhouse
# 10658   Albert Abraham Michelson                   Norman Foster Ramsey
# 2074    Albert Abraham Michelson                 John Robert Schrieffer
# 7494    Albert Abraham Michelson                   Nicolaas Bloembergen
# 7029    Albert Abraham Michelson                Percy Williams Bridgman
# 1957    Albert Abraham Michelson                     Jerome I. Friedman
# 29606   Albert Abraham Michelson                Arthur Leonard Schawlow
# ...                          ...                                    ...
# 90078                   universe                            dark matter
# 11830                   universe            cosmic background radiation
# 29298                   universe                   stellar astrophysics
# 16584                   universe                  Robert Woodrow Wilson
# 77118                   universe                             antimatter
# 68931                   universe                     general relativity
# 9325               vacuum energy                         casimir effect
# 3581               vacuum energy                    quantum electronics
# 61255              vacuum energy                        quantum gravity
# 37774              vacuum energy                      quantum chemistry
# 279                vacuum energy                                 photon
# 77097              vacuum energy                       particle physics
# 49577              vacuum energy                         atomic physics
# 12344              vacuum energy                   theory of everything
# 56583           vehicle dynamics                         fluid dynamics
# 103579          vehicle dynamics                      self-organization
# 3406            vehicle dynamics  newton's law of universal gravitation
# 66844           vehicle dynamics                        electromagnetic
# 4692            vehicle dynamics                        polymer physics
# 35220           vehicle dynamics                                    gas
# 5897            vehicle dynamics                       seesaw mechanism
# 89240           vehicle dynamics                                gravity
# 63207                       weak                      fundamental force
# 438                         weak                         standard model
# 104331                      weak               grand unification theory
# 32092                       weak                 quantum chromodynamics
# 4820                        weak                        electromagnetic
# 45722                       weak                          supersymmetry
# 6545                        weak                                 photon
# 44654                       weak                                nuclear
#
#            value
# 1514    0.810448
# 9442    0.640552
# 22853   0.593636
# 87695   0.453569
# 32066   0.451218
# 4246    0.429247
# 2537    0.424991
# 79156   0.403194
# 58248   0.308075
# 82062   0.298805
# 31096   0.287374
# 16476   0.278248
# 54470   0.277586
# 32080   0.274552
# 50668   0.273062
# 18331   0.270705
# 68030   0.645486
# 20712   0.520777
# 46781   0.484632
# 1967    0.456071
# 18689   0.449904
# 80502   0.448067
# 83223   0.442033
# 14104   0.442030
# 10658   0.427161
# 2074    0.414139
# 7494    0.390645
# 7029    0.387713
# 1957    0.386906
# 29606   0.381314
# ...          ...
# 90078   0.530716
# 11830   0.453019
# 29298   0.435193
# 16584   0.423351
# 77118   0.383282
# 68931   0.375835
# 9325    0.552734
# 3581    0.534961
# 61255   0.502574
# 37774   0.486764
# 279     0.411636
# 77097   0.385681
# 49577   0.365748
# 12344   0.347921
# 56583   0.205024
# 103579  0.150124
# 3406    0.129966
# 66844   0.127262
# 4692    0.119139
# 35220   0.113255
# 5897    0.111696
# 89240   0.109826
# 63207   0.653422
# 438     0.572795
# 104331  0.462364
# 32092   0.441070
# 4820    0.365393
# 45722   0.359115
# 6545    0.333775
# 44654   0.315055
#
# [2712 rows x 3 columns]

# %% [markdown]
# Finally, we conver this to a list.
#
# - ### Create the links_list

# %%
links_list =  list(links_df.transpose().to_dict().values())
links_list
# Out:
# [{'source': 'Aage Bohr', 'target': 'Niels Bohr', 'value': 0.810448278052767},
#  {'source': 'Aage Bohr',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.6405523849120306},
#  {'source': 'Aage Bohr',
#   'target': 'Leo James Rainwater',
#   'value': 0.59363610094523},
#  {'source': 'Aage Bohr',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4535685670272227},
#  {'source': 'Aage Bohr',
#   'target': 'James Franck',
#   'value': 0.45121833589128957},
#  {'source': 'Aage Bohr',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4292465753445105},
#  {'source': 'Aage Bohr', 'target': 'Andre Geim', 'value': 0.42499050449712006},
#  {'source': 'Aage Bohr',
#   'target': 'David J. Thouless',
#   'value': 0.4031941944705469},
#  {'source': 'Abdus Salam',
#   'target': 'Andre Geim',
#   'value': 0.3080747544129564},
#  {'source': 'Abdus Salam',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.2988046873651129},
#  {'source': 'Abdus Salam',
#   'target': 'Anthony James Leggett',
#   'value': 0.2873736808741804},
#  {'source': 'Abdus Salam',
#   'target': 'Makoto Kobayashi',
#   'value': 0.2782483997393901},
#  {'source': 'Abdus Salam',
#   'target': 'Arthur B. McDonald',
#   'value': 0.27758636019803823},
#  {'source': 'Abdus Salam',
#   'target': 'Bertram Brockhouse',
#   'value': 0.27455239678574067},
#  {'source': 'Abdus Salam',
#   'target': 'applied physics',
#   'value': 0.27306246847895554},
#  {'source': 'Abdus Salam',
#   'target': 'David J. Gross',
#   'value': 0.27070466074176497},
#  {'source': 'Adam G. Riess',
#   'target': 'Brian P. Schmidt',
#   'value': 0.6454863849564654},
#  {'source': 'Adam G. Riess',
#   'target': 'Takaaki Kajita',
#   'value': 0.5207772102052843},
#  {'source': 'Adam G. Riess',
#   'target': 'Rainer Weiss',
#   'value': 0.4846319684369358},
#  {'source': 'Adam G. Riess',
#   'target': 'Andre Geim',
#   'value': 0.45607120422882125},
#  {'source': 'Adam G. Riess',
#   'target': 'David J. Thouless',
#   'value': 0.44990449128258847},
#  {'source': 'Adam G. Riess',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4480671226616823},
#  {'source': 'Adam G. Riess',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.44203256796817497},
#  {'source': 'Adam G. Riess',
#   'target': 'Bertram Brockhouse',
#   'value': 0.44202961025336784},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.42716073583920816},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'John Robert Schrieffer',
#   'value': 0.4141393847378359},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3906451851652724},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.3877127082715823},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Jerome I. Friedman',
#   'value': 0.38690582924131334},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.3813138133354903},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'William Henry Bragg',
#   'value': 0.37362881987385044},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Riccardo Giacconi',
#   'value': 0.3543603569260332},
#  {'source': 'Albert Einstein',
#   'target': 'general relativity',
#   'value': 0.4799300453445137},
#  {'source': 'Albert Einstein',
#   'target': 'Hendrik Lorentz',
#   'value': 0.3887843043655804},
#  {'source': 'Albert Einstein',
#   'target': 'Philipp Eduard Anton von Lenard',
#   'value': 0.35923015297389727},
#  {'source': 'Albert Einstein',
#   'target': 'bose-einstein condensate',
#   'value': 0.3562091882570032},
#  {'source': 'Albert Einstein',
#   'target': 'Erwin Schrödinger',
#   'value': 0.3409360896152489},
#  {'source': 'Albert Einstein',
#   'target': 'photon',
#   'value': 0.3348426352022729},
#  {'source': 'Albert Einstein',
#   'target': 'gravitation physics',
#   'value': 0.3272014353222132},
#  {'source': 'Albert Einstein',
#   'target': 'gravity',
#   'value': 0.3272014353222132},
#  {'source': 'Albert Fert',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.642140140670525},
#  {'source': 'Albert Fert',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.579196975812144},
#  {'source': 'Albert Fert',
#   'target': 'François Englert',
#   'value': 0.5541382409026833},
#  {'source': 'Albert Fert',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5283192924055856},
#  {'source': 'Albert Fert',
#   'target': 'Joseph Hooton Taylor Jr.',
#   'value': 0.5275152584413341},
#  {'source': 'Albert Fert',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5111390539141498},
#  {'source': 'Albert Fert',
#   'target': 'Raymond Davis Jr.',
#   'value': 0.5110778584471206},
#  {'source': 'Albert Fert',
#   'target': 'Herbert Kroemer',
#   'value': 0.4789862561742688},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Zhores Ivanovich Alferov',
#   'value': 0.5574927212442855},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Vitaly Lazarevich Ginzburg',
#   'value': 0.5081023949297363},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Alexei Alexeyevich Abrikosov',
#   'value': 0.4752197175044719},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Konstantin Novoselov',
#   'value': 0.44227095355034707},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.43889925722347767},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Pyotr Leonidovich Kapitsa',
#   'value': 0.43511395934963526},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Manne Siegbahn',
#   'value': 0.43174052132236806},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Hiroshi Amano',
#   'value': 0.4248030232064144},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Zhores Ivanovich Alferov',
#   'value': 0.5568534446575352},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Clifford Glenwood Shull',
#   'value': 0.5077019849930063},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4865067719424451},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.4795831927409621},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'John L. Hall',
#   'value': 0.4547076528459126},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Albert Fert',
#   'value': 0.45126590902415337},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Eric Allin Cornell',
#   'value': 0.4495159448591846},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Hiroshi Amano',
#   'value': 0.429533596818939},
#  {'source': 'Alfred Kastler',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5581663174257308},
#  {'source': 'Alfred Kastler',
#   'target': 'Manne Siegbahn',
#   'value': 0.4972912980725862},
#  {'source': 'Alfred Kastler',
#   'target': 'Claude Cohen-Tannoudji',
#   'value': 0.49520655523781226},
#  {'source': 'Alfred Kastler',
#   'target': 'Frits Zernike',
#   'value': 0.4804073794278413},
#  {'source': 'Alfred Kastler',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.46564339329009713},
#  {'source': 'Alfred Kastler',
#   'target': 'Bertram Brockhouse',
#   'value': 0.46021991273779544},
#  {'source': 'Alfred Kastler',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.45535658590621975},
#  {'source': 'Alfred Kastler',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.44446135559810046},
#  {'source': 'Andre Geim',
#   'target': 'Konstantin Novoselov',
#   'value': 0.814499816300351},
#  {'source': 'Andre Geim',
#   'target': 'Takaaki Kajita',
#   'value': 0.6396310673398556},
#  {'source': 'Andre Geim',
#   'target': 'Isamu Akasaki',
#   'value': 0.571175177319079},
#  {'source': 'Andre Geim',
#   'target': 'Manne Siegbahn',
#   'value': 0.5529235447166196},
#  {'source': 'Andre Geim',
#   'target': 'John L. Hall',
#   'value': 0.5445442046211095},
#  {'source': 'Andre Geim',
#   'target': 'Barry Barish',
#   'value': 0.5385385704880454},
#  {'source': 'Andre Geim',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5352353208724334},
#  {'source': 'Andre Geim',
#   'target': 'Toshihide Maskawa',
#   'value': 0.5109685807649855},
#  {'source': 'Anthony James Leggett',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5265900009314289},
#  {'source': 'Anthony James Leggett',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.5120155881493494},
#  {'source': 'Anthony James Leggett',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.496331991779346},
#  {'source': 'Anthony James Leggett',
#   'target': 'Alexei Alexeyevich Abrikosov',
#   'value': 0.47687650882857835},
#  {'source': 'Anthony James Leggett',
#   'target': 'David Morris Lee',
#   'value': 0.4737654794752868},
#  {'source': 'Anthony James Leggett',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.463440824998251},
#  {'source': 'Anthony James Leggett',
#   'target': 'Eric Allin Cornell',
#   'value': 0.4623265146083381},
#  {'source': 'Anthony James Leggett',
#   'target': 'Andre Geim',
#   'value': 0.4616441217712052},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Pierre Curie',
#   'value': 0.352821670514508},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Maria Skłodowska-Curie',
#   'value': 0.3260729934093572},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'value': 0.24943661906512815},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.24430870636983035},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Joseph John Thomson',
#   'value': 0.23787094631248273},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Victor Francis Hess',
#   'value': 0.23723639205327884},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Clinton Joseph Davisson',
#   'value': 0.23546340843493554},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Carl David Anderson',
#   'value': 0.23541408335874695},
#  {'source': 'Antony Hewish',
#   'target': 'Martin Ryle',
#   'value': 0.5561003903915737},
#  {'source': 'Antony Hewish',
#   'target': 'Charles Glover Barkla',
#   'value': 0.48075462237781474},
#  {'source': 'Antony Hewish',
#   'target': 'Owen Willans Richardson',
#   'value': 0.46520063776081655},
#  {'source': 'Antony Hewish',
#   'target': 'Manne Siegbahn',
#   'value': 0.4620992240870424},
#  {'source': 'Antony Hewish',
#   'target': 'Andre Geim',
#   'value': 0.4539605703682614},
#  {'source': 'Antony Hewish',
#   'target': 'Bertram Brockhouse',
#   'value': 0.44886910502529115},
#  {'source': 'Antony Hewish',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.43719975632484875},
#  {'source': 'Antony Hewish',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.43570031970558004},
#  {'source': 'Arno Allan Penzias',
#   'target': 'George F. Smoot',
#   'value': 0.512883208871772},
#  {'source': 'Arno Allan Penzias',
#   'target': 'big bang',
#   'value': 0.44894935483284043},
#  {'source': 'Arno Allan Penzias',
#   'target': 'John C. Mather',
#   'value': 0.41416241982978574},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Brian P. Schmidt',
#   'value': 0.37128547589558514},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3439379708089851},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3436419033607689},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Antony Hewish',
#   'value': 0.3262578704048972},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Henry Way Kendall',
#   'value': 0.32316291023257365},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Takaaki Kajita',
#   'value': 0.6566701241027727},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Andre Geim',
#   'value': 0.5224878542277943},
#  {'source': 'Arthur B. McDonald',
#   'target': 'David J. Thouless',
#   'value': 0.5134506623932424},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Konstantin Novoselov',
#   'value': 0.4910930155175294},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4887101838020714},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Manne Siegbahn',
#   'value': 0.485082870718298},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Frederick Reines',
#   'value': 0.4795162652562038},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Hiroshi Amano',
#   'value': 0.4671331629666994},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.38467772958998725},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Robert Hofstadter',
#   'value': 0.3758212690486976},
#  {'source': 'Arthur Holly Compton',
#   'target': 'James Franck',
#   'value': 0.37075373001113504},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Enrico Fermi',
#   'value': 0.3556496195011407},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3451491729226735},
#  {'source': 'Arthur Holly Compton',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.33648489085805516},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Arthur B. McDonald',
#   'value': 0.32524191612791825},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Hans Albrecht Bethe',
#   'value': 0.31943660346829866},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Charles Hard Townes',
#   'value': 0.5481328114385086},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'John Robert Schrieffer',
#   'value': 0.5084540489380397},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4974038920325456},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4632662058010153},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.44647830264600374},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'William Alfred Fowler',
#   'value': 0.43737915307846537},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Burton Richter',
#   'value': 0.4254542339320158},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Barry Barish',
#   'value': 0.4167467871686411},
#  {'source': 'Barry Barish',
#   'target': 'Rainer Weiss',
#   'value': 0.5571516018425818},
#  {'source': 'Barry Barish',
#   'target': 'Jerome I. Friedman',
#   'value': 0.49423999310569977},
#  {'source': 'Barry Barish',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4758522604055207},
#  {'source': 'Barry Barish',
#   'target': 'Konstantin Novoselov',
#   'value': 0.46875461531210166},
#  {'source': 'Barry Barish',
#   'target': 'Riccardo Giacconi',
#   'value': 0.46657277513764067},
#  {'source': 'Barry Barish',
#   'target': 'John L. Hall',
#   'value': 0.4625461298686179},
#  {'source': 'Barry Barish',
#   'target': 'Hiroshi Amano',
#   'value': 0.45674466076326325},
#  {'source': 'Barry Barish',
#   'target': 'Leon Max Lederman',
#   'value': 0.450266705259322},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.6029180872187955},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Manne Siegbahn',
#   'value': 0.5642880861775493},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5443703409737858},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Leo James Rainwater',
#   'value': 0.539827902481032},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Hiroshi Amano',
#   'value': 0.5310748645434848},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5255504543284085},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5217139246036256},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Andre Geim',
#   'value': 0.5201205144560342},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.6018356366178196},
#  {'source': 'Bertram Brockhouse',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5963901860083175},
#  {'source': 'Bertram Brockhouse',
#   'target': 'David J. Thouless',
#   'value': 0.5813343338114578},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5807729333039418},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Andre Geim',
#   'value': 0.5753238604259848},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Arthur B. McDonald',
#   'value': 0.5701683952010196},
#  {'source': 'Bertram Brockhouse',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.565616190963196},
#  {'source': 'Bertram Brockhouse',
#   'target': 'David Morris Lee',
#   'value': 0.5622695107820743},
#  {'source': 'Brian David Josephson',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.4048678484404275},
#  {'source': 'Brian David Josephson',
#   'target': 'condensed matter physics',
#   'value': 0.4036790097055399},
#  {'source': 'Brian David Josephson',
#   'target': 'David J. Thouless',
#   'value': 0.3926649677296373},
#  {'source': 'Brian David Josephson',
#   'target': 'Hiroshi Amano',
#   'value': 0.3868778025396071},
#  {'source': 'Brian David Josephson',
#   'target': 'John M. Kosterlitz',
#   'value': 0.37046628666331705},
#  {'source': 'Brian David Josephson',
#   'target': 'Arthur B. McDonald',
#   'value': 0.369141152110815},
#  {'source': 'Brian David Josephson',
#   'target': 'Frank Wilczek',
#   'value': 0.367971918131809},
#  {'source': 'Brian David Josephson',
#   'target': 'Leon Neil Cooper',
#   'value': 0.3674884027318756},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Saul Perlmutter',
#   'value': 0.6116828013550375},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Andre Geim',
#   'value': 0.48298460405887855},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Takaaki Kajita',
#   'value': 0.48229839731670693},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Arthur B. McDonald',
#   'value': 0.4190899898519139},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Rainer Weiss',
#   'value': 0.41810423316722545},
#  {'source': 'Brian P. Schmidt',
#   'target': 'David J. Thouless',
#   'value': 0.4016222680129085},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Bertram Brockhouse',
#   'value': 0.39661932154287294},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.38876493873276546},
#  {'source': 'Burton Richter',
#   'target': 'Richard E. Taylor',
#   'value': 0.5147889298101895},
#  {'source': 'Burton Richter',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.482028567205932},
#  {'source': 'Burton Richter',
#   'target': 'Frederick Reines',
#   'value': 0.4737162910011402},
#  {'source': 'Burton Richter',
#   'target': 'John Robert Schrieffer',
#   'value': 0.47358431348100183},
#  {'source': 'Burton Richter',
#   'target': 'Melvin Schwartz',
#   'value': 0.4681162728265203},
#  {'source': 'Burton Richter',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4636315791143707},
#  {'source': 'Burton Richter',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4393700899596247},
#  {'source': 'Burton Richter',
#   'target': 'Edward Mills Purcell',
#   'value': 0.43539283618996233},
#  {'source': 'Carl David Anderson',
#   'target': 'Philip Warren Anderson',
#   'value': 0.5950101537732649},
#  {'source': 'Carl David Anderson',
#   'target': 'Victor Francis Hess',
#   'value': 0.467297069624968},
#  {'source': 'Carl David Anderson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.4569929215769673},
#  {'source': 'Carl David Anderson',
#   'target': 'Hugh David Politzer',
#   'value': 0.4472139775873334},
#  {'source': 'Carl David Anderson',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.44414272341650357},
#  {'source': 'Carl David Anderson',
#   'target': 'David Morris Lee',
#   'value': 0.4411390579169741},
#  {'source': 'Carl David Anderson',
#   'target': 'Eric Allin Cornell',
#   'value': 0.425595943533534},
#  {'source': 'Carl David Anderson',
#   'target': 'Melvin Schwartz',
#   'value': 0.41620676703743753},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Eric Allin Cornell',
#   'value': 0.6842633857682008},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Wolfgang Ketterle',
#   'value': 0.5055283492818826},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Herbert Kroemer',
#   'value': 0.4747310243874533},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4741028098181949},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'George E. Smith',
#   'value': 0.46966470125399445},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'William Daniel Phillips',
#   'value': 0.4685568681022829},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'David Morris Lee',
#   'value': 0.4580401316023685},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Robert B. Laughlin',
#   'value': 0.4506748122092078},
#  {'source': 'Carlo Rubbia',
#   'target': 'particle physics',
#   'value': 0.3893714320040906},
#  {'source': 'Carlo Rubbia',
#   'target': 'Melvin Schwartz',
#   'value': 0.3873782917514997},
#  {'source': 'Carlo Rubbia',
#   'target': 'Makoto Kobayashi',
#   'value': 0.3605397630875766},
#  {'source': 'Carlo Rubbia',
#   'target': 'Richard E. Taylor',
#   'value': 0.35229417102006144},
#  {'source': 'Carlo Rubbia',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3518066254560939},
#  {'source': 'Carlo Rubbia',
#   'target': 'Sheldon Lee Glashow',
#   'value': 0.35034015605958824},
#  {'source': 'Carlo Rubbia',
#   'target': 'Roy J. Glauber',
#   'value': 0.3444298733887213},
#  {'source': 'Carlo Rubbia',
#   'target': 'Leo James Rainwater',
#   'value': 0.3341154143656549},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.4618856343890469},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Manne Siegbahn',
#   'value': 0.43834466506529984},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Ilya Frank',
#   'value': 0.4352104555579897},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Georges Charpak',
#   'value': 0.4259916560770282},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4163269881414931},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4159129485650721},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Hiroshi Amano',
#   'value': 0.4015329935211675},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Konstantin Novoselov',
#   'value': 0.3936237025830811},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Andre Geim',
#   'value': 0.3576647550326891},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Manne Siegbahn',
#   'value': 0.33508160560225414},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Takaaki Kajita',
#   'value': 0.33060949573761916},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Isamu Akasaki',
#   'value': 0.3258504070141591},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.3166337900583741},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3083382900016861},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Bertram Brockhouse',
#   'value': 0.3059282806092719},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Frits Zernike',
#   'value': 0.3034364225557623},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Charles Thomson Rees Wilson',
#   'value': 0.5078890518246727},
#  {'source': 'Charles Glover Barkla',
#   'target': 'George Paget Thomson',
#   'value': 0.4917410388320145},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Riccardo Giacconi',
#   'value': 0.48167770522628106},
#  {'source': 'Charles Glover Barkla',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4807689397830212},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Anthony James Leggett',
#   'value': 0.44932544307429895},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4490371988067506},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.44296885773250205},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Karl Alexander Müller',
#   'value': 0.4400148792570958},
#  {'source': 'Charles Hard Townes',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4808340389341334},
#  {'source': 'Charles Hard Townes',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.4439788861025598},
#  {'source': 'Charles Hard Townes',
#   'target': 'Yoichiro Nambu',
#   'value': 0.43823234446705134},
#  {'source': 'Charles Hard Townes',
#   'target': 'Frederick Reines',
#   'value': 0.4263959958443213},
#  {'source': 'Charles Hard Townes',
#   'target': 'John Robert Schrieffer',
#   'value': 0.424386631188605},
#  {'source': 'Charles Hard Townes',
#   'target': 'Edward Mills Purcell',
#   'value': 0.42089819941089096},
#  {'source': 'Charles Hard Townes',
#   'target': 'John Bardeen',
#   'value': 0.4139553866174617},
#  {'source': 'Charles Hard Townes',
#   'target': 'Arthur B. McDonald',
#   'value': 0.4047954513755279},
#  {'source': 'Charles K. Kao',
#   'target': 'Andre Geim',
#   'value': 0.5459414384817108},
#  {'source': 'Charles K. Kao',
#   'target': 'Shuji Nakamura',
#   'value': 0.41344699462362305},
#  {'source': 'Charles K. Kao',
#   'target': 'Takaaki Kajita',
#   'value': 0.4110417821937228},
#  {'source': 'Charles K. Kao',
#   'target': 'David J. Thouless',
#   'value': 0.40659866713555526},
#  {'source': 'Charles K. Kao',
#   'target': 'Chen-Ning Yang',
#   'value': 0.4013827611195898},
#  {'source': 'Charles K. Kao',
#   'target': 'Dennis Gabor',
#   'value': 0.3934767516553818},
#  {'source': 'Charles K. Kao',
#   'target': 'Arthur B. McDonald',
#   'value': 0.39238457150538375},
#  {'source': 'Charles K. Kao',
#   'target': 'Charles Hard Townes',
#   'value': 0.37749070365602766},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Kenneth G. Wilson',
#   'value': 0.5598828719157912},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'George Paget Thomson',
#   'value': 0.4401241932457194},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4151782593001294},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Antony Hewish',
#   'value': 0.383221238509914},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Joseph John Thomson',
#   'value': 0.3800125467422367},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3679461492508085},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Cecil Frank Powell',
#   'value': 0.3618292846921121},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'William Lawrence Bragg',
#   'value': 0.35807679425756606},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Jean Baptiste Perrin',
#   'value': 0.3582740179627275},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Robert B. Laughlin',
#   'value': 0.3453351851410693},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Manne Siegbahn',
#   'value': 0.3200391317350134},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Alfred Kastler',
#   'value': 0.31356621825871245},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Georges Charpak',
#   'value': 0.30743992450285},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'value': 0.30649329535077247},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Johannes Georg Bednorz',
#   'value': 0.30181064357485177},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'William Daniel Phillips',
#   'value': 0.29702841986740136},
#  {'source': 'Chen-Ning Yang',
#   'target': 'David J. Wineland',
#   'value': 0.6437133250094983},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Yoichiro Nambu',
#   'value': 0.6411160178206032},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.6116739234143432},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Frederick Reines',
#   'value': 0.5792240224936562},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.5728878171804912},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Samuel Chao Chung Ting',
#   'value': 0.5224688445554119},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.4662418110085001},
#  {'source': 'Chen-Ning Yang',
#   'target': 'Jerome I. Friedman',
#   'value': 0.46618015326559686},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5105008663220438},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4957706142879559},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'John L. Hall',
#   'value': 0.4915900812618135},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Manne Siegbahn',
#   'value': 0.4854618883052958},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.4838786707129734},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.4773634465469157},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Albert Fert',
#   'value': 0.47708778727727397},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.46831968012344033},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Bertram Brockhouse',
#   'value': 0.624215403006162},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Melvin Schwartz',
#   'value': 0.5499816822358088},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Robert Hofstadter',
#   'value': 0.5175915044815065},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'John L. Hall',
#   'value': 0.510743466826236},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5089686587890485},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'George E. Smith',
#   'value': 0.4855355950680079},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'David J. Thouless',
#   'value': 0.4794872039909573},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Raymond Davis Jr.',
#   'value': 0.4792655935477164},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5369822543608174},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Manne Siegbahn',
#   'value': 0.5034528439529568},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.49720968386109915},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.4963372506166797},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Bertram Brockhouse',
#   'value': 0.47715278951778445},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.47528160245666107},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Hiroshi Amano',
#   'value': 0.4642588969732838},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'David Morris Lee',
#   'value': 0.4638142603804553},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.7458128857472237},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Robert B. Laughlin',
#   'value': 0.6381304181256817},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.6191178501790149},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'David Morris Lee',
#   'value': 0.5946844498820603},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5907031451700716},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.5844483579921894},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Herbert Kroemer',
#   'value': 0.569051599295179},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'John L. Hall',
#   'value': 0.5465071691789827},
#  {'source': 'David J. Gross',
#   'target': 'Hugh David Politzer',
#   'value': 0.6000870446313903},
#  {'source': 'David J. Gross',
#   'target': 'Frank Wilczek',
#   'value': 0.5918754561202937},
#  {'source': 'David J. Gross',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5068901816907007},
#  {'source': 'David J. Gross',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.4912349328475293},
#  {'source': 'David J. Gross',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4856871120181061},
#  {'source': 'David J. Gross',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4845063852649304},
#  {'source': 'David J. Gross',
#   'target': 'Clifford Glenwood Shull',
#   'value': 0.47860668527397743},
#  {'source': 'David J. Gross',
#   'target': 'François Englert',
#   'value': 0.4664512973849644},
#  {'source': 'David J. Thouless',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.6486088522703576},
#  {'source': 'David J. Thouless',
#   'target': 'Andre Geim',
#   'value': 0.596843665787193},
#  {'source': 'David J. Thouless',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5782483047599212},
#  {'source': 'David J. Thouless',
#   'target': 'François Englert',
#   'value': 0.5636959100290923},
#  {'source': 'David J. Thouless',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.5542868093269131},
#  {'source': 'David J. Thouless',
#   'target': 'Albert Fert',
#   'value': 0.5427677977863036},
#  {'source': 'David J. Thouless',
#   'target': 'Anthony James Leggett',
#   'value': 0.540122155149695},
#  {'source': 'David J. Thouless',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5326566552412186},
#  {'source': 'David J. Wineland',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.7118741079486626},
#  {'source': 'David J. Wineland',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5350222339613722},
#  {'source': 'David J. Wineland',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.5261882364150043},
#  {'source': 'David J. Wineland',
#   'target': 'John Robert Schrieffer',
#   'value': 0.5219927061395718},
#  {'source': 'David J. Wineland',
#   'target': 'Edward Mills Purcell',
#   'value': 0.514859763813245},
#  {'source': 'David J. Wineland',
#   'target': 'John L. Hall',
#   'value': 0.5110318825862968},
#  {'source': 'David J. Wineland',
#   'target': 'Serge Haroche',
#   'value': 0.4862705546282803},
#  {'source': 'David J. Wineland',
#   'target': 'David J. Thouless',
#   'value': 0.4851253695977183},
#  {'source': 'David Morris Lee',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.7597507309488302},
#  {'source': 'David Morris Lee',
#   'target': 'Tsung-Dao Lee',
#   'value': 0.6260401532494378},
#  {'source': 'David Morris Lee',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5934937333425877},
#  {'source': 'David Morris Lee',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5560732896577589},
#  {'source': 'David Morris Lee',
#   'target': 'David J. Thouless',
#   'value': 0.5549082794865857},
#  {'source': 'David Morris Lee',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5539696497111302},
#  {'source': 'David Morris Lee',
#   'target': 'George E. Smith',
#   'value': 0.5528848709712457},
#  {'source': 'David Morris Lee',
#   'target': 'Riccardo Giacconi',
#   'value': 0.5448213297022136},
#  {'source': 'Dennis Gabor',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4517702293861822},
#  {'source': 'Dennis Gabor',
#   'target': 'Manne Siegbahn',
#   'value': 0.4479221504817113},
#  {'source': 'Dennis Gabor',
#   'target': 'Andre Geim',
#   'value': 0.44735978506218815},
#  {'source': 'Dennis Gabor',
#   'target': 'Bertram Brockhouse',
#   'value': 0.44243128546847915},
#  {'source': 'Dennis Gabor',
#   'target': 'Konstantin Novoselov',
#   'value': 0.4422669930513057},
#  {'source': 'Dennis Gabor',
#   'target': 'Frits Zernike',
#   'value': 0.4342056841402725},
#  {'source': 'Dennis Gabor',
#   'target': 'Antony Hewish',
#   'value': 0.423171336053631},
#  {'source': 'Dennis Gabor',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4165623565719876},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.3872285579503558},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Hiroshi Amano',
#   'value': 0.38126068617237757},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.3774574844723338},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'David J. Wineland',
#   'value': 0.37300345363955584},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Carl David Anderson',
#   'value': 0.36757362010865763},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'John Robert Schrieffer',
#   'value': 0.36600994445569635},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Manne Siegbahn',
#   'value': 0.36516037529248235},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Leo James Rainwater',
#   'value': 0.3549698325655003},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'David Morris Lee',
#   'value': 0.7864637950194773},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.6217698174196143},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5933182720090049},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5887667451983277},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Robert B. Laughlin',
#   'value': 0.5832018792347333},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Hugh David Politzer',
#   'value': 0.5760142210865494},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Riccardo Giacconi',
#   'value': 0.572675006310624},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5595158147712683},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.5378619176439479},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5188779240788552},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.4881915586567958},
#  {'source': 'Edward Mills Purcell',
#   'target': 'John Hasbrouck Van Vleck',
#   'value': 0.47200006151980334},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.45530006887386204},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Chen-Ning Yang',
#   'value': 0.4450534056196336},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Leo James Rainwater',
#   'value': 0.42871264566935036},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.41463252138855033},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Charles Glover Barkla',
#   'value': 0.33246254377302936},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Dennis Gabor',
#   'value': 0.3159299719918566},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Manne Siegbahn',
#   'value': 0.3100595868329013},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Theodor W. Hänsch',
#   'value': 0.301042314823511},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Edward Mills Purcell',
#   'value': 0.29801136638221276},
#  {'source': 'Edward Victor Appleton',
#   'target': 'William Lawrence Bragg',
#   'value': 0.2955402048810893},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.2947577562033572},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Frits Zernike',
#   'value': 0.29465903547348016},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Leo James Rainwater',
#   'value': 0.38588381625592993},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.35761735436110115},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'James Franck',
#   'value': 0.34509019156093323},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.3430200326038897},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'James Chadwick',
#   'value': 0.33800265086666303},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Aage Bohr',
#   'value': 0.3280560976720735},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Melvin Schwartz',
#   'value': 0.3213405513103149},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Hans Albrecht Bethe',
#   'value': 0.31902869450332333},
#  {'source': 'Enrico Fermi',
#   'target': 'Emilio Gino Segrè',
#   'value': 0.4402684239572988},
#  {'source': 'Enrico Fermi',
#   'target': 'Leo James Rainwater',
#   'value': 0.4273706190581457},
#  {'source': 'Enrico Fermi',
#   'target': 'James Chadwick',
#   'value': 0.39154267711915997},
#  {'source': 'Enrico Fermi',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.35710268366640363},
#  {'source': 'Enrico Fermi',
#   'target': 'Hans Albrecht Bethe',
#   'value': 0.35697668018797424},
#  {'source': 'Enrico Fermi',
#   'target': 'Robert Hofstadter',
#   'value': 0.3457902502090742},
#  {'source': 'Enrico Fermi',
#   'target': 'Maria Goeppert-Mayer',
#   'value': 0.34103386543281305},
#  {'source': 'Enrico Fermi',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.33870577248067035},
#  {'source': 'Eric Allin Cornell',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.6125639210475442},
#  {'source': 'Eric Allin Cornell',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.583577150614078},
#  {'source': 'Eric Allin Cornell',
#   'target': 'David Morris Lee',
#   'value': 0.5819585229887082},
#  {'source': 'Eric Allin Cornell',
#   'target': 'Wolfgang Ketterle',
#   'value': 0.573669876309711},
#  {'source': 'Eric Allin Cornell',
#   'target': 'William Daniel Phillips',
#   'value': 0.559983703014498},
#  {'source': 'Eric Allin Cornell',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5438913543593552},
#  {'source': 'Eric Allin Cornell',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5384821370605102},
#  {'source': 'Eric Allin Cornell',
#   'target': 'Hugh David Politzer',
#   'value': 0.5383794083413163},
#  {'source': 'Ernest Lawrence',
#   'target': 'Emilio Gino Segrè',
#   'value': 0.4465276148534846},
#  {'source': 'Ernest Lawrence',
#   'target': 'Frederick Reines',
#   'value': 0.36926168339760373},
#  {'source': 'Ernest Lawrence',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.3609356568924515},
#  {'source': 'Ernest Lawrence',
#   'target': 'Arthur Holly Compton',
#   'value': 0.3531369171745938},
#  {'source': 'Ernest Lawrence',
#   'target': 'Enrico Fermi',
#   'value': 0.34536883956670356},
#  {'source': 'Ernest Lawrence',
#   'target': 'James Franck',
#   'value': 0.34224361832155487},
#  {'source': 'Ernest Lawrence',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.3232759258573955},
#  {'source': 'Ernest Lawrence',
#   'target': 'Isamu Akasaki',
#   'value': 0.3082755730284936},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.4078476558654549},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Owen Willans Richardson',
#   'value': 0.3296582737214578},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Dennis Gabor',
#   'value': 0.3175340091403079},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Hiroshi Amano',
#   'value': 0.3149308450303657},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Jerome I. Friedman',
#   'value': 0.3119935221413592},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Anthony James Leggett',
#   'value': 0.3114379562133938},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.311203476606732},
#  {'source': 'Ernest Thomas Sinton Walton',
#   'target': 'George Paget Thomson',
#   'value': 0.3057605311287115},
#  {'source': 'Ernst Ruska',
#   'target': 'Heinrich Rohrer',
#   'value': 0.5216424258991185},
#  {'source': 'Ernst Ruska',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.4696798813659331},
#  {'source': 'Ernst Ruska',
#   'target': 'Bertram Brockhouse',
#   'value': 0.45321018890636616},
#  {'source': 'Ernst Ruska',
#   'target': 'Gerd Binnig',
#   'value': 0.45314533687659114},
#  {'source': 'Ernst Ruska',
#   'target': 'Clinton Joseph Davisson',
#   'value': 0.4465681875808324},
#  {'source': 'Ernst Ruska',
#   'target': 'Toshihide Maskawa',
#   'value': 0.44239948680273616},
#  {'source': 'Ernst Ruska',
#   'target': 'Herbert Kroemer',
#   'value': 0.441299894216403},
#  {'source': 'Ernst Ruska',
#   'target': 'Martin Lewis Perl',
#   'value': 0.4370245832735839},
#  {'source': 'Erwin Schrödinger',
#   'target': 'Paul Dirac',
#   'value': 0.4079974498807712},
#  {'source': 'Erwin Schrödinger',
#   'target': 'Anthony James Leggett',
#   'value': 0.3706526426220658},
#  {'source': 'Erwin Schrödinger',
#   'target': 'Max Born',
#   'value': 0.3459717886328004},
#  {'source': 'Erwin Schrödinger',
#   'target': 'atomic physics',
#   'value': 0.32375511575674804},
#  {'source': 'Erwin Schrödinger',
#   'target': 'theory of everything',
#   'value': 0.321054123657042},
#  {'source': 'Erwin Schrödinger',
#   'target': 'Julian Schwinger',
#   'value': 0.3205322987448519},
#  {'source': 'Erwin Schrödinger',
#   'target': 'Steven Weinberg',
#   'value': 0.3204492242875234},
#  {'source': 'Erwin Schrödinger',
#   'target': 'condensed matter physics',
#   'value': 0.3186077070894034},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.5426458137804575},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Frederick Reines',
#   'value': 0.5158862770704252},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Leo James Rainwater',
#   'value': 0.43719044653039163},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'John Robert Schrieffer',
#   'value': 0.42971206953783647},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'John Hasbrouck Van Vleck',
#   'value': 0.3823912728344444},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Isidor Isaac Rabi',
#   'value': 0.37227610222156426},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3677684654348534},
#  {'source': 'Eugene Paul Wigner',
#   'target': 'Aage Bohr',
#   'value': 0.3645284835412657},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'John M. Kosterlitz',
#   'value': 0.6397722453500327},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5195830633332392},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Andre Geim',
#   'value': 0.5167102107664697},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.49865049421759833},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'John L. Hall',
#   'value': 0.4973043404036555},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Eric Allin Cornell',
#   'value': 0.4948130252263709},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Robert B. Laughlin',
#   'value': 0.4936407703723793},
#  {'source': 'F. Duncan M. Haldane',
#   'target': 'Roy J. Glauber',
#   'value': 0.48980125301606214},
#  {'source': 'Felix Bloch',
#   'target': 'Edward Mills Purcell',
#   'value': 0.5097802768097411},
#  {'source': 'Felix Bloch',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4792782610523144},
#  {'source': 'Felix Bloch',
#   'target': 'John Robert Schrieffer',
#   'value': 0.47039838364030245},
#  {'source': 'Felix Bloch',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.45322265609334517},
#  {'source': 'Felix Bloch',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.43321671814102736},
#  {'source': 'Felix Bloch',
#   'target': 'Burton Richter',
#   'value': 0.4316445149399733},
#  {'source': 'Felix Bloch',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.42031761841065807},
#  {'source': 'Felix Bloch',
#   'target': 'Yoichiro Nambu',
#   'value': 0.4028780834369242},
#  {'source': 'Frank Wilczek',
#   'target': 'Hugh David Politzer',
#   'value': 0.5183274221904552},
#  {'source': 'Frank Wilczek',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.4611515923661224},
#  {'source': 'Frank Wilczek',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.43959527429808387},
#  {'source': 'Frank Wilczek',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4384332660332729},
#  {'source': 'Frank Wilczek',
#   'target': 'François Englert',
#   'value': 0.4363175143598819},
#  {'source': 'Frank Wilczek',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4343194229822057},
#  {'source': 'Frank Wilczek',
#   'target': 'David Morris Lee',
#   'value': 0.433792679572328},
#  {'source': 'Frank Wilczek',
#   'target': 'Anthony James Leggett',
#   'value': 0.4183466854664643},
#  {'source': 'François Englert',
#   'target': 'Peter Higgs',
#   'value': 0.6344755554436453},
#  {'source': 'François Englert',
#   'target': 'Riccardo Giacconi',
#   'value': 0.5773749888588573},
#  {'source': 'François Englert',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.56966643352858},
#  {'source': 'François Englert',
#   'target': 'Andre Geim',
#   'value': 0.5212608850208794},
#  {'source': 'François Englert',
#   'target': 'Takaaki Kajita',
#   'value': 0.5184144231365736},
#  {'source': 'François Englert',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5164155057720502},
#  {'source': 'François Englert',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.507598393005219},
#  {'source': 'François Englert',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5075642370328594},
#  {'source': 'Frederick Reines',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.6749336396051987},
#  {'source': 'Frederick Reines',
#   'target': 'David J. Wineland',
#   'value': 0.6648581217418738},
#  {'source': 'Frederick Reines',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.6010948241576911},
#  {'source': 'Frederick Reines',
#   'target': 'John Robert Schrieffer',
#   'value': 0.4928121114852262},
#  {'source': 'Frederick Reines',
#   'target': 'Edward Mills Purcell',
#   'value': 0.477240323847415},
#  {'source': 'Frederick Reines',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.47369436533564435},
#  {'source': 'Frederick Reines',
#   'target': 'Takaaki Kajita',
#   'value': 0.44201755535089},
#  {'source': 'Frederick Reines',
#   'target': 'John Bardeen',
#   'value': 0.43287721934051293},
#  {'source': 'Frits Zernike',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.5362990634648829},
#  {'source': 'Frits Zernike',
#   'target': 'Simon van der Meer',
#   'value': 0.5329262793152894},
#  {'source': 'Frits Zernike',
#   'target': 'Toshihide Maskawa',
#   'value': 0.5139832218354036},
#  {'source': 'Frits Zernike',
#   'target': 'John L. Hall',
# ...
#   'target': 'Masatoshi Koshiba',
#   'value': 0.507256151462843},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.488562942284756},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'David J. Thouless',
#   'value': 0.4847743418186982},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.47991155138042724},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4764771919665425},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'Raymond Davis Jr.',
#   'value': 0.46631154814436737},
#  {'source': 'Joseph Hooton Taylor Jr.',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4642141390792971},
#  {'source': 'Joseph John Thomson',
#   'target': 'Nevill Francis Mott',
#   'value': 0.2852526836606777},
#  {'source': 'Joseph John Thomson',
#   'target': 'James Chadwick',
#   'value': 0.2665848905835783},
#  {'source': 'Joseph John Thomson',
#   'target': 'David J. Wineland',
#   'value': 0.26258442583918645},
#  {'source': 'Joseph John Thomson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.2622999579853629},
#  {'source': 'Joseph John Thomson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.2582369151072299},
#  {'source': 'Joseph John Thomson',
#   'target': 'Dennis Gabor',
#   'value': 0.2576594731144758},
#  {'source': 'Joseph John Thomson',
#   'target': 'Clinton Joseph Davisson',
#   'value': 0.2559672811550487},
#  {'source': 'Joseph John Thomson',
#   'target': 'Carl David Anderson',
#   'value': 0.2532373975162296},
#  {'source': 'Julian Schwinger',
#   'target': 'quantum field theory',
#   'value': 0.48663531648332775},
#  {'source': 'Julian Schwinger',
#   'target': 'quantum electrodynamics',
#   'value': 0.4630132182717134},
#  {'source': 'Julian Schwinger',
#   'target': 'Sheldon Lee Glashow',
#   'value': 0.4219491069519907},
#  {'source': 'Julian Schwinger',
#   'target': 'effective field theory',
#   'value': 0.3817125843725913},
#  {'source': 'Julian Schwinger',
#   'target': 'theory of everything',
#   'value': 0.37946473044658646},
#  {'source': 'Julian Schwinger',
#   'target': 'quantum optics',
#   'value': 0.3703118372251154},
#  {'source': 'Julian Schwinger',
#   'target': 'quantum electronics',
#   'value': 0.3703118372251154},
#  {'source': 'Julian Schwinger',
#   'target': 'atomic, molecular, and optical physics',
#   'value': 0.36120214967042596},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Manne Siegbahn',
#   'value': 0.7323291787440034},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5957084929635277},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.5914349102085996},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Frits Zernike',
#   'value': 0.5885159954132367},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5885157494390242},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Ernst Ruska',
#   'value': 0.5846834885781282},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Melvin Schwartz',
#   'value': 0.5826593034135803},
#  {'source': 'Kai Manne Börje Siegbahn',
#   'target': 'Nils Gustaf Dalén',
#   'value': 0.5814722122345947},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Johannes Georg Bednorz',
#   'value': 0.6537127007047621},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Hiroshi Amano',
#   'value': 0.47478820659562676},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Wolfgang Paul',
#   'value': 0.45621880330248143},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.45441103857366266},
#  {'source': 'Karl Alexander Müller',
#   'target': 'David Morris Lee',
#   'value': 0.44771770291046087},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4457663555550177},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4446084610165616},
#  {'source': 'Karl Alexander Müller',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.4409756049932567},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Guglielmo Marconi',
#   'value': 0.3779845457570588},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.3708044713879461},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.32686121154725917},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Bertram Brockhouse',
#   'value': 0.32205881431792016},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.31467680401506176},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Wolfgang Paul',
#   'value': 0.31421562016866705},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'George E. Smith',
#   'value': 0.3072134739531801},
#  {'source': 'Karl Ferdinand Braun',
#   'target': 'Alfred Kastler',
#   'value': 0.30492113090541295},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'David J. Thouless',
#   'value': 0.47153804609768546},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'François Englert',
#   'value': 0.4604132148217025},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'David Morris Lee',
#   'value': 0.4475166679076414},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.43622625165254497},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.434565669656541},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'John M. Kosterlitz',
#   'value': 0.42779811481845226},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'Hiroshi Amano',
#   'value': 0.4251055864753627},
#  {'source': 'Kenneth G. Wilson',
#   'target': 'Bertram Brockhouse',
#   'value': 0.42089814597436553},
#  {'source': 'Kip Thorne',
#   'target': 'Barry Barish',
#   'value': 0.5325361822765358},
#  {'source': 'Kip Thorne',
#   'target': 'Takaaki Kajita',
#   'value': 0.42732023847330425},
#  {'source': 'Kip Thorne',
#   'target': 'Joseph Hooton Taylor Jr.',
#   'value': 0.4234255152563187},
#  {'source': 'Kip Thorne',
#   'target': 'Russell Alan Hulse',
#   'value': 0.404712881866284},
#  {'source': 'Kip Thorne',
#   'target': 'Arthur B. McDonald',
#   'value': 0.391898775392629},
#  {'source': 'Kip Thorne',
#   'target': 'Konstantin Novoselov',
#   'value': 0.3867310868465202},
#  {'source': 'Kip Thorne',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3795542153205964},
#  {'source': 'Kip Thorne',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3723531896058255},
#  {'source': 'Klaus von Klitzing',
#   'target': 'Wilhelm Wien',
#   'value': 0.46455151974593495},
#  {'source': 'Klaus von Klitzing',
#   'target': 'Manne Siegbahn',
#   'value': 0.4644554121632446},
#  {'source': 'Klaus von Klitzing',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4155237288546498},
#  {'source': 'Klaus von Klitzing',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4055390207358198},
#  {'source': 'Klaus von Klitzing',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.4024117496796297},
#  {'source': 'Klaus von Klitzing',
#   'target': 'Frits Zernike',
#   'value': 0.39978644686866444},
#  {'source': 'Klaus von Klitzing',
#   'target': 'David Morris Lee',
#   'value': 0.3953865520157132},
#  {'source': 'Klaus von Klitzing',
#   'target': 'Arthur B. McDonald',
#   'value': 0.3938407365150831},
#  {'source': 'Konstantin Novoselov',
#   'target': 'David J. Thouless',
#   'value': 0.5286414451152872},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Isamu Akasaki',
#   'value': 0.512452708181663},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Manne Siegbahn',
#   'value': 0.4933831283356077},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Charles K. Kao',
#   'value': 0.48938607299274983},
#  {'source': 'Konstantin Novoselov',
#   'target': 'John L. Hall',
#   'value': 0.486231681187562},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.481701509469338},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Hiroshi Amano',
#   'value': 0.4748267077539079},
#  {'source': 'Konstantin Novoselov',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.45447300762265463},
#  {'source': 'Leo Esaki',
#   'target': 'Hiroshi Amano',
#   'value': 0.5121344108622363},
#  {'source': 'Leo Esaki',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.46749442753855},
#  {'source': 'Leo Esaki',
#   'target': 'Toshihide Maskawa',
#   'value': 0.4572489717461802},
#  {'source': 'Leo Esaki',
#   'target': 'Makoto Kobayashi',
#   'value': 0.4496611471371688},
#  {'source': 'Leo Esaki',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4140288142278749},
#  {'source': 'Leo Esaki',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.41205358981656837},
#  {'source': 'Leo Esaki',
#   'target': 'John L. Hall',
#   'value': 0.40742621526292605},
#  {'source': 'Leo Esaki',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.40701094919651337},
#  {'source': 'Leo James Rainwater',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.6137875602894364},
#  {'source': 'Leo James Rainwater',
#   'target': 'Frederick Reines',
#   'value': 0.5189341655845475},
#  {'source': 'Leo James Rainwater',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.5080217755760943},
#  {'source': 'Leo James Rainwater',
#   'target': 'Jerome I. Friedman',
#   'value': 0.48744401166655443},
#  {'source': 'Leo James Rainwater',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.46659861112379675},
#  {'source': 'Leo James Rainwater',
#   'target': 'James Franck',
#   'value': 0.4626802210227114},
#  {'source': 'Leo James Rainwater',
#   'target': 'Maria Goeppert-Mayer',
#   'value': 0.4532795512072213},
#  {'source': 'Leo James Rainwater',
#   'target': 'John Robert Schrieffer',
#   'value': 0.44594333443209694},
#  {'source': 'Leon Max Lederman',
#   'target': 'Leon Neil Cooper',
#   'value': 0.47650297514224005},
#  {'source': 'Leon Max Lederman',
#   'target': 'Konstantin Novoselov',
#   'value': 0.42327593443559935},
#  {'source': 'Leon Max Lederman',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.41983619980793535},
#  {'source': 'Leon Max Lederman',
#   'target': 'Charles K. Kao',
#   'value': 0.41928854897344947},
#  {'source': 'Leon Max Lederman',
#   'target': 'Steven Weinberg',
#   'value': 0.4132119219116377},
#  {'source': 'Leon Max Lederman',
#   'target': 'Isamu Akasaki',
#   'value': 0.3954677293494552},
#  {'source': 'Leon Max Lederman',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.39320743710116096},
#  {'source': 'Leon Max Lederman',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.38437644214449745},
#  {'source': 'Leon Neil Cooper',
#   'target': 'John Robert Schrieffer',
#   'value': 0.5628881625934193},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Melvin Schwartz',
#   'value': 0.5202858476148059},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Bertram Brockhouse',
#   'value': 0.487699511296845},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.48388949440048507},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Robert Hofstadter',
#   'value': 0.48007042093629587},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Hiroshi Amano',
#   'value': 0.46257254540100684},
#  {'source': 'Leon Neil Cooper',
#   'target': 'John L. Hall',
#   'value': 0.45697535925075183},
#  {'source': 'Leon Neil Cooper',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4532369753232851},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Nicolay Gennadiyevich Basov',
#   'value': 0.341069325412748},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'atomic, molecular, and optical physics',
#   'value': 0.32270357058714655},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Sheldon Lee Glashow',
#   'value': 0.31683846604266735},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Anthony James Leggett',
#   'value': 0.3049284848746474},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'atomic physics',
#   'value': 0.2997272040849902},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Alexander Prokhorov',
#   'value': 0.29809802180977857},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Vitaly Lazarevich Ginzburg',
#   'value': 0.2976608164890804},
#  {'source': 'Lev Davidovich Landau',
#   'target': 'Frank Wilczek',
#   'value': 0.29723108858267866},
#  {'source': 'Lord Rayleigh',
#   'target': 'Yoichiro Nambu',
#   'value': 0.3974573526009893},
#  {'source': 'Lord Rayleigh',
#   'target': 'John Robert Schrieffer',
#   'value': 0.37363067627769125},
#  {'source': 'Lord Rayleigh',
#   'target': 'Charles Glover Barkla',
#   'value': 0.3728986743009552},
#  {'source': 'Lord Rayleigh',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.3727319282606048},
#  {'source': 'Lord Rayleigh',
#   'target': 'John Bardeen',
#   'value': 0.36580646398805255},
#  {'source': 'Lord Rayleigh',
#   'target': 'Chen-Ning Yang',
#   'value': 0.36416250077614887},
#  {'source': 'Lord Rayleigh',
#   'target': 'Frederick Reines',
#   'value': 0.3565407472149434},
#  {'source': 'Lord Rayleigh',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.352970848355885},
#  {'source': 'Louis Néel',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.47254588762928},
#  {'source': 'Louis Néel',
#   'target': 'David J. Wineland',
#   'value': 0.4173929065715228},
#  {'source': 'Louis Néel',
#   'target': 'Nevill Francis Mott',
#   'value': 0.40164331061255165},
#  {'source': 'Louis Néel',
#   'target': 'Riccardo Giacconi',
#   'value': 0.3818680068670886},
#  {'source': 'Louis Néel',
#   'target': 'John L. Hall',
#   'value': 0.3778154574302224},
#  {'source': 'Louis Néel',
#   'target': 'Robert B. Laughlin',
#   'value': 0.3770396750751734},
#  {'source': 'Louis Néel',
#   'target': 'Frits Zernike',
#   'value': 0.3684465786561258},
#  {'source': 'Louis Néel',
#   'target': 'Edward Mills Purcell',
#   'value': 0.3617231777111178},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Gabriel Lippmann',
#   'value': 0.511470172438525},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.5074945069707266},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Louis Néel',
#   'value': 0.3690176555374673},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Albert Fert',
#   'value': 0.3517786176540437},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'particle physics',
#   'value': 0.32220162023308796},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Nils Gustaf Dalén',
#   'value': 0.30995966197734015},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'atomic, molecular, and optical physics',
#   'value': 0.3046888898483543},
#  {'source': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'target': 'Clinton Joseph Davisson',
#   'value': 0.2935992726241873},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.46747464055163307},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Frederick Reines',
#   'value': 0.4490148475716817},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Ernest Lawrence',
#   'value': 0.40740431542166045},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Yoichiro Nambu',
#   'value': 0.40304100629674094},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.3706784678229454},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Chen-Ning Yang',
#   'value': 0.3598787279464942},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Edward Mills Purcell',
#   'value': 0.3488462616064912},
#  {'source': 'Luis Walter Alvarez',
#   'target': 'Arthur Holly Compton',
#   'value': 0.33116103404383396},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.48991040638696115},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Andre Geim',
#   'value': 0.4837747300496119},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Melvin Schwartz',
#   'value': 0.4555967521322481},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Frits Zernike',
#   'value': 0.4538755099993352},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.4505504316300963},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.441211023033205},
#  {'source': 'Makoto Kobayashi',
#   'target': 'John L. Hall',
#   'value': 0.4408865185644138},
#  {'source': 'Makoto Kobayashi',
#   'target': 'Roy J. Glauber',
#   'value': 0.4295251809191228},
#  ...]

# %% [markdown]
# Similar to how we did at the beginning of this project for the small network, we export this as a json file. As before, we dump this file in a folder named "data", which is itself inside a folder containing "index.html". Open up index.html, and you will be able to interact with our social network.
#
# When you open up this file, you will see a social network. Each circle represents either a physicist ("red") or domain ("blue"). Additionally, clicking on one of them will highlight the 8 closest connections. The size of each circle is determined by how many words were in the corresponding Wikipedia entry.

# %%
network_dict = {"nodes": nodes_list,
                "links": links_list}

with open(".\data\physicists.json","w") as f:
    json.dump(network_dict, f, indent=4)
